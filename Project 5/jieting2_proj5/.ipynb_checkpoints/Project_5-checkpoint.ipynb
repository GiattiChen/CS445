# %% [markdown]
# # Programming Project #5: Video Stitching and Processing

# %% [markdown]
# ## CS445: Computational Photography - Fall 2019

# %% [markdown]
# ### Part I: Stitch two key frames <img src="images/project_5/image005.jpg" alt="Drawing" style="float: right; width: 450px"/>
#
# #### This involves:
# 1. compute homography H between two frames;
# 2. project each frame onto the same surface;
# 3. blend the surfaces.
#
#
#
# Check that your homography is correct by plotting four points that form a square in frame 270 and their projections in each image, like this:
# <p>
#     <img src="images/project_5/image002.jpg" alt="Drawing"/>
#     <img src="images/project_5/image004.jpg" alt="Drawing"/>
# </p>

# %%
import cv2
import numpy as np
from numpy.linalg import svd, inv

# %matplotlib inline
from matplotlib import pyplot as plt

# %%
pts = np.array([[10,5],[20,30],[70,20],[50,10]], np.int32)
pts = pts.reshape((-1,1,2))
print(pts)
# Out:
# [[[10  5]]
#
#  [[20 30]]
#
#  [[70 20]]
#
#  [[50 10]]]

# %%
# images location
im1 = './images/input/frames/f0001.jpg'
im2 = './images/input/frames/f0270.jpg'

# Load an color image in grayscale
im1 = cv2.imread(im1) # float32, 0.0-1.0
im2 = cv2.imread(im2)
print(im1.shape[0],im1.shape[1],im1.shape[2])
# Out:
# 360 480 3

# %%
def auto_homography(Ia,Ib, homography_func=None):
    '''
    Computes a homography that maps points from Ia to Ib

    Input: Ia and Ib are images
    Output: H is the homography

    '''
    if Ia.dtype == 'float32' and Ib.dtype == 'float32':
        Ia = (Ia*255).astype(np.uint8)
        Ib = (Ib*255).astype(np.uint8)
    
    Ia_gray = cv2.cvtColor(Ia,cv2.COLOR_BGR2GRAY)
    Ib_gray = cv2.cvtColor(Ib,cv2.COLOR_BGR2GRAY)

    # Initiate SIFT detector
    sift = cv2.xfeatures2d.SIFT_create()
    
    # find the keypoints and descriptors with SIFT
    # kp_a is keypoints List and des_a is descriptors List
    kp_a, des_a = sift.detectAndCompute(Ia_gray,None)
    kp_b, des_b = sift.detectAndCompute(Ib_gray,None)    
    
    # BFMatcher with default params
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(des_a,des_b, k=2)
#     print('---TEST values in matches, which is list of elements(a,b)---')
#     print(matches[0])
#     print(matches[0][0].distance)
#     print(matches[0][1].distance)
    
    # Apply ratio test
    good = []
    for m,n in matches:
        if m.distance < 0.75*n.distance:
            good.append(m)
    
    numMatches = int(len(good)) # numMatches = 215
    matches = good 
    
    # Xa and Xb are 3xN matrices that contain homogeneous coordinates for the N
    # matching points for each image
    Xa = np.ones((3,numMatches))
    Xb = np.ones((3,numMatches))
    
#     print('---TEST 3*215 point---')
#     print(Xa[:,0][0:2])
#     print(Xa[:,0])
    pts1_good = np.ones((3,4))
    pts2_good = np.ones((3,4))
    for idx, match_i in enumerate(matches):
        Xa[:,idx][0:2] = kp_a[match_i.queryIdx].pt
        Xb[:,idx][0:2] = kp_b[match_i.trainIdx].pt

    ## RANSAC
    niter = 1000
    best_score = 0
    
    H = np.zeros((3,3))
    for t in range(niter):
        # estimate homography
        subset = np.random.choice(numMatches, 4, replace=False)
        pts1 = Xa[:,subset]
        pts2 = Xb[:,subset]

        H_t = homography_func(pts1, pts2)
#         H_t = computeHomography(pts1, pts2) # edit helper code below (computeHomography)
        # pts1 = 3xN matrix and N = 4

        # score homography
        Xb_ = np.dot(H_t, Xa) # project points from first image to second using H
        du = Xb_[0,:]/Xb_[2,:] - Xb[0,:]/Xb[2,:]
        dv = Xb_[1,:]/Xb_[2,:] - Xb[1,:]/Xb[2,:]
        
        ok_t = np.sqrt(du**2 + dv**2) < 1  # you may need to play with this threshold
        score_t = sum(ok_t)

        if score_t > best_score:
            best_score = score_t
            H = H_t
            in_idx = ok_t
            pts1_good = pts1
            pts2_good = pts2
#     print(pts1_good)
#     print(pts2_good)
    print('best score: {:02f}'.format(best_score))
    
# # Check that your homography is correct by plotting four points that form a square in frame 270 
#     # use as the four corners to draw the polylines
#     con_pts1 = np.zeros((4,2),np.int32)
#     con_pts2 = np.zeros((4,2),np.int32)
    
#     for i in range (4):
# #         print("point %d Xa"%(i),pts1_good[:,i])
# #         print("point %d Xb"%(i),pts2_good[:,i])  
# #         Xb_ = np.dot(H, Xa)
# #         print("point %d Xb_"%(i),Xb_[:,i])
# #         print(Xb_[:,i]/Xb_[2,i])
#         con_pts1[i] = pts1_good[0:2,i]
#         con_pts2[i] = pts2_good[0:2,i]
# #         print(con_pts1[i])
# #         print(con_pts2[i])
# #     A[[i, j], :] = A[[j, i], :] # 实现了第i行与第j行的互换
#     im1_RGB2 = cv2.cvtColor(Ia,cv2.COLOR_BGR2RGB)
#     im2_RGB2 = cv2.cvtColor(Ib,cv2.COLOR_BGR2RGB)
#     con_pts1[[0, 2], :] = con_pts1[[2, 0], :]
#     con_pts2[[0, 2], :] = con_pts2[[2, 0], :]
    
# #   for draw rectangular  im1_RGB2 = cv2.rectangle(im1_RGB2,(100,100),(200,200),(255,0,0),3)
# #     pts = np.array([[10,5],[20,30],[70,20],[50,10]], np.int32)
#     con_pts1 = con_pts1.reshape((-1,1,2))
#     con_pts2 = con_pts2.reshape((-1,1,2))
# #     print("--------")
# #     print(con_pts1)
# #     print(con_pts2)
#     im1_RGB2 = cv2.polylines(im1_RGB2,[con_pts1],True,(255,0,0),thickness = 2,lineType = 8)
#     im2_RGB2 = cv2.polylines(im2_RGB2,[con_pts2],True,(255,0,0),thickness = 2,lineType = 8)
    
#     plt.imshow(im1_RGB2)
#     plt.show()
    
#     plt.imshow(im2_RGB2)
#     plt.show()
    
#     # Optionally, you may want to re-estimate H based on inliers

    return H

# %%
def computeHomography(pts1, pts2):
    '''
    Compute homography that maps from pts1 to pts2 using least squares solver
     
    Input: pts1 and pts2 are 3xN matrices for N points in homogeneous
    coordinates.  N is 4.
    
    Output: H is a 3x3 matrix, such that pts2~=H*pts1
    '''
    
    dimen, num = pts1.shape
    A = np.zeros((2*num, 9), dtype = np.float32)
    
    for i in range (0, num):
        # p_prime = w*[u_prime,v_prime,1]
        # p = [u,v,1]
        p_prime = pts2[:,i]
        u_prime = p_prime[0]/p_prime[2]
        v_prime = p_prime[1]/p_prime[2]
        
        p = pts1[:,i]
        u = p[0]/p[2]
        v = p[1]/p[2]
        A[i*2,:] = [-u,-v,-1,0,0,0,u*u_prime, v*u_prime, u_prime]
        A[i*2+1,:] = [0,0,0,-u,-v,-1,u*v_prime, v*v_prime, v_prime]
    U,S,Vt = svd(A)
    h = Vt[-1,:]
    H = np.reshape(h, (3, 3))
    
#     std1_u = np.std(pts1[1,:])
#     std1_v =  np.std(pts1[2,:])
#     mean1_u = np.mean(pts1[1,:])
#     mean1_v = np.mean(pts1[2,:]) 
#     T1 = np.matrix([[1/std1_u, 0, 0],[0, 1/std1_v, 0],[0, 0, 1]]) * np.matrix([[1,0,-mean1_u],[0,1,-mean1_v],[0,0,1]])
    
#     std2_u = np.std(pts2[1,:])
#     std2_v = np.std(pts2[2,:])
#     mean2_u = np.mean(pts2[1,:])
#     mean2_v = np.mean(pts2[2,:]) 
#     T2 = np.matrix([[1/std2_u, 0, 0],[0, 1/std2_v, 0],[0, 0, 1]]) * np.matrix([[1,0,-mean2_u],[0,1,-mean2_v],[0,0,1]])
#     H = T2/H_n * T1
    return H

# %%
H = auto_homography(im1,im2, computeHomography)
# Out:
# best score: 144.000000

# %%
im1_path = './images/input/frames/f0001.jpg'
im2_path = './images/input/frames/f0270.jpg'
im1_cv2 = cv2.imread(im1_path) # uint 0-255
im2_cv2 = cv2.imread(im2_path)

im1_RGB = cv2.cvtColor(im1_cv2,cv2.COLOR_BGR2RGB)
im2_RGB = cv2.cvtColor(im2_cv2,cv2.COLOR_BGR2RGB)

im1_plt = im1_RGB.astype(np.float32)/255
im2_plt = im2_RGB.astype(np.float32)/255


# im1 = cv2.imread(im1_path,cv2.COLOR_BGR2RGB)
# im2 = cv2.imread(im2_path,cv2.COLOR_BGR2RGB)
# Load an color image in grayscale
# im1 = plt.imread(im1) # float32, 0.0-1.0
# im2 = plt.imread(im2)

fig, axes = plt.subplots(3,2)
axes[0,0].imshow(im1_cv2)
axes[0,1].imshow(im2_cv2)
axes[1,0].imshow(im1_RGB)
axes[1,1].imshow(im2_RGB)
axes[2,0].imshow(im1_plt)
axes[2,1].imshow(im2_plt)
"It is important to change color from BGR to RGB"
# Out:
# 'It is important to change color from BGR to RGB'

# %%
cols = 2000
rows = 500
# 360*480
# pts = np.float32([[0, 0], [0, h-1], [w-1, h-1], [w-1, 0]]).reshape(-1, 1, 2)
# dst = cv2.perspectiveTransform(pts, H)
H_transition = np.identity(3)
H_transition[0,2] = cols/2-240
H_transition[1,2] = rows/2-180
print(H_transition)
# Xb_ = np.dot(H, im1_plt) # project points from first image to second using H
# du = Xb_[0,:]/Xb_[2,:]
# img_warped = cv2.warpPerspective(img, H_t.dot(H), (output_width, output_height))

img_warped_270 = cv2.warpPerspective(im2_plt,H_transition,(cols, rows))
img_warped_0 = cv2.warpPerspective(im1_plt, np.dot(H_transition, H), (cols, rows))
# img_warped3 = cv2.warpPerspective(img_warped2, H_transition, (w, h))

plt.imshow(img_warped_270)
plt.show()
plt.imshow(img_warped_0)
plt.show()
#  method 1
print("method1")
result = img_warped_270
for i in range(0,rows):
    for j in range(0,cols):
        if (result[i,j].sum() == 0) and (img_warped_0[i,j].sum() != 0):
            result[i,j] = img_warped_0[i,j]
plt.imshow(result)
plt.show()
# Out:
# [[  1.   0. 760.]
#  [  0.   1.  70.]
#  [  0.   0.   1.]]
# method1

# %%
'''
#  method 2
print("method2")
for col in range(0, cols):
    if img_warped_270[:, col].any() and img_warped_0[:, col].any():
        left = col
        break
for col in range(cols-1, 0, -1):
    if img_warped_270[:, col].any() and img_warped_0[:, col].any():
        right = col
        break
srcImg = img_warped_270
warpImg = img_warped_0
res = np.zeros([rows, cols, 3], np.float32)

for row in range(0, rows):
    for col in range(0, cols):
        if not srcImg[row, col].any():
            res[row, col] = warpImg[row, col]
        elif not warpImg[row, col].any():
            res[row, col] = srcImg[row, col]
        else:
            srcImgLen = float(abs(col - right))
            testImgLen = float(abs(col - left))
            alpha = srcImgLen / (srcImgLen + testImgLen)
            res[row, col] = np.clip(srcImg[row, col] * (1-alpha) + warpImg[row, col] * alpha, 0, 255)
plt.imshow(res)
plt.show()
'''
# Out:
# '\n#  method 2\nprint("method2")\nfor col in range(0, cols):\n    if img_warped_270[:, col].any() and img_warped_0[:, col].any():\n        left = col\n        break\nfor col in range(cols-1, 0, -1):\n    if img_warped_270[:, col].any() and img_warped_0[:, col].any():\n        right = col\n        break\nsrcImg = img_warped_270\nwarpImg = img_warped_0\nres = np.zeros([rows, cols, 3], np.float32)\n\nfor row in range(0, rows):\n    for col in range(0, cols):\n        if not srcImg[row, col].any():\n            res[row, col] = warpImg[row, col]\n        elif not warpImg[row, col].any():\n            res[row, col] = srcImg[row, col]\n        else:\n            srcImgLen = float(abs(col - right))\n            testImgLen = float(abs(col - left))\n            alpha = srcImgLen / (srcImgLen + testImgLen)\n            res[row, col] = np.clip(srcImg[row, col] * (1-alpha) + warpImg[row, col] * alpha, 0, 255)\nplt.imshow(res)\nplt.show()\n'

# %% [markdown]
# ### Part II: Panorama using five key frames
#
# In this part you will produce a panorama using five key frames. Let's determine frames [90, 270, 450, 630, 810] as key frames. The goal is to map all the five frames onto the plane corresponding to frame 450 (that we also call the _reference frame_). For the frames 270 and 630 you can follow the instructions in part 1.
#
# <img src="images/project_5/header.jpg" alt="Drawing" style="float: center; width: 500px"/>
#
# Mapping frame 90 to frame 450 is difficult because they share very little area. Therefore you need to perform a two stage mapping by using frame 270 as a guide. Compute one projection from 90 to 270 and one from 270 to 450 and multiply the two matrices. This produces a projection from 90 to 450 even though these frames have very little area in common

# %%
import cv2
import numpy as np
import utils

# %%
def warpped(result,img1,img2,H):
    # img2 = H*img1
    rows, cols, c = result.shape
#     cols = 1200
#     rows = 500
    img_warped = cv2.warpPerspective(img1, np.dot(H_transition, H), (cols, rows))
    return utils.blendImages(img_warped, result)
#     the following is written by myself instead of using utils.blendImages
#     for i in range(0,rows):
#         for j in range(0,cols):
#             if (result[i,j].sum() == 0) and (img_warped[i,j].sum() != 0):
#                 result[i,j] = img_warped[i,j]
#     return 0

# %%
master_frames =[90, 270, 450, 630, 810]
reference_frame = 450
reference_idx = master_frames.index(reference_frame)
im1_path = './images/input/frames/f0090.jpg'
im2_path = './images/input/frames/f0270.jpg'
im3_path = './images/input/frames/f0450.jpg'
im4_path = './images/input/frames/f0630.jpg'
im5_path = './images/input/frames/f0810.jpg'
im1_cv2 = cv2.imread(im1_path) # float32, 0.0-1.0
im2_cv2 = cv2.imread(im2_path)
im3_cv2 = cv2.imread(im3_path)
im4_cv2 = cv2.imread(im4_path)
im5_cv2 = cv2.imread(im5_path)

im1_RGB = cv2.cvtColor(im1_cv2,cv2.COLOR_BGR2RGB)
im2_RGB = cv2.cvtColor(im2_cv2,cv2.COLOR_BGR2RGB)
im3_RGB = cv2.cvtColor(im3_cv2,cv2.COLOR_BGR2RGB)
im4_RGB = cv2.cvtColor(im4_cv2,cv2.COLOR_BGR2RGB)
im5_RGB = cv2.cvtColor(im5_cv2,cv2.COLOR_BGR2RGB)

# fig, axes = plt.subplots(1,5)
# axes[0].imshow(im1_RGB)
# axes[1].imshow(im2_RGB)
# axes[2].imshow(im3_RGB)
# axes[3].imshow(im4_RGB)
# axes[4].imshow(im5_RGB)

H12 = auto_homography(im1_cv2,im2_cv2, computeHomography)
H23 = auto_homography(im2_cv2,im3_cv2, computeHomography)
H43 = auto_homography(im4_cv2,im3_cv2, computeHomography)
H54 = auto_homography(im5_cv2,im4_cv2, computeHomography)

H13 = np.dot(H23,H12)
H53 = np.dot(H43,H54)
cols = 1632
rows = 512
# 360*480
H_transition = np.identity(3)
H_transition[0,2] = cols/2-240
H_transition[1,2] = rows/2-180

result = cv2.warpPerspective(im1_RGB ,np.dot(H_transition, H13),(cols, rows))

result = warpped(result,im2_RGB,im3_RGB,H23)
result = warpped(result,im3_RGB,im3_RGB,np.identity(3))
result = warpped(result,im4_RGB,im3_RGB,H43)
result = warpped(result,im5_RGB,im3_RGB,H53)

# img_warped_0 = cv2.warpPerspective(im1_plt, np.dot(H_transition, H), (cols, rows))
# img_warped3 = cv2.warpPerspective(img_warped2, H_transition, (w, h))

plt.imshow(result)
plt.show()
# Out:
# best score: 208.000000
# best score: 153.000000
# best score: 132.000000
# best score: 97.000000

# %% [markdown]
# ### Part 3: Map the video to the reference plane

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from math import floor

# import utils

# %%
dir_frames = 'images/input/frames'
filenames = []
filesinfo = os.scandir(dir_frames)
filesinfo

# %%
filenames = [f.path for f in filesinfo if f.name.endswith(".jpg")]
filenames.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
filenames
# Out:
# ['images/input/frames/f0001.jpg',
#  'images/input/frames/f0002.jpg',
#  'images/input/frames/f0003.jpg',
#  'images/input/frames/f0004.jpg',
#  'images/input/frames/f0005.jpg',
#  'images/input/frames/f0006.jpg',
#  'images/input/frames/f0007.jpg',
#  'images/input/frames/f0008.jpg',
#  'images/input/frames/f0009.jpg',
#  'images/input/frames/f0010.jpg',
#  'images/input/frames/f0011.jpg',
#  'images/input/frames/f0012.jpg',
#  'images/input/frames/f0013.jpg',
#  'images/input/frames/f0014.jpg',
#  'images/input/frames/f0015.jpg',
#  'images/input/frames/f0016.jpg',
#  'images/input/frames/f0017.jpg',
#  'images/input/frames/f0018.jpg',
#  'images/input/frames/f0019.jpg',
#  'images/input/frames/f0020.jpg',
#  'images/input/frames/f0021.jpg',
#  'images/input/frames/f0022.jpg',
#  'images/input/frames/f0023.jpg',
#  'images/input/frames/f0024.jpg',
#  'images/input/frames/f0025.jpg',
#  'images/input/frames/f0026.jpg',
#  'images/input/frames/f0027.jpg',
#  'images/input/frames/f0028.jpg',
#  'images/input/frames/f0029.jpg',
#  'images/input/frames/f0030.jpg',
#  'images/input/frames/f0031.jpg',
#  'images/input/frames/f0032.jpg',
#  'images/input/frames/f0033.jpg',
#  'images/input/frames/f0034.jpg',
#  'images/input/frames/f0035.jpg',
#  'images/input/frames/f0036.jpg',
#  'images/input/frames/f0037.jpg',
#  'images/input/frames/f0038.jpg',
#  'images/input/frames/f0039.jpg',
#  'images/input/frames/f0040.jpg',
#  'images/input/frames/f0041.jpg',
#  'images/input/frames/f0042.jpg',
#  'images/input/frames/f0043.jpg',
#  'images/input/frames/f0044.jpg',
#  'images/input/frames/f0045.jpg',
#  'images/input/frames/f0046.jpg',
#  'images/input/frames/f0047.jpg',
#  'images/input/frames/f0048.jpg',
#  'images/input/frames/f0049.jpg',
#  'images/input/frames/f0050.jpg',
#  'images/input/frames/f0051.jpg',
#  'images/input/frames/f0052.jpg',
#  'images/input/frames/f0053.jpg',
#  'images/input/frames/f0054.jpg',
#  'images/input/frames/f0055.jpg',
#  'images/input/frames/f0056.jpg',
#  'images/input/frames/f0057.jpg',
#  'images/input/frames/f0058.jpg',
#  'images/input/frames/f0059.jpg',
#  'images/input/frames/f0060.jpg',
#  'images/input/frames/f0061.jpg',
#  'images/input/frames/f0062.jpg',
#  'images/input/frames/f0063.jpg',
#  'images/input/frames/f0064.jpg',
#  'images/input/frames/f0065.jpg',
#  'images/input/frames/f0066.jpg',
#  'images/input/frames/f0067.jpg',
#  'images/input/frames/f0068.jpg',
#  'images/input/frames/f0069.jpg',
#  'images/input/frames/f0070.jpg',
#  'images/input/frames/f0071.jpg',
#  'images/input/frames/f0072.jpg',
#  'images/input/frames/f0073.jpg',
#  'images/input/frames/f0074.jpg',
#  'images/input/frames/f0075.jpg',
#  'images/input/frames/f0076.jpg',
#  'images/input/frames/f0077.jpg',
#  'images/input/frames/f0078.jpg',
#  'images/input/frames/f0079.jpg',
#  'images/input/frames/f0080.jpg',
#  'images/input/frames/f0081.jpg',
#  'images/input/frames/f0082.jpg',
#  'images/input/frames/f0083.jpg',
#  'images/input/frames/f0084.jpg',
#  'images/input/frames/f0085.jpg',
#  'images/input/frames/f0086.jpg',
#  'images/input/frames/f0087.jpg',
#  'images/input/frames/f0088.jpg',
#  'images/input/frames/f0089.jpg',
#  'images/input/frames/f0090.jpg',
#  'images/input/frames/f0091.jpg',
#  'images/input/frames/f0092.jpg',
#  'images/input/frames/f0093.jpg',
#  'images/input/frames/f0094.jpg',
#  'images/input/frames/f0095.jpg',
#  'images/input/frames/f0096.jpg',
#  'images/input/frames/f0097.jpg',
#  'images/input/frames/f0098.jpg',
#  'images/input/frames/f0099.jpg',
#  'images/input/frames/f0100.jpg',
#  'images/input/frames/f0101.jpg',
#  'images/input/frames/f0102.jpg',
#  'images/input/frames/f0103.jpg',
#  'images/input/frames/f0104.jpg',
#  'images/input/frames/f0105.jpg',
#  'images/input/frames/f0106.jpg',
#  'images/input/frames/f0107.jpg',
#  'images/input/frames/f0108.jpg',
#  'images/input/frames/f0109.jpg',
#  'images/input/frames/f0110.jpg',
#  'images/input/frames/f0111.jpg',
#  'images/input/frames/f0112.jpg',
#  'images/input/frames/f0113.jpg',
#  'images/input/frames/f0114.jpg',
#  'images/input/frames/f0115.jpg',
#  'images/input/frames/f0116.jpg',
#  'images/input/frames/f0117.jpg',
#  'images/input/frames/f0118.jpg',
#  'images/input/frames/f0119.jpg',
#  'images/input/frames/f0120.jpg',
#  'images/input/frames/f0121.jpg',
#  'images/input/frames/f0122.jpg',
#  'images/input/frames/f0123.jpg',
#  'images/input/frames/f0124.jpg',
#  'images/input/frames/f0125.jpg',
#  'images/input/frames/f0126.jpg',
#  'images/input/frames/f0127.jpg',
#  'images/input/frames/f0128.jpg',
#  'images/input/frames/f0129.jpg',
#  'images/input/frames/f0130.jpg',
#  'images/input/frames/f0131.jpg',
#  'images/input/frames/f0132.jpg',
#  'images/input/frames/f0133.jpg',
#  'images/input/frames/f0134.jpg',
#  'images/input/frames/f0135.jpg',
#  'images/input/frames/f0136.jpg',
#  'images/input/frames/f0137.jpg',
#  'images/input/frames/f0138.jpg',
#  'images/input/frames/f0139.jpg',
#  'images/input/frames/f0140.jpg',
#  'images/input/frames/f0141.jpg',
#  'images/input/frames/f0142.jpg',
#  'images/input/frames/f0143.jpg',
#  'images/input/frames/f0144.jpg',
#  'images/input/frames/f0145.jpg',
#  'images/input/frames/f0146.jpg',
#  'images/input/frames/f0147.jpg',
#  'images/input/frames/f0148.jpg',
#  'images/input/frames/f0149.jpg',
#  'images/input/frames/f0150.jpg',
#  'images/input/frames/f0151.jpg',
#  'images/input/frames/f0152.jpg',
#  'images/input/frames/f0153.jpg',
#  'images/input/frames/f0154.jpg',
#  'images/input/frames/f0155.jpg',
#  'images/input/frames/f0156.jpg',
#  'images/input/frames/f0157.jpg',
#  'images/input/frames/f0158.jpg',
#  'images/input/frames/f0159.jpg',
#  'images/input/frames/f0160.jpg',
#  'images/input/frames/f0161.jpg',
#  'images/input/frames/f0162.jpg',
#  'images/input/frames/f0163.jpg',
#  'images/input/frames/f0164.jpg',
#  'images/input/frames/f0165.jpg',
#  'images/input/frames/f0166.jpg',
#  'images/input/frames/f0167.jpg',
#  'images/input/frames/f0168.jpg',
#  'images/input/frames/f0169.jpg',
#  'images/input/frames/f0170.jpg',
#  'images/input/frames/f0171.jpg',
#  'images/input/frames/f0172.jpg',
#  'images/input/frames/f0173.jpg',
#  'images/input/frames/f0174.jpg',
#  'images/input/frames/f0175.jpg',
#  'images/input/frames/f0176.jpg',
#  'images/input/frames/f0177.jpg',
#  'images/input/frames/f0178.jpg',
#  'images/input/frames/f0179.jpg',
#  'images/input/frames/f0180.jpg',
#  'images/input/frames/f0181.jpg',
#  'images/input/frames/f0182.jpg',
#  'images/input/frames/f0183.jpg',
#  'images/input/frames/f0184.jpg',
#  'images/input/frames/f0185.jpg',
#  'images/input/frames/f0186.jpg',
#  'images/input/frames/f0187.jpg',
#  'images/input/frames/f0188.jpg',
#  'images/input/frames/f0189.jpg',
#  'images/input/frames/f0190.jpg',
#  'images/input/frames/f0191.jpg',
#  'images/input/frames/f0192.jpg',
#  'images/input/frames/f0193.jpg',
#  'images/input/frames/f0194.jpg',
#  'images/input/frames/f0195.jpg',
#  'images/input/frames/f0196.jpg',
#  'images/input/frames/f0197.jpg',
#  'images/input/frames/f0198.jpg',
#  'images/input/frames/f0199.jpg',
#  'images/input/frames/f0200.jpg',
#  'images/input/frames/f0201.jpg',
#  'images/input/frames/f0202.jpg',
#  'images/input/frames/f0203.jpg',
#  'images/input/frames/f0204.jpg',
#  'images/input/frames/f0205.jpg',
#  'images/input/frames/f0206.jpg',
#  'images/input/frames/f0207.jpg',
#  'images/input/frames/f0208.jpg',
#  'images/input/frames/f0209.jpg',
#  'images/input/frames/f0210.jpg',
#  'images/input/frames/f0211.jpg',
#  'images/input/frames/f0212.jpg',
#  'images/input/frames/f0213.jpg',
#  'images/input/frames/f0214.jpg',
#  'images/input/frames/f0215.jpg',
#  'images/input/frames/f0216.jpg',
#  'images/input/frames/f0217.jpg',
#  'images/input/frames/f0218.jpg',
#  'images/input/frames/f0219.jpg',
#  'images/input/frames/f0220.jpg',
#  'images/input/frames/f0221.jpg',
#  'images/input/frames/f0222.jpg',
#  'images/input/frames/f0223.jpg',
#  'images/input/frames/f0224.jpg',
#  'images/input/frames/f0225.jpg',
#  'images/input/frames/f0226.jpg',
#  'images/input/frames/f0227.jpg',
#  'images/input/frames/f0228.jpg',
#  'images/input/frames/f0229.jpg',
#  'images/input/frames/f0230.jpg',
#  'images/input/frames/f0231.jpg',
#  'images/input/frames/f0232.jpg',
#  'images/input/frames/f0233.jpg',
#  'images/input/frames/f0234.jpg',
#  'images/input/frames/f0235.jpg',
#  'images/input/frames/f0236.jpg',
#  'images/input/frames/f0237.jpg',
#  'images/input/frames/f0238.jpg',
#  'images/input/frames/f0239.jpg',
#  'images/input/frames/f0240.jpg',
#  'images/input/frames/f0241.jpg',
#  'images/input/frames/f0242.jpg',
#  'images/input/frames/f0243.jpg',
#  'images/input/frames/f0244.jpg',
#  'images/input/frames/f0245.jpg',
#  'images/input/frames/f0246.jpg',
#  'images/input/frames/f0247.jpg',
#  'images/input/frames/f0248.jpg',
#  'images/input/frames/f0249.jpg',
#  'images/input/frames/f0250.jpg',
#  'images/input/frames/f0251.jpg',
#  'images/input/frames/f0252.jpg',
#  'images/input/frames/f0253.jpg',
#  'images/input/frames/f0254.jpg',
#  'images/input/frames/f0255.jpg',
#  'images/input/frames/f0256.jpg',
#  'images/input/frames/f0257.jpg',
#  'images/input/frames/f0258.jpg',
#  'images/input/frames/f0259.jpg',
#  'images/input/frames/f0260.jpg',
#  'images/input/frames/f0261.jpg',
#  'images/input/frames/f0262.jpg',
#  'images/input/frames/f0263.jpg',
#  'images/input/frames/f0264.jpg',
#  'images/input/frames/f0265.jpg',
#  'images/input/frames/f0266.jpg',
#  'images/input/frames/f0267.jpg',
#  'images/input/frames/f0268.jpg',
#  'images/input/frames/f0269.jpg',
#  'images/input/frames/f0270.jpg',
#  'images/input/frames/f0271.jpg',
#  'images/input/frames/f0272.jpg',
#  'images/input/frames/f0273.jpg',
#  'images/input/frames/f0274.jpg',
#  'images/input/frames/f0275.jpg',
#  'images/input/frames/f0276.jpg',
#  'images/input/frames/f0277.jpg',
#  'images/input/frames/f0278.jpg',
#  'images/input/frames/f0279.jpg',
#  'images/input/frames/f0280.jpg',
#  'images/input/frames/f0281.jpg',
#  'images/input/frames/f0282.jpg',
#  'images/input/frames/f0283.jpg',
#  'images/input/frames/f0284.jpg',
#  'images/input/frames/f0285.jpg',
#  'images/input/frames/f0286.jpg',
#  'images/input/frames/f0287.jpg',
#  'images/input/frames/f0288.jpg',
#  'images/input/frames/f0289.jpg',
#  'images/input/frames/f0290.jpg',
#  'images/input/frames/f0291.jpg',
#  'images/input/frames/f0292.jpg',
#  'images/input/frames/f0293.jpg',
#  'images/input/frames/f0294.jpg',
#  'images/input/frames/f0295.jpg',
#  'images/input/frames/f0296.jpg',
#  'images/input/frames/f0297.jpg',
#  'images/input/frames/f0298.jpg',
#  'images/input/frames/f0299.jpg',
#  'images/input/frames/f0300.jpg',
#  'images/input/frames/f0301.jpg',
#  'images/input/frames/f0302.jpg',
#  'images/input/frames/f0303.jpg',
#  'images/input/frames/f0304.jpg',
#  'images/input/frames/f0305.jpg',
#  'images/input/frames/f0306.jpg',
#  'images/input/frames/f0307.jpg',
#  'images/input/frames/f0308.jpg',
#  'images/input/frames/f0309.jpg',
#  'images/input/frames/f0310.jpg',
#  'images/input/frames/f0311.jpg',
#  'images/input/frames/f0312.jpg',
#  'images/input/frames/f0313.jpg',
#  'images/input/frames/f0314.jpg',
#  'images/input/frames/f0315.jpg',
#  'images/input/frames/f0316.jpg',
#  'images/input/frames/f0317.jpg',
#  'images/input/frames/f0318.jpg',
#  'images/input/frames/f0319.jpg',
#  'images/input/frames/f0320.jpg',
#  'images/input/frames/f0321.jpg',
#  'images/input/frames/f0322.jpg',
#  'images/input/frames/f0323.jpg',
#  'images/input/frames/f0324.jpg',
#  'images/input/frames/f0325.jpg',
#  'images/input/frames/f0326.jpg',
#  'images/input/frames/f0327.jpg',
#  'images/input/frames/f0328.jpg',
#  'images/input/frames/f0329.jpg',
#  'images/input/frames/f0330.jpg',
#  'images/input/frames/f0331.jpg',
#  'images/input/frames/f0332.jpg',
#  'images/input/frames/f0333.jpg',
#  'images/input/frames/f0334.jpg',
#  'images/input/frames/f0335.jpg',
#  'images/input/frames/f0336.jpg',
#  'images/input/frames/f0337.jpg',
#  'images/input/frames/f0338.jpg',
#  'images/input/frames/f0339.jpg',
#  'images/input/frames/f0340.jpg',
#  'images/input/frames/f0341.jpg',
#  'images/input/frames/f0342.jpg',
#  'images/input/frames/f0343.jpg',
#  'images/input/frames/f0344.jpg',
#  'images/input/frames/f0345.jpg',
#  'images/input/frames/f0346.jpg',
#  'images/input/frames/f0347.jpg',
#  'images/input/frames/f0348.jpg',
#  'images/input/frames/f0349.jpg',
#  'images/input/frames/f0350.jpg',
#  'images/input/frames/f0351.jpg',
#  'images/input/frames/f0352.jpg',
#  'images/input/frames/f0353.jpg',
#  'images/input/frames/f0354.jpg',
#  'images/input/frames/f0355.jpg',
#  'images/input/frames/f0356.jpg',
#  'images/input/frames/f0357.jpg',
#  'images/input/frames/f0358.jpg',
#  'images/input/frames/f0359.jpg',
#  'images/input/frames/f0360.jpg',
#  'images/input/frames/f0361.jpg',
#  'images/input/frames/f0362.jpg',
#  'images/input/frames/f0363.jpg',
#  'images/input/frames/f0364.jpg',
#  'images/input/frames/f0365.jpg',
#  'images/input/frames/f0366.jpg',
#  'images/input/frames/f0367.jpg',
#  'images/input/frames/f0368.jpg',
#  'images/input/frames/f0369.jpg',
#  'images/input/frames/f0370.jpg',
#  'images/input/frames/f0371.jpg',
#  'images/input/frames/f0372.jpg',
#  'images/input/frames/f0373.jpg',
#  'images/input/frames/f0374.jpg',
#  'images/input/frames/f0375.jpg',
#  'images/input/frames/f0376.jpg',
#  'images/input/frames/f0377.jpg',
#  'images/input/frames/f0378.jpg',
#  'images/input/frames/f0379.jpg',
#  'images/input/frames/f0380.jpg',
#  'images/input/frames/f0381.jpg',
#  'images/input/frames/f0382.jpg',
#  'images/input/frames/f0383.jpg',
#  'images/input/frames/f0384.jpg',
#  'images/input/frames/f0385.jpg',
#  'images/input/frames/f0386.jpg',
#  'images/input/frames/f0387.jpg',
#  'images/input/frames/f0388.jpg',
#  'images/input/frames/f0389.jpg',
#  'images/input/frames/f0390.jpg',
#  'images/input/frames/f0391.jpg',
#  'images/input/frames/f0392.jpg',
#  'images/input/frames/f0393.jpg',
#  'images/input/frames/f0394.jpg',
#  'images/input/frames/f0395.jpg',
#  'images/input/frames/f0396.jpg',
#  'images/input/frames/f0397.jpg',
#  'images/input/frames/f0398.jpg',
#  'images/input/frames/f0399.jpg',
#  'images/input/frames/f0400.jpg',
#  'images/input/frames/f0401.jpg',
#  'images/input/frames/f0402.jpg',
#  'images/input/frames/f0403.jpg',
#  'images/input/frames/f0404.jpg',
#  'images/input/frames/f0405.jpg',
#  'images/input/frames/f0406.jpg',
#  'images/input/frames/f0407.jpg',
#  'images/input/frames/f0408.jpg',
#  'images/input/frames/f0409.jpg',
#  'images/input/frames/f0410.jpg',
#  'images/input/frames/f0411.jpg',
#  'images/input/frames/f0412.jpg',
#  'images/input/frames/f0413.jpg',
#  'images/input/frames/f0414.jpg',
#  'images/input/frames/f0415.jpg',
#  'images/input/frames/f0416.jpg',
#  'images/input/frames/f0417.jpg',
#  'images/input/frames/f0418.jpg',
#  'images/input/frames/f0419.jpg',
#  'images/input/frames/f0420.jpg',
#  'images/input/frames/f0421.jpg',
#  'images/input/frames/f0422.jpg',
#  'images/input/frames/f0423.jpg',
#  'images/input/frames/f0424.jpg',
#  'images/input/frames/f0425.jpg',
#  'images/input/frames/f0426.jpg',
#  'images/input/frames/f0427.jpg',
#  'images/input/frames/f0428.jpg',
#  'images/input/frames/f0429.jpg',
#  'images/input/frames/f0430.jpg',
#  'images/input/frames/f0431.jpg',
#  'images/input/frames/f0432.jpg',
#  'images/input/frames/f0433.jpg',
#  'images/input/frames/f0434.jpg',
#  'images/input/frames/f0435.jpg',
#  'images/input/frames/f0436.jpg',
#  'images/input/frames/f0437.jpg',
#  'images/input/frames/f0438.jpg',
#  'images/input/frames/f0439.jpg',
#  'images/input/frames/f0440.jpg',
#  'images/input/frames/f0441.jpg',
#  'images/input/frames/f0442.jpg',
#  'images/input/frames/f0443.jpg',
#  'images/input/frames/f0444.jpg',
#  'images/input/frames/f0445.jpg',
#  'images/input/frames/f0446.jpg',
#  'images/input/frames/f0447.jpg',
#  'images/input/frames/f0448.jpg',
#  'images/input/frames/f0449.jpg',
#  'images/input/frames/f0450.jpg',
#  'images/input/frames/f0451.jpg',
#  'images/input/frames/f0452.jpg',
#  'images/input/frames/f0453.jpg',
#  'images/input/frames/f0454.jpg',
#  'images/input/frames/f0455.jpg',
#  'images/input/frames/f0456.jpg',
#  'images/input/frames/f0457.jpg',
#  'images/input/frames/f0458.jpg',
#  'images/input/frames/f0459.jpg',
#  'images/input/frames/f0460.jpg',
#  'images/input/frames/f0461.jpg',
#  'images/input/frames/f0462.jpg',
#  'images/input/frames/f0463.jpg',
#  'images/input/frames/f0464.jpg',
#  'images/input/frames/f0465.jpg',
#  'images/input/frames/f0466.jpg',
#  'images/input/frames/f0467.jpg',
#  'images/input/frames/f0468.jpg',
#  'images/input/frames/f0469.jpg',
#  'images/input/frames/f0470.jpg',
#  'images/input/frames/f0471.jpg',
#  'images/input/frames/f0472.jpg',
#  'images/input/frames/f0473.jpg',
#  'images/input/frames/f0474.jpg',
#  'images/input/frames/f0475.jpg',
#  'images/input/frames/f0476.jpg',
#  'images/input/frames/f0477.jpg',
#  'images/input/frames/f0478.jpg',
#  'images/input/frames/f0479.jpg',
#  'images/input/frames/f0480.jpg',
#  'images/input/frames/f0481.jpg',
#  'images/input/frames/f0482.jpg',
#  'images/input/frames/f0483.jpg',
#  'images/input/frames/f0484.jpg',
#  'images/input/frames/f0485.jpg',
#  'images/input/frames/f0486.jpg',
#  'images/input/frames/f0487.jpg',
#  'images/input/frames/f0488.jpg',
#  'images/input/frames/f0489.jpg',
#  'images/input/frames/f0490.jpg',
#  'images/input/frames/f0491.jpg',
#  'images/input/frames/f0492.jpg',
#  'images/input/frames/f0493.jpg',
#  'images/input/frames/f0494.jpg',
#  'images/input/frames/f0495.jpg',
#  'images/input/frames/f0496.jpg',
#  'images/input/frames/f0497.jpg',
#  'images/input/frames/f0498.jpg',
#  'images/input/frames/f0499.jpg',
#  'images/input/frames/f0500.jpg',
#  'images/input/frames/f0501.jpg',
#  'images/input/frames/f0502.jpg',
#  'images/input/frames/f0503.jpg',
#  'images/input/frames/f0504.jpg',
#  'images/input/frames/f0505.jpg',
#  'images/input/frames/f0506.jpg',
#  'images/input/frames/f0507.jpg',
#  'images/input/frames/f0508.jpg',
#  'images/input/frames/f0509.jpg',
#  'images/input/frames/f0510.jpg',
#  'images/input/frames/f0511.jpg',
#  'images/input/frames/f0512.jpg',
#  'images/input/frames/f0513.jpg',
#  'images/input/frames/f0514.jpg',
#  'images/input/frames/f0515.jpg',
#  'images/input/frames/f0516.jpg',
#  'images/input/frames/f0517.jpg',
#  'images/input/frames/f0518.jpg',
#  'images/input/frames/f0519.jpg',
#  'images/input/frames/f0520.jpg',
#  'images/input/frames/f0521.jpg',
#  'images/input/frames/f0522.jpg',
#  'images/input/frames/f0523.jpg',
#  'images/input/frames/f0524.jpg',
#  'images/input/frames/f0525.jpg',
#  'images/input/frames/f0526.jpg',
#  'images/input/frames/f0527.jpg',
#  'images/input/frames/f0528.jpg',
#  'images/input/frames/f0529.jpg',
#  'images/input/frames/f0530.jpg',
#  'images/input/frames/f0531.jpg',
#  'images/input/frames/f0532.jpg',
#  'images/input/frames/f0533.jpg',
#  'images/input/frames/f0534.jpg',
#  'images/input/frames/f0535.jpg',
#  'images/input/frames/f0536.jpg',
#  'images/input/frames/f0537.jpg',
#  'images/input/frames/f0538.jpg',
#  'images/input/frames/f0539.jpg',
#  'images/input/frames/f0540.jpg',
#  'images/input/frames/f0541.jpg',
#  'images/input/frames/f0542.jpg',
#  'images/input/frames/f0543.jpg',
#  'images/input/frames/f0544.jpg',
#  'images/input/frames/f0545.jpg',
#  'images/input/frames/f0546.jpg',
#  'images/input/frames/f0547.jpg',
#  'images/input/frames/f0548.jpg',
#  'images/input/frames/f0549.jpg',
#  'images/input/frames/f0550.jpg',
#  'images/input/frames/f0551.jpg',
#  'images/input/frames/f0552.jpg',
#  'images/input/frames/f0553.jpg',
#  'images/input/frames/f0554.jpg',
#  'images/input/frames/f0555.jpg',
#  'images/input/frames/f0556.jpg',
#  'images/input/frames/f0557.jpg',
#  'images/input/frames/f0558.jpg',
#  'images/input/frames/f0559.jpg',
#  'images/input/frames/f0560.jpg',
#  'images/input/frames/f0561.jpg',
#  'images/input/frames/f0562.jpg',
#  'images/input/frames/f0563.jpg',
#  'images/input/frames/f0564.jpg',
#  'images/input/frames/f0565.jpg',
#  'images/input/frames/f0566.jpg',
#  'images/input/frames/f0567.jpg',
#  'images/input/frames/f0568.jpg',
#  'images/input/frames/f0569.jpg',
#  'images/input/frames/f0570.jpg',
#  'images/input/frames/f0571.jpg',
#  'images/input/frames/f0572.jpg',
#  'images/input/frames/f0573.jpg',
#  'images/input/frames/f0574.jpg',
#  'images/input/frames/f0575.jpg',
#  'images/input/frames/f0576.jpg',
#  'images/input/frames/f0577.jpg',
#  'images/input/frames/f0578.jpg',
#  'images/input/frames/f0579.jpg',
#  'images/input/frames/f0580.jpg',
#  'images/input/frames/f0581.jpg',
#  'images/input/frames/f0582.jpg',
#  'images/input/frames/f0583.jpg',
#  'images/input/frames/f0584.jpg',
#  'images/input/frames/f0585.jpg',
#  'images/input/frames/f0586.jpg',
#  'images/input/frames/f0587.jpg',
#  'images/input/frames/f0588.jpg',
#  'images/input/frames/f0589.jpg',
#  'images/input/frames/f0590.jpg',
#  'images/input/frames/f0591.jpg',
#  'images/input/frames/f0592.jpg',
#  'images/input/frames/f0593.jpg',
#  'images/input/frames/f0594.jpg',
#  'images/input/frames/f0595.jpg',
#  'images/input/frames/f0596.jpg',
#  'images/input/frames/f0597.jpg',
#  'images/input/frames/f0598.jpg',
#  'images/input/frames/f0599.jpg',
#  'images/input/frames/f0600.jpg',
#  'images/input/frames/f0601.jpg',
#  'images/input/frames/f0602.jpg',
#  'images/input/frames/f0603.jpg',
#  'images/input/frames/f0604.jpg',
#  'images/input/frames/f0605.jpg',
#  'images/input/frames/f0606.jpg',
#  'images/input/frames/f0607.jpg',
#  'images/input/frames/f0608.jpg',
#  'images/input/frames/f0609.jpg',
#  'images/input/frames/f0610.jpg',
#  'images/input/frames/f0611.jpg',
#  'images/input/frames/f0612.jpg',
#  'images/input/frames/f0613.jpg',
#  'images/input/frames/f0614.jpg',
#  'images/input/frames/f0615.jpg',
#  'images/input/frames/f0616.jpg',
#  'images/input/frames/f0617.jpg',
#  'images/input/frames/f0618.jpg',
#  'images/input/frames/f0619.jpg',
#  'images/input/frames/f0620.jpg',
#  'images/input/frames/f0621.jpg',
#  'images/input/frames/f0622.jpg',
#  'images/input/frames/f0623.jpg',
#  'images/input/frames/f0624.jpg',
#  'images/input/frames/f0625.jpg',
#  'images/input/frames/f0626.jpg',
#  'images/input/frames/f0627.jpg',
#  'images/input/frames/f0628.jpg',
#  'images/input/frames/f0629.jpg',
#  'images/input/frames/f0630.jpg',
#  'images/input/frames/f0631.jpg',
#  'images/input/frames/f0632.jpg',
#  'images/input/frames/f0633.jpg',
#  'images/input/frames/f0634.jpg',
#  'images/input/frames/f0635.jpg',
#  'images/input/frames/f0636.jpg',
#  'images/input/frames/f0637.jpg',
#  'images/input/frames/f0638.jpg',
#  'images/input/frames/f0639.jpg',
#  'images/input/frames/f0640.jpg',
#  'images/input/frames/f0641.jpg',
#  'images/input/frames/f0642.jpg',
#  'images/input/frames/f0643.jpg',
#  'images/input/frames/f0644.jpg',
#  'images/input/frames/f0645.jpg',
#  'images/input/frames/f0646.jpg',
#  'images/input/frames/f0647.jpg',
#  'images/input/frames/f0648.jpg',
#  'images/input/frames/f0649.jpg',
#  'images/input/frames/f0650.jpg',
#  'images/input/frames/f0651.jpg',
#  'images/input/frames/f0652.jpg',
#  'images/input/frames/f0653.jpg',
#  'images/input/frames/f0654.jpg',
#  'images/input/frames/f0655.jpg',
#  'images/input/frames/f0656.jpg',
#  'images/input/frames/f0657.jpg',
#  'images/input/frames/f0658.jpg',
#  'images/input/frames/f0659.jpg',
#  'images/input/frames/f0660.jpg',
#  'images/input/frames/f0661.jpg',
#  'images/input/frames/f0662.jpg',
#  'images/input/frames/f0663.jpg',
#  'images/input/frames/f0664.jpg',
#  'images/input/frames/f0665.jpg',
#  'images/input/frames/f0666.jpg',
#  'images/input/frames/f0667.jpg',
#  'images/input/frames/f0668.jpg',
#  'images/input/frames/f0669.jpg',
#  'images/input/frames/f0670.jpg',
#  'images/input/frames/f0671.jpg',
#  'images/input/frames/f0672.jpg',
#  'images/input/frames/f0673.jpg',
#  'images/input/frames/f0674.jpg',
#  'images/input/frames/f0675.jpg',
#  'images/input/frames/f0676.jpg',
#  'images/input/frames/f0677.jpg',
#  'images/input/frames/f0678.jpg',
#  'images/input/frames/f0679.jpg',
#  'images/input/frames/f0680.jpg',
#  'images/input/frames/f0681.jpg',
#  'images/input/frames/f0682.jpg',
#  'images/input/frames/f0683.jpg',
#  'images/input/frames/f0684.jpg',
#  'images/input/frames/f0685.jpg',
#  'images/input/frames/f0686.jpg',
#  'images/input/frames/f0687.jpg',
#  'images/input/frames/f0688.jpg',
#  'images/input/frames/f0689.jpg',
#  'images/input/frames/f0690.jpg',
#  'images/input/frames/f0691.jpg',
#  'images/input/frames/f0692.jpg',
#  'images/input/frames/f0693.jpg',
#  'images/input/frames/f0694.jpg',
#  'images/input/frames/f0695.jpg',
#  'images/input/frames/f0696.jpg',
#  'images/input/frames/f0697.jpg',
#  'images/input/frames/f0698.jpg',
#  'images/input/frames/f0699.jpg',
#  'images/input/frames/f0700.jpg',
#  'images/input/frames/f0701.jpg',
#  'images/input/frames/f0702.jpg',
#  'images/input/frames/f0703.jpg',
#  'images/input/frames/f0704.jpg',
#  'images/input/frames/f0705.jpg',
#  'images/input/frames/f0706.jpg',
#  'images/input/frames/f0707.jpg',
#  'images/input/frames/f0708.jpg',
#  'images/input/frames/f0709.jpg',
#  'images/input/frames/f0710.jpg',
#  'images/input/frames/f0711.jpg',
#  'images/input/frames/f0712.jpg',
#  'images/input/frames/f0713.jpg',
#  'images/input/frames/f0714.jpg',
#  'images/input/frames/f0715.jpg',
#  'images/input/frames/f0716.jpg',
#  'images/input/frames/f0717.jpg',
#  'images/input/frames/f0718.jpg',
#  'images/input/frames/f0719.jpg',
#  'images/input/frames/f0720.jpg',
#  'images/input/frames/f0721.jpg',
#  'images/input/frames/f0722.jpg',
#  'images/input/frames/f0723.jpg',
#  'images/input/frames/f0724.jpg',
#  'images/input/frames/f0725.jpg',
#  'images/input/frames/f0726.jpg',
#  'images/input/frames/f0727.jpg',
#  'images/input/frames/f0728.jpg',
#  'images/input/frames/f0729.jpg',
#  'images/input/frames/f0730.jpg',
#  'images/input/frames/f0731.jpg',
#  'images/input/frames/f0732.jpg',
#  'images/input/frames/f0733.jpg',
#  'images/input/frames/f0734.jpg',
#  'images/input/frames/f0735.jpg',
#  'images/input/frames/f0736.jpg',
#  'images/input/frames/f0737.jpg',
#  'images/input/frames/f0738.jpg',
#  'images/input/frames/f0739.jpg',
#  'images/input/frames/f0740.jpg',
#  'images/input/frames/f0741.jpg',
#  'images/input/frames/f0742.jpg',
#  'images/input/frames/f0743.jpg',
#  'images/input/frames/f0744.jpg',
#  'images/input/frames/f0745.jpg',
#  'images/input/frames/f0746.jpg',
#  'images/input/frames/f0747.jpg',
#  'images/input/frames/f0748.jpg',
#  'images/input/frames/f0749.jpg',
#  'images/input/frames/f0750.jpg',
#  'images/input/frames/f0751.jpg',
#  'images/input/frames/f0752.jpg',
#  'images/input/frames/f0753.jpg',
#  'images/input/frames/f0754.jpg',
#  'images/input/frames/f0755.jpg',
#  'images/input/frames/f0756.jpg',
#  'images/input/frames/f0757.jpg',
#  'images/input/frames/f0758.jpg',
#  'images/input/frames/f0759.jpg',
#  'images/input/frames/f0760.jpg',
#  'images/input/frames/f0761.jpg',
#  'images/input/frames/f0762.jpg',
#  'images/input/frames/f0763.jpg',
#  'images/input/frames/f0764.jpg',
#  'images/input/frames/f0765.jpg',
#  'images/input/frames/f0766.jpg',
#  'images/input/frames/f0767.jpg',
#  'images/input/frames/f0768.jpg',
#  'images/input/frames/f0769.jpg',
#  'images/input/frames/f0770.jpg',
#  'images/input/frames/f0771.jpg',
#  'images/input/frames/f0772.jpg',
#  'images/input/frames/f0773.jpg',
#  'images/input/frames/f0774.jpg',
#  'images/input/frames/f0775.jpg',
#  'images/input/frames/f0776.jpg',
#  'images/input/frames/f0777.jpg',
#  'images/input/frames/f0778.jpg',
#  'images/input/frames/f0779.jpg',
#  'images/input/frames/f0780.jpg',
#  'images/input/frames/f0781.jpg',
#  'images/input/frames/f0782.jpg',
#  'images/input/frames/f0783.jpg',
#  'images/input/frames/f0784.jpg',
#  'images/input/frames/f0785.jpg',
#  'images/input/frames/f0786.jpg',
#  'images/input/frames/f0787.jpg',
#  'images/input/frames/f0788.jpg',
#  'images/input/frames/f0789.jpg',
#  'images/input/frames/f0790.jpg',
#  'images/input/frames/f0791.jpg',
#  'images/input/frames/f0792.jpg',
#  'images/input/frames/f0793.jpg',
#  'images/input/frames/f0794.jpg',
#  'images/input/frames/f0795.jpg',
#  'images/input/frames/f0796.jpg',
#  'images/input/frames/f0797.jpg',
#  'images/input/frames/f0798.jpg',
#  'images/input/frames/f0799.jpg',
#  'images/input/frames/f0800.jpg',
#  'images/input/frames/f0801.jpg',
#  'images/input/frames/f0802.jpg',
#  'images/input/frames/f0803.jpg',
#  'images/input/frames/f0804.jpg',
#  'images/input/frames/f0805.jpg',
#  'images/input/frames/f0806.jpg',
#  'images/input/frames/f0807.jpg',
#  'images/input/frames/f0808.jpg',
#  'images/input/frames/f0809.jpg',
#  'images/input/frames/f0810.jpg',
#  'images/input/frames/f0811.jpg',
#  'images/input/frames/f0812.jpg',
#  'images/input/frames/f0813.jpg',
#  'images/input/frames/f0814.jpg',
#  'images/input/frames/f0815.jpg',
#  'images/input/frames/f0816.jpg',
#  'images/input/frames/f0817.jpg',
#  'images/input/frames/f0818.jpg',
#  'images/input/frames/f0819.jpg',
#  'images/input/frames/f0820.jpg',
#  'images/input/frames/f0821.jpg',
#  'images/input/frames/f0822.jpg',
#  'images/input/frames/f0823.jpg',
#  'images/input/frames/f0824.jpg',
#  'images/input/frames/f0825.jpg',
#  'images/input/frames/f0826.jpg',
#  'images/input/frames/f0827.jpg',
#  'images/input/frames/f0828.jpg',
#  'images/input/frames/f0829.jpg',
#  'images/input/frames/f0830.jpg',
#  'images/input/frames/f0831.jpg',
#  'images/input/frames/f0832.jpg',
#  'images/input/frames/f0833.jpg',
#  'images/input/frames/f0834.jpg',
#  'images/input/frames/f0835.jpg',
#  'images/input/frames/f0836.jpg',
#  'images/input/frames/f0837.jpg',
#  'images/input/frames/f0838.jpg',
#  'images/input/frames/f0839.jpg',
#  'images/input/frames/f0840.jpg',
#  'images/input/frames/f0841.jpg',
#  'images/input/frames/f0842.jpg',
#  'images/input/frames/f0843.jpg',
#  'images/input/frames/f0844.jpg',
#  'images/input/frames/f0845.jpg',
#  'images/input/frames/f0846.jpg',
#  'images/input/frames/f0847.jpg',
#  'images/input/frames/f0848.jpg',
#  'images/input/frames/f0849.jpg',
#  'images/input/frames/f0850.jpg',
#  'images/input/frames/f0851.jpg',
#  'images/input/frames/f0852.jpg',
#  'images/input/frames/f0853.jpg',
#  'images/input/frames/f0854.jpg',
#  'images/input/frames/f0855.jpg',
#  'images/input/frames/f0856.jpg',
#  'images/input/frames/f0857.jpg',
#  'images/input/frames/f0858.jpg',
#  'images/input/frames/f0859.jpg',
#  'images/input/frames/f0860.jpg',
#  'images/input/frames/f0861.jpg',
#  'images/input/frames/f0862.jpg',
#  'images/input/frames/f0863.jpg',
#  'images/input/frames/f0864.jpg',
#  'images/input/frames/f0865.jpg',
#  'images/input/frames/f0866.jpg',
#  'images/input/frames/f0867.jpg',
#  'images/input/frames/f0868.jpg',
#  'images/input/frames/f0869.jpg',
#  'images/input/frames/f0870.jpg',
#  'images/input/frames/f0871.jpg',
#  'images/input/frames/f0872.jpg',
#  'images/input/frames/f0873.jpg',
#  'images/input/frames/f0874.jpg',
#  'images/input/frames/f0875.jpg',
#  'images/input/frames/f0876.jpg',
#  'images/input/frames/f0877.jpg',
#  'images/input/frames/f0878.jpg',
#  'images/input/frames/f0879.jpg',
#  'images/input/frames/f0880.jpg',
#  'images/input/frames/f0881.jpg',
#  'images/input/frames/f0882.jpg',
#  'images/input/frames/f0883.jpg',
#  'images/input/frames/f0884.jpg',
#  'images/input/frames/f0885.jpg',
#  'images/input/frames/f0886.jpg',
#  'images/input/frames/f0887.jpg',
#  'images/input/frames/f0888.jpg',
#  'images/input/frames/f0889.jpg',
#  'images/input/frames/f0890.jpg',
#  'images/input/frames/f0891.jpg',
#  'images/input/frames/f0892.jpg',
#  'images/input/frames/f0893.jpg',
#  'images/input/frames/f0894.jpg',
#  'images/input/frames/f0895.jpg',
#  'images/input/frames/f0896.jpg',
#  'images/input/frames/f0897.jpg',
#  'images/input/frames/f0898.jpg',
#  'images/input/frames/f0899.jpg',
#  'images/input/frames/f0900.jpg']

# %%
frameCount = len(filenames)
frameHeight, frameWidth, frameChannels = cv2.imread(filenames[0]).shape
# rows, cols, 3 for a frame
frames = np.zeros((frameCount, frameHeight, frameWidth, frameChannels),dtype=np.float32)
# 900, rows, cols, 3 for all frames

# %%
# im2_cv2 = cv2.imread(im2_path)
# im2_RGB = cv2.cvtColor(im2_cv2,cv2.COLOR_BGR2RGB)
# im2_plt = im2_RGB.astype(np.float32)/255  !!! (value/255.0) instead of 255
for idx, file_i in enumerate(filenames):
    frames[idx] = cv2.cvtColor(cv2.imread(file_i), cv2.COLOR_BGR2RGB) / 255.0

# %%
def auto_homography(Ia,Ib, homography_func=None, normalization_func=None):
    '''
    Computes a homography that maps points from Ia to Ib

    Input: Ia and Ib are images
    Output: H is the homography

    '''
    if Ia.dtype == 'float32' and Ib.dtype == 'float32':
        Ia = (Ia*255).astype(np.uint8)
        Ib = (Ib*255).astype(np.uint8)
    
    Ia_gray = cv2.cvtColor(Ia,cv2.COLOR_BGR2GRAY)
    Ib_gray = cv2.cvtColor(Ib,cv2.COLOR_BGR2GRAY)

    # Initiate SIFT detector
    sift = cv2.xfeatures2d.SIFT_create()
    
    # find the keypoints and descriptors with SIFT
    # kp_a is keypoints List and des_a is descriptors List
    kp_a, des_a = sift.detectAndCompute(Ia_gray,None)
    kp_b, des_b = sift.detectAndCompute(Ib_gray,None)    
    
    # BFMatcher with default params
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(des_a,des_b, k=2)
#     print('---TEST values in matches, which is list of elements(a,b)---')
#     print(matches[0])
#     print(matches[0][0].distance)
#     print(matches[0][1].distance)
    
    # Apply ratio test
    good = []
    for m,n in matches:
        if m.distance < 0.75*n.distance:
            good.append(m)
    
    numMatches = int(len(good)) # numMatches = 215
    matches = good 
    
    # Xa and Xb are 3xN matrices that contain homogeneous coordinates for the N
    # matching points for each image
    Xa = np.ones((3,numMatches))
    Xb = np.ones((3,numMatches))
    
#     print('---TEST 3*215 point---')
#     print(Xa[:,0][0:2])
#     print(Xa[:,0])
    pts1_good = np.ones((3,4))
    pts2_good = np.ones((3,4))
    for idx, match_i in enumerate(matches):
        Xa[:,idx][0:2] = kp_a[match_i.queryIdx].pt
        Xb[:,idx][0:2] = kp_b[match_i.trainIdx].pt

    ## RANSAC
    niter = 1000
    best_score = 0
    
    H = np.zeros((3,3))
    for t in range(niter):
        # estimate homography
        subset = np.random.choice(numMatches, 4, replace=False)
        pts1 = Xa[:,subset]
        pts2 = Xb[:,subset]

        H_t = homography_func(pts1, pts2, normalization_func)
#         H_t = computeHomography(pts1, pts2) # edit helper code below (computeHomography)
        # pts1 = 3xN matrix and N = 4

        # score homography
        Xb_ = np.dot(H_t, Xa) # project points from first image to second using H
        du = Xb_[0,:]/Xb_[2,:] - Xb[0,:]/Xb[2,:]
        dv = Xb_[1,:]/Xb_[2,:] - Xb[1,:]/Xb[2,:]
        
        ok_t = np.sqrt(du**2 + dv**2) < 1  # you may need to play with this threshold
        score_t = sum(ok_t)

        if score_t > best_score:
            best_score = score_t
            H = H_t
            in_idx = ok_t
            pts1_good = pts1
            pts2_good = pts2
#     print(pts1_good)
#     print(pts2_good)
    print('best score: {:02f}'.format(best_score))
    
# # Check that your homography is correct by plotting four points that form a square in frame 270 
#     # use as the four corners to draw the polylines
#     con_pts1 = np.zeros((4,2),np.int32)
#     con_pts2 = np.zeros((4,2),np.int32)
    
#     for i in range (4):
# #         print("point %d Xa"%(i),pts1_good[:,i])
# #         print("point %d Xb"%(i),pts2_good[:,i])  
# #         Xb_ = np.dot(H, Xa)
# #         print("point %d Xb_"%(i),Xb_[:,i])
# #         print(Xb_[:,i]/Xb_[2,i])
#         con_pts1[i] = pts1_good[0:2,i]
#         con_pts2[i] = pts2_good[0:2,i]
# #         print(con_pts1[i])
# #         print(con_pts2[i])
# #     A[[i, j], :] = A[[j, i], :] # 实现了第i行与第j行的互换
#     im1_RGB2 = cv2.cvtColor(Ia,cv2.COLOR_BGR2RGB)
#     im2_RGB2 = cv2.cvtColor(Ib,cv2.COLOR_BGR2RGB)
#     con_pts1[[0, 2], :] = con_pts1[[2, 0], :]
#     con_pts2[[0, 2], :] = con_pts2[[2, 0], :]
    
# #   for draw rectangular  im1_RGB2 = cv2.rectangle(im1_RGB2,(100,100),(200,200),(255,0,0),3)
# #     pts = np.array([[10,5],[20,30],[70,20],[50,10]], np.int32)
#     con_pts1 = con_pts1.reshape((-1,1,2))
#     con_pts2 = con_pts2.reshape((-1,1,2))
# #     print("--------")
# #     print(con_pts1)
# #     print(con_pts2)
#     im1_RGB2 = cv2.polylines(im1_RGB2,[con_pts1],True,(255,0,0),thickness = 2,lineType = 8)
#     im2_RGB2 = cv2.polylines(im2_RGB2,[con_pts2],True,(255,0,0),thickness = 2,lineType = 8)
    
#     plt.imshow(im1_RGB2)
#     plt.show()
    
#     plt.imshow(im2_RGB2)
#     plt.show()
    
#     # Optionally, you may want to re-estimate H based on inliers

    return H

# %%
def computeHomography(pts1, pts2, normalization_func=None):
    '''
    Compute homography that maps from pts1 to pts2 using least squares solver
     
    Input: pts1 and pts2 are 3xN matrices for N points in homogeneous
    coordinates.  N is 4.
    
    Output: H is a 3x3 matrix, such that pts2~=H*pts1
    '''
    
    dimen, num = pts1.shape
    A = np.zeros((2*num, 9), dtype = np.float32)
    
    for i in range (0, num):
        # p_prime = w*[u_prime,v_prime,1]
        # p = [u,v,1]
        p_prime = pts2[:,i]
        u_prime = p_prime[0]/p_prime[2]
        v_prime = p_prime[1]/p_prime[2]
        
        p = pts1[:,i]
        u = p[0]/p[2]
        v = p[1]/p[2]
        A[i*2,:] = [-u,-v,-1,0,0,0,u*u_prime, v*u_prime, u_prime]
        A[i*2+1,:] = [0,0,0,-u,-v,-1,u*v_prime, v*v_prime, v_prime]
    U,S,Vt = svd(A)
    h = Vt[-1,:]
    H = np.reshape(h, (3, 3))
    
#     std1_u = np.std(pts1[1,:])
#     std1_v =  np.std(pts1[2,:])
#     mean1_u = np.mean(pts1[1,:])
#     mean1_v = np.mean(pts1[2,:]) 
#     T1 = np.matrix([[1/std1_u, 0, 0],[0, 1/std1_v, 0],[0, 0, 1]]) * np.matrix([[1,0,-mean1_u],[0,1,-mean1_v],[0,0,1]])
    
#     std2_u = np.std(pts2[1,:])
#     std2_v = np.std(pts2[2,:])
#     mean2_u = np.mean(pts2[1,:])
#     mean2_v = np.mean(pts2[2,:]) 
#     T2 = np.matrix([[1/std2_u, 0, 0],[0, 1/std2_v, 0],[0, 0, 1]]) * np.matrix([[1,0,-mean2_u],[0,1,-mean2_v],[0,0,1]])
#     H = T2/H_n * T1
    return H

# %%
def projectImage(frames, sourceFrameIndex, referenceFrameIndex,
                 pastHomographies, originTranslations, xrange=2000,
                 yrange=800, overlapThreshold=40000, errorThreshold=4e-4,
                 numKeyframes=3, checkAllKeyframes=0, auto_H_func=None,
                 homography_func=None, normalization_func=None):
    '''
    Input:
        - frames: 4D array of frames
        - sourceFrameIndex: index of the frame to be projected
        - referenceFrameIndex: index of the frame to be projected to
        - pastHomographies: 2D cell array caching previously computed
          homographies from every frame to every other frame
        - xrange, yrange: dimensions of the output image
        - overlapThreshold: sufficient number of pixels overlapping between
          projected source and reference frames to ensure good homography
        - errorThreshold: acceptable error for good homography
        - numKeyframes: number of equidistant keyframes between source and
          reference frame to be visited in search of better homography
        - checkAllKeyframes: 0 if algorithms breaks after first better
          homography is found, 1 if all keyframes are to be visited

    Output:
        - bestProjectedImage: source frame optimally projected onto reference
          frame using reestimation of homography based on closest-frame search
          and using closest-frame homography as
    '''
        # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    H_transition = np.identity(3)
    H_transition[0,2] = 400 #cols
    H_transition[1,2] = yrange/2-180 #rows
#     360 * 480
    print("once")
    numFrames = frames.shape[0]
    _, referenceTransform, ref_origin_coord = transformImage(frames, referenceFrameIndex, referenceFrameIndex, pastHomographies, xrange, yrange, auto_H_func, homography_func, normalization_func)
    _, sourceTransform, src_origin_coord = transformImage(frames, sourceFrameIndex, referenceFrameIndex, pastHomographies, xrange, yrange, auto_H_func, homography_func, normalization_func)
    _, err = computeOverlap(sourceTransform, src_origin_coord, referenceTransform, ref_origin_coord, overlapThreshold)
    originTranslations[sourceFrameIndex] = src_origin_coord
    
    
    x_min, y_min = originTranslations[0]
    # Translation matrix
    t = [-x_min, -y_min]
    H_t = np.array([[1, 0, t[0]], [0, 1, t[1]], [0, 0, 1]], dtype=np.float32)
    # Dot product of translation matrix and homography
    pastHomographies[sourceFrameIndex, referenceFrameIndex] = H_t.dot(pastHomographies[sourceFrameIndex, referenceFrameIndex])

#     projectedImage = cv2.warpPerspective((frames[sourceFrameIndex]*255).astype(np.uint8),
#                                          pastHomographies[sourceFrameIndex, referenceFrameIndex],
#                                          (xrange, yrange))
    projectedImage = cv2.warpPerspective((frames[sourceFrameIndex]*255).astype(np.uint8),
                                         H_transition.dot(pastHomographies[sourceFrameIndex, referenceFrameIndex]),
                                         (xrange, yrange))
   

    
    if err > errorThreshold:
        print('Finding better homography...')
        increment = floor(((referenceFrameIndex - sourceFrameIndex) - 1) / (numKeyframes + 1))
        keyframeIndex = sourceFrameIndex + increment  # frame being used to find better homography from source to reference
        found = 0
        counter = 0
        bestHomography = np.eye(3)  # initialize H as identity

        while counter < numKeyframes and keyframeIndex < numFrames and keyframeIndex > 0:

            # compute homography and projected image from keyframe to
            # reference frame
            H2, keyframeTransform, keyframe_origin_coord = transformImage(frames, keyframeIndex, referenceFrameIndex, pastHomographies, xrange, yrange, auto_H_func, homography_func, normalization_func)
            a, error1 = computeOverlap(keyframeTransform, keyframe_origin_coord, referenceTransform, ref_origin_coord, overlapThreshold)

            # compute homography and projected image from source frame to
            # keyframe (new reference = keyframe)
            _, keyframeToKeyframeTransform, keyframeToKeyframe_origin_coord = transformImage(frames, keyframeIndex, keyframeIndex, pastHomographies, xrange, yrange,  auto_H_func, homography_func, normalization_func)
            H1, sourceToKeyframeTransform, srcToKeyframe_origin_coord = transformImage(frames, sourceFrameIndex, keyframeIndex, pastHomographies, xrange, yrange,  auto_H_func, homography_func, normalization_func)
            b, error2 = computeOverlap(sourceToKeyframeTransform, srcToKeyframe_origin_coord, keyframeToKeyframeTransform, keyframeToKeyframe_origin_coord, overlapThreshold)

            sufficientOverlap = (a and b)

            if (sufficientOverlap and max(error1, error2) < err):
                found = 1
                bestHomography = np.dot(H1, H2)
                src_origin_coord = keyframe_origin_coord + srcToKeyframe_origin_coord
                if not checkAllKeyframes:
                    break

            keyframeIndex = keyframeIndex + increment
            counter = counter + 1

        if found:
            print('Found better homography')
            pastHomographies[sourceFrameIndex, referenceFrameIndex] = bestHomography
            originTranslations[sourceFrameIndex] = src_origin_coord
            min_origin_coord = np.amin(originTranslations, axis=0)

            x_min, y_min = originTranslations[0]
            # Translation matrix
            t = [-x_min, -y_min]
            H_t = np.array([[1, 0, t[0]], [0, 1, t[1]], [0, 0, 1]], dtype=np.float32)

            # Dot product of translation matrix and homography
            T = H_t.dot(bestHomography)
            
#             projectedImage = cv2.warpPerspective((frames[sourceFrameIndex]*255).astype(np.uint8), T, (xrange, yrange))

            projectedImage = cv2.warpPerspective((frames[sourceFrameIndex]*255).astype(np.uint8), np.dot(H_transition,T), (xrange, yrange))

            pastHomographies[sourceFrameIndex, referenceFrameIndex] = T.astype(np.float32)
    
    return projectedImage, pastHomographies, originTranslations

# %%
## Example usage of utils.projectImage

pastHomographies = np.zeros((len(filenames),len(filenames), 3, 3),dtype=np.float32)
# 900*900*(3*3) H13 = pastHomographies[1,3]
originTranslations = np.zeros((len(filenames), 2), dtype=np.float32)
# store the current homographies
# sourceFrameIndex = 630
# referenceFrameIndex = 450

# %%
from utils import transformImage, computeOverlap

# %%
# frameCount = len(filenames)
# frameHeight, frameWidth, frameChannels = cv2.imread(filenames[0]).shape
# # rows, cols, 3 for a frame
# frames = np.zeros((frameCount, frameHeight, frameWidth, frameChannels),dtype=np.float32)
# # 900, rows, cols, 3 for all frames

# idx start from 0
# for idx, file_i in enumerate(filenames):
#     frames[idx] = cv2.cvtColor(cv2.imread(file_i), cv2.COLOR_BGR2RGB) / 255.0

pastHomographies = np.zeros((len(filenames),len(filenames), 3, 3),dtype=np.float32)
# 900*900*(3*3) H13 = pastHomographies[1,3]
originTranslations = np.zeros((len(filenames), 2),dtype=np.float32)

# %%
# blendOutput_images = np.zeros((900,800,2000,3))
# 900 * rows * cols * 3
master_frames =[x for x in range (0,len(filenames))]

reference_frame = 450
referenceFrameIndex = master_frames.index(reference_frame)
print(referenceFrameIndex)

projectedSource, pastHomographies, originTranslations = projectImage(frames, referenceFrameIndex, referenceFrameIndex,
                                                            pastHomographies, originTranslations,
                                                            auto_H_func=auto_homography, homography_func=computeHomography)

H_transition = np.identity(3)
H_transition[0,2] = 400 #cols
H_transition[1,2] = 800/2-180 #rows
# H = np.identity(3)
# projectedSource = cv2.warpPerspective((frames[450]*255).astype(np.uint8), np.dot(H_transition, H), (cols, rows))
projectedSource = cv2.cvtColor(projectedSource,cv2.COLOR_RGB2BGR)
cv2.imwrite('images/input/aligned_frames/a{:04d}.jpg'.format(referenceFrameIndex), projectedSource)
print('------frame{:04d} have been written------'.format(450))
# blendOutput_images[referenceFrameIndex] = projectedSource

for i in range(0,499):
    sourceFrameIndex = master_frames[i]
    
    projectedSource, pastHomographies, originTranslations = projectImage(frames, sourceFrameIndex, referenceFrameIndex,
                                                            pastHomographies, originTranslations,
                                                            auto_H_func=auto_homography, homography_func=computeHomography)
    projectedSource = cv2.cvtColor(projectedSource,cv2.COLOR_RGB2BGR)
    cv2.imwrite('images/input/aligned_frames/a{:04d}.jpg'.format(i), projectedSource)
    print('------frame{:04d} have been written------'.format(i))
#     blendOutput_images[sourceFrameIndex] = projectedSource
    
for i in range(899,450,-1):
    print(i)
#     projectedSource = cv2.warpPerspective((frames[sourceFrameIndex]*255).astype(np.uint8),
#                                          H_transition.dot(auto_homography(frames[sourceFrameIndex],frames[450],computeHomography)),
#                                          (2000, 800))
    sourceFrameIndex = master_frames[i]

    projectedSource, pastHomographies, originTranslations = projectImage(frames, sourceFrameIndex, referenceFrameIndex,
                                                            pastHomographies, originTranslations,
                                                            auto_H_func=auto_homography, homography_func=computeHomography)
    projectedSource = cv2.cvtColor(projectedSource,cv2.COLOR_RGB2BGR)
    cv2.imwrite('images/input/aligned_frames/a{:04d}.jpg'.format(i), projectedSource)
    print('------frame{:04d} have been written------'.format(i))
#     blendOutput_images[sourceFrameIndex] = projectedSource
# Out:
# 450
# once
# best score: 2620.000000
# Overlap:169898
# Error:0.0
# ------frame0450 have been written------
# once
# best score: 31.000000
# Overlap:24320
# Error:0.0007329335635273897
# Finding better homography...
# best score: 64.000000
# Overlap:40964
# Error:0.0005239931365053894
# best score: 2735.000000
# best score: 243.000000
# Overlap:148129
# Error:0.0001853896652214096
# Found better homography
# ------frame0000 have been written------
# once
# best score: 28.000000
# Overlap:0
# Error:3.4028234663852886e+38
# Finding better homography...
# best score: 68.000000
# Overlap:40269
# Error:0.0005286348931498656
# best score: 2753.000000
# best score: 277.000000
# Overlap:147990
# Error:0.00018461976431996416
# Found better homography
# ------frame0001 have been written------
# once
# best score: 34.000000
# Overlap:24415
# Error:0.0007139659090422842
# Finding better homography...
# Overlap:40269
# Error:0.0005286348931498656
# best score: 278.000000
# Overlap:148610
# Error:0.0001844842632993747
# Found better homography
# ------frame0002 have been written------
# once
# best score: 41.000000
# Overlap:24370
# Error:0.0007130245582752456
# Finding better homography...
# best score: 72.000000
# Overlap:41306
# Error:0.0005286340469454671
# best score: 2693.000000
# best score: 288.000000
# Overlap:149075
# Error:0.00018678905247479039
# Found better homography
# ------frame0003 have been written------
# once
# best score: 37.000000
# Overlap:25252
# Error:0.0006976450438827255
# Finding better homography...
# best score: 66.000000
# Overlap:42386
# Error:0.0005117161158341157
# best score: 2781.000000
# best score: 348.000000
# Overlap:149016
# Error:0.00018250692401361018
# Found better homography
# ------frame0004 have been written------
# once
# best score: 39.000000
# Overlap:25945
# Error:0.0007078418707642039
# Finding better homography...
# best score: 59.000000
# Overlap:42911
# Error:0.0005245508434547867
# best score: 2657.000000
# best score: 291.000000
# Overlap:149340
# Error:0.00018362932357397823
# Found better homography
# ------frame0005 have been written------
# once
# best score: 31.000000
# Overlap:25370
# Error:0.0006994137960410535
# Finding better homography...
# Overlap:42911
# Error:0.0005245508434547867
# best score: 314.000000
# Overlap:149487
# Error:0.00018101909788328878
# Found better homography
# ------frame0006 have been written------
# once
# best score: 41.000000
# Overlap:25039
# Error:0.0007135759544526115
# Finding better homography...
# best score: 67.000000
# Overlap:42046
# Error:0.0005094202857706983
# best score: 2648.000000
# best score: 279.000000
# Overlap:150090
# Error:0.00017853977057022494
# Found better homography
# ------frame0007 have been written------
# once
# best score: 39.000000
# Overlap:25836
# Error:0.0007194194950237083
# Finding better homography...
# best score: 62.000000
# Overlap:42239
# Error:0.0005158022720726229
# best score: 2702.000000
# best score: 288.000000
# Overlap:149961
# Error:0.00017944174565289462
# Found better homography
# ------frame0008 have been written------
# once
# best score: 38.000000
# Overlap:26259
# Error:0.0006911088149296635
# Finding better homography...
# best score: 59.000000
# Overlap:42547
# Error:0.0005179375643690193
# best score: 2597.000000
# best score: 270.000000
# Overlap:149980
# Error:0.0001808495658204201
# Found better homography
# ------frame0009 have been written------
# once
# best score: 31.000000
# Overlap:28163
# Error:0.0007647548896921997
# Finding better homography...
# Overlap:42547
# Error:0.0005179375643690193
# best score: 273.000000
# Overlap:148191
# Error:0.00017885006741311248
# Found better homography
# ------frame0010 have been written------
# once
# best score: 37.000000
# Overlap:25571
# Error:0.0006934730273500585
# Finding better homography...
# best score: 63.000000
# Overlap:43378
# Error:0.000515996963807739
# best score: 2586.000000
# best score: 311.000000
# Overlap:146483
# Error:0.00018107845367992486
# Found better homography
# ------frame0011 have been written------
# once
# best score: 40.000000
# Overlap:25685
# Error:0.0006879486348236381
# Finding better homography...
# best score: 70.000000
# Overlap:42941
# Error:0.0005169645536004379
# best score: 2597.000000
# best score: 293.000000
# Overlap:146036
# Error:0.0001791435831820333
# Found better homography
# ------frame0012 have been written------
# once
# best score: 44.000000
# Overlap:26483
# Error:0.000693687627421219
# Finding better homography...
# best score: 61.000000
# Overlap:44769
# Error:0.0005173724075143928
# best score: 2609.000000
# best score: 291.000000
# Overlap:147783
# Error:0.00017992487855058033
# Found better homography
# ------frame0013 have been written------
# once
# best score: 43.000000
# Overlap:27477
# Error:0.0007247014666680588
# Finding better homography...
# Overlap:44769
# Error:0.0005173724075143928
# best score: 298.000000
# Overlap:148027
# Error:0.0001820706319798174
# Found better homography
# ------frame0014 have been written------
# once
# best score: 41.000000
# Overlap:27051
# Error:0.0007034594733719163
# Finding better homography...
# best score: 69.000000
# Overlap:43696
# Error:0.0005035971379700222
# best score: 2622.000000
# best score: 281.000000
# Overlap:148361
# Error:0.0001801681740250179
# Found better homography
# ------frame0015 have been written------
# once
# best score: 40.000000
# Overlap:27489
# Error:0.0007133462819393258
# Finding better homography...
# best score: 77.000000
# Overlap:42821
# Error:0.0005199674286420763
# best score: 2597.000000
# best score: 307.000000
# Overlap:148551
# Error:0.00017855353603686978
# Found better homography
# ------frame0016 have been written------
# once
# best score: 45.000000
# Overlap:26827
# Error:0.0007084744182289088
# Finding better homography...
# best score: 60.000000
# Overlap:43312
# Error:0.0005078847292590714
# best score: 2592.000000
# best score: 291.000000
# Overlap:149569
# Error:0.0001795218801770512
# Found better homography
# ------frame0017 have been written------
# once
# best score: 42.000000
# Overlap:27671
# Error:0.0007111269802614384
# Finding better homography...
# Overlap:43312
# Error:0.0005078847292590714
# best score: 290.000000
# Overlap:148624
# Error:0.00017585212965927864
# Found better homography
# ------frame0018 have been written------
# once
# best score: 50.000000
# Overlap:27094
# Error:0.0006884687227130829
# Finding better homography...
# best score: 59.000000
# Overlap:42496
# Error:0.0005139929878785047
# best score: 2613.000000
# best score: 269.000000
# Overlap:149923
# Error:0.00018336847218013958
# Found better homography
# ------frame0019 have been written------
# once
# best score: 44.000000
# Overlap:28017
# Error:0.0007441190638121901
# Finding better homography...
# best score: 63.000000
# Overlap:43580
# Error:0.0005036956854716294
# best score: 2623.000000
# best score: 342.000000
# Overlap:149117
# Error:0.00017680077155814736
# Found better homography
# ------frame0020 have been written------
# once
# best score: 41.000000
# Overlap:27283
# Error:0.0007118577794277983
# Finding better homography...
# best score: 71.000000
# Overlap:43257
# Error:0.0005031987950808754
# best score: 2624.000000
# best score: 283.000000
# Overlap:149955
# Error:0.00017940786265359163
# Found better homography
# ------frame0021 have been written------
# once
# best score: 40.000000
# Overlap:27073
# Error:0.0007334397756029057
# Finding better homography...
# Overlap:43257
# Error:0.0005031987950808754
# best score: 296.000000
# Overlap:149837
# Error:0.00017790134690530594
# Found better homography
# ------frame0022 have been written------
# once
# best score: 45.000000
# Overlap:26486
# Error:0.000737482940154223
# Finding better homography...
# best score: 59.000000
# Overlap:43508
# Error:0.0005015167146618949
# best score: 2599.000000
# best score: 249.000000
# Overlap:149499
# Error:0.00018113103395966758
# Found better homography
# ------frame0023 have been written------
# once
# best score: 37.000000
# Overlap:26930
# Error:0.00074316708311323
# Finding better homography...
# best score: 69.000000
# Overlap:44324
# Error:0.0004880268761754164
# best score: 2575.000000
# best score: 277.000000
# Overlap:149715
# Error:0.00017946717982638758
# Found better homography
# ------frame0024 have been written------
# once
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-05667dd37d8e> in <module>()
#      26     projectedSource, pastHomographies, originTranslations = projectImage(frames, sourceFrameIndex, referenceFrameIndex,
#      27                                                             pastHomographies, originTranslations,
# ---> 28                                                             auto_H_func=auto_homography, homography_func=computeHomography)
#      29     projectedSource = cv2.cvtColor(projectedSource,cv2.COLOR_RGB2BGR)
#      30     cv2.imwrite('images/input/aligned_frames/a{:04d}.jpg'.format(i), projectedSource)
#
# <ipython-input-20-2f0b1af41cef> in projectImage(frames, sourceFrameIndex, referenceFrameIndex, pastHomographies, originTranslations, xrange, yrange, overlapThreshold, errorThreshold, numKeyframes, checkAllKeyframes, auto_H_func, homography_func, normalization_func)
#      33     numFrames = frames.shape[0]
#      34     _, referenceTransform, ref_origin_coord = transformImage(frames, referenceFrameIndex, referenceFrameIndex, pastHomographies, xrange, yrange, auto_H_func, homography_func, normalization_func)
# ---> 35     _, sourceTransform, src_origin_coord = transformImage(frames, sourceFrameIndex, referenceFrameIndex, pastHomographies, xrange, yrange, auto_H_func, homography_func, normalization_func)
#      36     _, err = computeOverlap(sourceTransform, src_origin_coord, referenceTransform, ref_origin_coord, overlapThreshold)
#      37     originTranslations[sourceFrameIndex] = src_origin_coord
#
# ~/Desktop/CS 445/CS445_proj5/Project 5/jieting2_proj5/utils.py in transformImage(frames, sourceFrameIndex, referenceFrameIndex, pastHomographies, xrange, yrange, auto_H_func, homography_func, normalization_func)
#     178     else:
#     179         homography = auto_H_func(frames[sourceFrameIndex], frames[referenceFrameIndex],
# --> 180                                  homography_func, normalization_func)
#     181         pastHomographies[sourceFrameIndex, referenceFrameIndex] = homography.astype(np.float32)
#     182
#
# <ipython-input-18-f079c1a0be6d> in auto_homography(Ia, Ib, homography_func, normalization_func)
#      20     # kp_a is keypoints List and des_a is descriptors List
#      21     kp_a, des_a = sift.detectAndCompute(Ia_gray,None)
# ---> 22     kp_b, des_b = sift.detectAndCompute(Ib_gray,None)
#      23
#      24     # BFMatcher with default params
#
# KeyboardInterrupt:

# %%
utils.imageFolder2mpeg('./images/input/aligned_frames_100',output_path='./images/input/output_video_result100.mpeg', fps=30.0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-525fea9713cf> in <module>()
# ----> 1 utils.imageFolder2mpeg('./images/input/aligned_frames_2',output_path='./images/input/output_video_result.mpeg', fps=30.0)
#
# ~/Desktop/CS 445/CS445_proj5/Project 5/jieting2_proj5/utils.py in imageFolder2mpeg(input_path, output_path, fps)
#     290
#     291     dir_frames = input_path
# --> 292     files_info = os.scandir(dir_frames)
#     293
#     294     file_names = [f.path for f in files_info if f.name.endswith(".jpg")]
#
# FileNotFoundError: [Errno 2] No such file or directory: './images/input/aligned_frames_2'

# %%
# im2_cv2 = cv2.imread(im2_path)
# im2_RGB = cv2.cvtColor(im2_cv2,cv2.COLOR_BGR2RGB)
# im2_plt = im2_RGB.astype(np.float32)/255  !!! (value/255.0) instead of 255
# for idx, file_i in enumerate(filenames):
#     frames[idx] = cv2.cvtColor(cv2.imread(file_i), cv2.COLOR_BGR2RGB) / 255.0

# %% [markdown]
# ### Part 4: Create background panorama
#
# In this part you will remove moving objects from the video and create a background panorama that should incorporate pixels from all the frames.
#
# In the video you produced in __part 3__ each pixel appears in several frames. You need to estimate which of the many colors correspond to the background. We take advantage of the fact that the background color is fixed while the foreground color changes frequently (because foreground moves).
#
# <img src="images/project_5/background.jpg" alt="Drawing" style="float: center; width: 500px"/>
#
#
# For each pixel in the sequence of __part 3__, determine all valid colors (colors that come from all frames that overlap that pixel). You can experiment with different methods for determining the background color of each pixel, as discussed in class. Perform the same procedure for all pixels and generate output. The output should be a completed panorama showing only pixels of background or non-moving objects.

# %%
import utils
import cv2
import numpy as np
from numpy.linalg import svd, inv

# %matplotlib inline
from matplotlib import pyplot as plt
import os

from math import floor

# import utils

# %%
#  read files from the wrapped images
dir_frames_transfered = 'images/input/frames_transfered'
wrapped_imgs = []
filesinfo_transfered = os.scandir(dir_frames_transfered)
filesinfo_transfered

# %%
filenames_transfered = [f.path for f in filesinfo_transfered if f.name.endswith(".jpg")]
filenames_transfered.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
filenames_transfered
# Out:
# ['images/input/frames_transfered/a0000.jpg',
#  'images/input/frames_transfered/a0001.jpg',
#  'images/input/frames_transfered/a0002.jpg',
#  'images/input/frames_transfered/a0003.jpg',
#  'images/input/frames_transfered/a0004.jpg',
#  'images/input/frames_transfered/a0005.jpg',
#  'images/input/frames_transfered/a0006.jpg',
#  'images/input/frames_transfered/a0007.jpg',
#  'images/input/frames_transfered/a0008.jpg',
#  'images/input/frames_transfered/a0009.jpg',
#  'images/input/frames_transfered/a0010.jpg',
#  'images/input/frames_transfered/a0011.jpg',
#  'images/input/frames_transfered/a0012.jpg',
#  'images/input/frames_transfered/a0013.jpg',
#  'images/input/frames_transfered/a0014.jpg',
#  'images/input/frames_transfered/a0015.jpg',
#  'images/input/frames_transfered/a0016.jpg',
#  'images/input/frames_transfered/a0017.jpg',
#  'images/input/frames_transfered/a0018.jpg',
#  'images/input/frames_transfered/a0019.jpg',
#  'images/input/frames_transfered/a0020.jpg',
#  'images/input/frames_transfered/a0021.jpg',
#  'images/input/frames_transfered/a0022.jpg',
#  'images/input/frames_transfered/a0023.jpg',
#  'images/input/frames_transfered/a0024.jpg',
#  'images/input/frames_transfered/a0025.jpg',
#  'images/input/frames_transfered/a0026.jpg',
#  'images/input/frames_transfered/a0027.jpg',
#  'images/input/frames_transfered/a0028.jpg',
#  'images/input/frames_transfered/a0029.jpg',
#  'images/input/frames_transfered/a0030.jpg',
#  'images/input/frames_transfered/a0031.jpg',
#  'images/input/frames_transfered/a0032.jpg',
#  'images/input/frames_transfered/a0033.jpg',
#  'images/input/frames_transfered/a0034.jpg',
#  'images/input/frames_transfered/a0035.jpg',
#  'images/input/frames_transfered/a0036.jpg',
#  'images/input/frames_transfered/a0037.jpg',
#  'images/input/frames_transfered/a0038.jpg',
#  'images/input/frames_transfered/a0039.jpg',
#  'images/input/frames_transfered/a0040.jpg',
#  'images/input/frames_transfered/a0041.jpg',
#  'images/input/frames_transfered/a0042.jpg',
#  'images/input/frames_transfered/a0043.jpg',
#  'images/input/frames_transfered/a0044.jpg',
#  'images/input/frames_transfered/a0045.jpg',
#  'images/input/frames_transfered/a0046.jpg',
#  'images/input/frames_transfered/a0047.jpg',
#  'images/input/frames_transfered/a0048.jpg',
#  'images/input/frames_transfered/a0049.jpg',
#  'images/input/frames_transfered/a0050.jpg',
#  'images/input/frames_transfered/a0051.jpg',
#  'images/input/frames_transfered/a0052.jpg',
#  'images/input/frames_transfered/a0053.jpg',
#  'images/input/frames_transfered/a0054.jpg',
#  'images/input/frames_transfered/a0055.jpg',
#  'images/input/frames_transfered/a0056.jpg',
#  'images/input/frames_transfered/a0057.jpg',
#  'images/input/frames_transfered/a0058.jpg',
#  'images/input/frames_transfered/a0059.jpg',
#  'images/input/frames_transfered/a0060.jpg',
#  'images/input/frames_transfered/a0061.jpg',
#  'images/input/frames_transfered/a0062.jpg',
#  'images/input/frames_transfered/a0063.jpg',
#  'images/input/frames_transfered/a0064.jpg',
#  'images/input/frames_transfered/a0065.jpg',
#  'images/input/frames_transfered/a0066.jpg',
#  'images/input/frames_transfered/a0067.jpg',
#  'images/input/frames_transfered/a0068.jpg',
#  'images/input/frames_transfered/a0069.jpg',
#  'images/input/frames_transfered/a0070.jpg',
#  'images/input/frames_transfered/a0071.jpg',
#  'images/input/frames_transfered/a0072.jpg',
#  'images/input/frames_transfered/a0073.jpg',
#  'images/input/frames_transfered/a0074.jpg',
#  'images/input/frames_transfered/a0075.jpg',
#  'images/input/frames_transfered/a0076.jpg',
#  'images/input/frames_transfered/a0077.jpg',
#  'images/input/frames_transfered/a0078.jpg',
#  'images/input/frames_transfered/a0079.jpg',
#  'images/input/frames_transfered/a0080.jpg',
#  'images/input/frames_transfered/a0081.jpg',
#  'images/input/frames_transfered/a0082.jpg',
#  'images/input/frames_transfered/a0083.jpg',
#  'images/input/frames_transfered/a0084.jpg',
#  'images/input/frames_transfered/a0085.jpg',
#  'images/input/frames_transfered/a0086.jpg',
#  'images/input/frames_transfered/a0087.jpg',
#  'images/input/frames_transfered/a0088.jpg',
#  'images/input/frames_transfered/a0089.jpg',
#  'images/input/frames_transfered/a0090.jpg',
#  'images/input/frames_transfered/a0091.jpg',
#  'images/input/frames_transfered/a0092.jpg',
#  'images/input/frames_transfered/a0093.jpg',
#  'images/input/frames_transfered/a0094.jpg',
#  'images/input/frames_transfered/a0095.jpg',
#  'images/input/frames_transfered/a0096.jpg',
#  'images/input/frames_transfered/a0097.jpg',
#  'images/input/frames_transfered/a0098.jpg',
#  'images/input/frames_transfered/a0099.jpg',
#  'images/input/frames_transfered/a0100.jpg',
#  'images/input/frames_transfered/a0101.jpg',
#  'images/input/frames_transfered/a0102.jpg',
#  'images/input/frames_transfered/a0103.jpg',
#  'images/input/frames_transfered/a0104.jpg',
#  'images/input/frames_transfered/a0105.jpg',
#  'images/input/frames_transfered/a0106.jpg',
#  'images/input/frames_transfered/a0107.jpg',
#  'images/input/frames_transfered/a0108.jpg',
#  'images/input/frames_transfered/a0109.jpg',
#  'images/input/frames_transfered/a0110.jpg',
#  'images/input/frames_transfered/a0111.jpg',
#  'images/input/frames_transfered/a0112.jpg',
#  'images/input/frames_transfered/a0113.jpg',
#  'images/input/frames_transfered/a0114.jpg',
#  'images/input/frames_transfered/a0115.jpg',
#  'images/input/frames_transfered/a0116.jpg',
#  'images/input/frames_transfered/a0117.jpg',
#  'images/input/frames_transfered/a0118.jpg',
#  'images/input/frames_transfered/a0119.jpg',
#  'images/input/frames_transfered/a0120.jpg',
#  'images/input/frames_transfered/a0121.jpg',
#  'images/input/frames_transfered/a0122.jpg',
#  'images/input/frames_transfered/a0123.jpg',
#  'images/input/frames_transfered/a0124.jpg',
#  'images/input/frames_transfered/a0125.jpg',
#  'images/input/frames_transfered/a0126.jpg',
#  'images/input/frames_transfered/a0127.jpg',
#  'images/input/frames_transfered/a0128.jpg',
#  'images/input/frames_transfered/a0129.jpg',
#  'images/input/frames_transfered/a0130.jpg',
#  'images/input/frames_transfered/a0131.jpg',
#  'images/input/frames_transfered/a0132.jpg',
#  'images/input/frames_transfered/a0133.jpg',
#  'images/input/frames_transfered/a0134.jpg',
#  'images/input/frames_transfered/a0135.jpg',
#  'images/input/frames_transfered/a0136.jpg',
#  'images/input/frames_transfered/a0137.jpg',
#  'images/input/frames_transfered/a0138.jpg',
#  'images/input/frames_transfered/a0139.jpg',
#  'images/input/frames_transfered/a0140.jpg',
#  'images/input/frames_transfered/a0141.jpg',
#  'images/input/frames_transfered/a0142.jpg',
#  'images/input/frames_transfered/a0143.jpg',
#  'images/input/frames_transfered/a0144.jpg',
#  'images/input/frames_transfered/a0145.jpg',
#  'images/input/frames_transfered/a0146.jpg',
#  'images/input/frames_transfered/a0147.jpg',
#  'images/input/frames_transfered/a0148.jpg',
#  'images/input/frames_transfered/a0149.jpg',
#  'images/input/frames_transfered/a0150.jpg',
#  'images/input/frames_transfered/a0151.jpg',
#  'images/input/frames_transfered/a0152.jpg',
#  'images/input/frames_transfered/a0153.jpg',
#  'images/input/frames_transfered/a0154.jpg',
#  'images/input/frames_transfered/a0155.jpg',
#  'images/input/frames_transfered/a0156.jpg',
#  'images/input/frames_transfered/a0157.jpg',
#  'images/input/frames_transfered/a0158.jpg',
#  'images/input/frames_transfered/a0159.jpg',
#  'images/input/frames_transfered/a0160.jpg',
#  'images/input/frames_transfered/a0161.jpg',
#  'images/input/frames_transfered/a0162.jpg',
#  'images/input/frames_transfered/a0163.jpg',
#  'images/input/frames_transfered/a0164.jpg',
#  'images/input/frames_transfered/a0165.jpg',
#  'images/input/frames_transfered/a0166.jpg',
#  'images/input/frames_transfered/a0167.jpg',
#  'images/input/frames_transfered/a0168.jpg',
#  'images/input/frames_transfered/a0169.jpg',
#  'images/input/frames_transfered/a0170.jpg',
#  'images/input/frames_transfered/a0171.jpg',
#  'images/input/frames_transfered/a0172.jpg',
#  'images/input/frames_transfered/a0173.jpg',
#  'images/input/frames_transfered/a0174.jpg',
#  'images/input/frames_transfered/a0175.jpg',
#  'images/input/frames_transfered/a0176.jpg',
#  'images/input/frames_transfered/a0177.jpg',
#  'images/input/frames_transfered/a0178.jpg',
#  'images/input/frames_transfered/a0179.jpg',
#  'images/input/frames_transfered/a0180.jpg',
#  'images/input/frames_transfered/a0181.jpg',
#  'images/input/frames_transfered/a0182.jpg',
#  'images/input/frames_transfered/a0183.jpg',
#  'images/input/frames_transfered/a0184.jpg',
#  'images/input/frames_transfered/a0185.jpg',
#  'images/input/frames_transfered/a0186.jpg',
#  'images/input/frames_transfered/a0187.jpg',
#  'images/input/frames_transfered/a0188.jpg',
#  'images/input/frames_transfered/a0189.jpg',
#  'images/input/frames_transfered/a0190.jpg',
#  'images/input/frames_transfered/a0191.jpg',
#  'images/input/frames_transfered/a0192.jpg',
#  'images/input/frames_transfered/a0193.jpg',
#  'images/input/frames_transfered/a0194.jpg',
#  'images/input/frames_transfered/a0195.jpg',
#  'images/input/frames_transfered/a0196.jpg',
#  'images/input/frames_transfered/a0197.jpg',
#  'images/input/frames_transfered/a0198.jpg',
#  'images/input/frames_transfered/a0199.jpg',
#  'images/input/frames_transfered/a0200.jpg',
#  'images/input/frames_transfered/a0201.jpg',
#  'images/input/frames_transfered/a0202.jpg',
#  'images/input/frames_transfered/a0203.jpg',
#  'images/input/frames_transfered/a0204.jpg',
#  'images/input/frames_transfered/a0205.jpg',
#  'images/input/frames_transfered/a0206.jpg',
#  'images/input/frames_transfered/a0207.jpg',
#  'images/input/frames_transfered/a0208.jpg',
#  'images/input/frames_transfered/a0209.jpg',
#  'images/input/frames_transfered/a0210.jpg',
#  'images/input/frames_transfered/a0211.jpg',
#  'images/input/frames_transfered/a0212.jpg',
#  'images/input/frames_transfered/a0213.jpg',
#  'images/input/frames_transfered/a0214.jpg',
#  'images/input/frames_transfered/a0215.jpg',
#  'images/input/frames_transfered/a0216.jpg',
#  'images/input/frames_transfered/a0217.jpg',
#  'images/input/frames_transfered/a0218.jpg',
#  'images/input/frames_transfered/a0219.jpg',
#  'images/input/frames_transfered/a0220.jpg',
#  'images/input/frames_transfered/a0221.jpg',
#  'images/input/frames_transfered/a0222.jpg',
#  'images/input/frames_transfered/a0223.jpg',
#  'images/input/frames_transfered/a0224.jpg',
#  'images/input/frames_transfered/a0225.jpg',
#  'images/input/frames_transfered/a0226.jpg',
#  'images/input/frames_transfered/a0227.jpg',
#  'images/input/frames_transfered/a0228.jpg',
#  'images/input/frames_transfered/a0229.jpg',
#  'images/input/frames_transfered/a0230.jpg',
#  'images/input/frames_transfered/a0231.jpg',
#  'images/input/frames_transfered/a0232.jpg',
#  'images/input/frames_transfered/a0233.jpg',
#  'images/input/frames_transfered/a0234.jpg',
#  'images/input/frames_transfered/a0235.jpg',
#  'images/input/frames_transfered/a0236.jpg',
#  'images/input/frames_transfered/a0237.jpg',
#  'images/input/frames_transfered/a0238.jpg',
#  'images/input/frames_transfered/a0239.jpg',
#  'images/input/frames_transfered/a0240.jpg',
#  'images/input/frames_transfered/a0241.jpg',
#  'images/input/frames_transfered/a0242.jpg',
#  'images/input/frames_transfered/a0243.jpg',
#  'images/input/frames_transfered/a0244.jpg',
#  'images/input/frames_transfered/a0245.jpg',
#  'images/input/frames_transfered/a0246.jpg',
#  'images/input/frames_transfered/a0247.jpg',
#  'images/input/frames_transfered/a0248.jpg',
#  'images/input/frames_transfered/a0249.jpg',
#  'images/input/frames_transfered/a0250.jpg',
#  'images/input/frames_transfered/a0251.jpg',
#  'images/input/frames_transfered/a0252.jpg',
#  'images/input/frames_transfered/a0253.jpg',
#  'images/input/frames_transfered/a0254.jpg',
#  'images/input/frames_transfered/a0255.jpg',
#  'images/input/frames_transfered/a0256.jpg',
#  'images/input/frames_transfered/a0257.jpg',
#  'images/input/frames_transfered/a0258.jpg',
#  'images/input/frames_transfered/a0259.jpg',
#  'images/input/frames_transfered/a0260.jpg',
#  'images/input/frames_transfered/a0261.jpg',
#  'images/input/frames_transfered/a0262.jpg',
#  'images/input/frames_transfered/a0263.jpg',
#  'images/input/frames_transfered/a0264.jpg',
#  'images/input/frames_transfered/a0265.jpg',
#  'images/input/frames_transfered/a0266.jpg',
#  'images/input/frames_transfered/a0267.jpg',
#  'images/input/frames_transfered/a0268.jpg',
#  'images/input/frames_transfered/a0269.jpg',
#  'images/input/frames_transfered/a0270.jpg',
#  'images/input/frames_transfered/a0271.jpg',
#  'images/input/frames_transfered/a0272.jpg',
#  'images/input/frames_transfered/a0273.jpg',
#  'images/input/frames_transfered/a0274.jpg',
#  'images/input/frames_transfered/a0275.jpg',
#  'images/input/frames_transfered/a0276.jpg',
#  'images/input/frames_transfered/a0277.jpg',
#  'images/input/frames_transfered/a0278.jpg',
#  'images/input/frames_transfered/a0279.jpg',
#  'images/input/frames_transfered/a0280.jpg',
#  'images/input/frames_transfered/a0281.jpg',
#  'images/input/frames_transfered/a0282.jpg',
#  'images/input/frames_transfered/a0283.jpg',
#  'images/input/frames_transfered/a0284.jpg',
#  'images/input/frames_transfered/a0285.jpg',
#  'images/input/frames_transfered/a0286.jpg',
#  'images/input/frames_transfered/a0287.jpg',
#  'images/input/frames_transfered/a0288.jpg',
#  'images/input/frames_transfered/a0289.jpg',
#  'images/input/frames_transfered/a0290.jpg',
#  'images/input/frames_transfered/a0291.jpg',
#  'images/input/frames_transfered/a0292.jpg',
#  'images/input/frames_transfered/a0293.jpg',
#  'images/input/frames_transfered/a0294.jpg',
#  'images/input/frames_transfered/a0295.jpg',
#  'images/input/frames_transfered/a0296.jpg',
#  'images/input/frames_transfered/a0297.jpg',
#  'images/input/frames_transfered/a0298.jpg',
#  'images/input/frames_transfered/a0299.jpg',
#  'images/input/frames_transfered/a0300.jpg',
#  'images/input/frames_transfered/a0301.jpg',
#  'images/input/frames_transfered/a0302.jpg',
#  'images/input/frames_transfered/a0303.jpg',
#  'images/input/frames_transfered/a0304.jpg',
#  'images/input/frames_transfered/a0305.jpg',
#  'images/input/frames_transfered/a0306.jpg',
#  'images/input/frames_transfered/a0307.jpg',
#  'images/input/frames_transfered/a0308.jpg',
#  'images/input/frames_transfered/a0309.jpg',
#  'images/input/frames_transfered/a0310.jpg',
#  'images/input/frames_transfered/a0311.jpg',
#  'images/input/frames_transfered/a0312.jpg',
#  'images/input/frames_transfered/a0313.jpg',
#  'images/input/frames_transfered/a0314.jpg',
#  'images/input/frames_transfered/a0315.jpg',
#  'images/input/frames_transfered/a0316.jpg',
#  'images/input/frames_transfered/a0317.jpg',
#  'images/input/frames_transfered/a0318.jpg',
#  'images/input/frames_transfered/a0319.jpg',
#  'images/input/frames_transfered/a0320.jpg',
#  'images/input/frames_transfered/a0321.jpg',
#  'images/input/frames_transfered/a0322.jpg',
#  'images/input/frames_transfered/a0323.jpg',
#  'images/input/frames_transfered/a0324.jpg',
#  'images/input/frames_transfered/a0325.jpg',
#  'images/input/frames_transfered/a0326.jpg',
#  'images/input/frames_transfered/a0327.jpg',
#  'images/input/frames_transfered/a0328.jpg',
#  'images/input/frames_transfered/a0329.jpg',
#  'images/input/frames_transfered/a0330.jpg',
#  'images/input/frames_transfered/a0331.jpg',
#  'images/input/frames_transfered/a0332.jpg',
#  'images/input/frames_transfered/a0333.jpg',
#  'images/input/frames_transfered/a0334.jpg',
#  'images/input/frames_transfered/a0335.jpg',
#  'images/input/frames_transfered/a0336.jpg',
#  'images/input/frames_transfered/a0337.jpg',
#  'images/input/frames_transfered/a0338.jpg',
#  'images/input/frames_transfered/a0339.jpg',
#  'images/input/frames_transfered/a0340.jpg',
#  'images/input/frames_transfered/a0341.jpg',
#  'images/input/frames_transfered/a0342.jpg',
#  'images/input/frames_transfered/a0343.jpg',
#  'images/input/frames_transfered/a0344.jpg',
#  'images/input/frames_transfered/a0345.jpg',
#  'images/input/frames_transfered/a0346.jpg',
#  'images/input/frames_transfered/a0347.jpg',
#  'images/input/frames_transfered/a0348.jpg',
#  'images/input/frames_transfered/a0349.jpg',
#  'images/input/frames_transfered/a0350.jpg',
#  'images/input/frames_transfered/a0351.jpg',
#  'images/input/frames_transfered/a0352.jpg',
#  'images/input/frames_transfered/a0353.jpg',
#  'images/input/frames_transfered/a0354.jpg',
#  'images/input/frames_transfered/a0355.jpg',
#  'images/input/frames_transfered/a0356.jpg',
#  'images/input/frames_transfered/a0357.jpg',
#  'images/input/frames_transfered/a0358.jpg',
#  'images/input/frames_transfered/a0359.jpg',
#  'images/input/frames_transfered/a0360.jpg',
#  'images/input/frames_transfered/a0361.jpg',
#  'images/input/frames_transfered/a0362.jpg',
#  'images/input/frames_transfered/a0363.jpg',
#  'images/input/frames_transfered/a0364.jpg',
#  'images/input/frames_transfered/a0365.jpg',
#  'images/input/frames_transfered/a0366.jpg',
#  'images/input/frames_transfered/a0367.jpg',
#  'images/input/frames_transfered/a0368.jpg',
#  'images/input/frames_transfered/a0369.jpg',
#  'images/input/frames_transfered/a0370.jpg',
#  'images/input/frames_transfered/a0371.jpg',
#  'images/input/frames_transfered/a0372.jpg',
#  'images/input/frames_transfered/a0373.jpg',
#  'images/input/frames_transfered/a0374.jpg',
#  'images/input/frames_transfered/a0375.jpg',
#  'images/input/frames_transfered/a0376.jpg',
#  'images/input/frames_transfered/a0377.jpg',
#  'images/input/frames_transfered/a0378.jpg',
#  'images/input/frames_transfered/a0379.jpg',
#  'images/input/frames_transfered/a0380.jpg',
#  'images/input/frames_transfered/a0381.jpg',
#  'images/input/frames_transfered/a0382.jpg',
#  'images/input/frames_transfered/a0383.jpg',
#  'images/input/frames_transfered/a0384.jpg',
#  'images/input/frames_transfered/a0385.jpg',
#  'images/input/frames_transfered/a0386.jpg',
#  'images/input/frames_transfered/a0387.jpg',
#  'images/input/frames_transfered/a0388.jpg',
#  'images/input/frames_transfered/a0389.jpg',
#  'images/input/frames_transfered/a0390.jpg',
#  'images/input/frames_transfered/a0391.jpg',
#  'images/input/frames_transfered/a0392.jpg',
#  'images/input/frames_transfered/a0393.jpg',
#  'images/input/frames_transfered/a0394.jpg',
#  'images/input/frames_transfered/a0395.jpg',
#  'images/input/frames_transfered/a0396.jpg',
#  'images/input/frames_transfered/a0397.jpg',
#  'images/input/frames_transfered/a0398.jpg',
#  'images/input/frames_transfered/a0399.jpg',
#  'images/input/frames_transfered/a0400.jpg',
#  'images/input/frames_transfered/a0401.jpg',
#  'images/input/frames_transfered/a0402.jpg',
#  'images/input/frames_transfered/a0403.jpg',
#  'images/input/frames_transfered/a0404.jpg',
#  'images/input/frames_transfered/a0405.jpg',
#  'images/input/frames_transfered/a0406.jpg',
#  'images/input/frames_transfered/a0407.jpg',
#  'images/input/frames_transfered/a0408.jpg',
#  'images/input/frames_transfered/a0409.jpg',
#  'images/input/frames_transfered/a0410.jpg',
#  'images/input/frames_transfered/a0411.jpg',
#  'images/input/frames_transfered/a0412.jpg',
#  'images/input/frames_transfered/a0413.jpg',
#  'images/input/frames_transfered/a0414.jpg',
#  'images/input/frames_transfered/a0415.jpg',
#  'images/input/frames_transfered/a0416.jpg',
#  'images/input/frames_transfered/a0417.jpg',
#  'images/input/frames_transfered/a0418.jpg',
#  'images/input/frames_transfered/a0419.jpg',
#  'images/input/frames_transfered/a0420.jpg',
#  'images/input/frames_transfered/a0421.jpg',
#  'images/input/frames_transfered/a0422.jpg',
#  'images/input/frames_transfered/a0423.jpg',
#  'images/input/frames_transfered/a0424.jpg',
#  'images/input/frames_transfered/a0425.jpg',
#  'images/input/frames_transfered/a0426.jpg',
#  'images/input/frames_transfered/a0427.jpg',
#  'images/input/frames_transfered/a0428.jpg',
#  'images/input/frames_transfered/a0429.jpg',
#  'images/input/frames_transfered/a0430.jpg',
#  'images/input/frames_transfered/a0431.jpg',
#  'images/input/frames_transfered/a0432.jpg',
#  'images/input/frames_transfered/a0433.jpg',
#  'images/input/frames_transfered/a0434.jpg',
#  'images/input/frames_transfered/a0435.jpg',
#  'images/input/frames_transfered/a0436.jpg',
#  'images/input/frames_transfered/a0437.jpg',
#  'images/input/frames_transfered/a0438.jpg',
#  'images/input/frames_transfered/a0439.jpg',
#  'images/input/frames_transfered/a0440.jpg',
#  'images/input/frames_transfered/a0441.jpg',
#  'images/input/frames_transfered/a0442.jpg',
#  'images/input/frames_transfered/a0443.jpg',
#  'images/input/frames_transfered/a0444.jpg',
#  'images/input/frames_transfered/a0445.jpg',
#  'images/input/frames_transfered/a0446.jpg',
#  'images/input/frames_transfered/a0447.jpg',
#  'images/input/frames_transfered/a0448.jpg',
#  'images/input/frames_transfered/a0449.jpg',
#  'images/input/frames_transfered/a0450.jpg',
#  'images/input/frames_transfered/a0451.jpg',
#  'images/input/frames_transfered/a0452.jpg',
#  'images/input/frames_transfered/a0453.jpg',
#  'images/input/frames_transfered/a0454.jpg',
#  'images/input/frames_transfered/a0455.jpg',
#  'images/input/frames_transfered/a0456.jpg',
#  'images/input/frames_transfered/a0457.jpg',
#  'images/input/frames_transfered/a0458.jpg',
#  'images/input/frames_transfered/a0459.jpg',
#  'images/input/frames_transfered/a0460.jpg',
#  'images/input/frames_transfered/a0461.jpg',
#  'images/input/frames_transfered/a0462.jpg',
#  'images/input/frames_transfered/a0463.jpg',
#  'images/input/frames_transfered/a0464.jpg',
#  'images/input/frames_transfered/a0465.jpg',
#  'images/input/frames_transfered/a0466.jpg',
#  'images/input/frames_transfered/a0467.jpg',
#  'images/input/frames_transfered/a0468.jpg',
#  'images/input/frames_transfered/a0469.jpg',
#  'images/input/frames_transfered/a0470.jpg',
#  'images/input/frames_transfered/a0471.jpg',
#  'images/input/frames_transfered/a0472.jpg',
#  'images/input/frames_transfered/a0473.jpg',
#  'images/input/frames_transfered/a0474.jpg',
#  'images/input/frames_transfered/a0475.jpg',
#  'images/input/frames_transfered/a0476.jpg',
#  'images/input/frames_transfered/a0477.jpg',
#  'images/input/frames_transfered/a0478.jpg',
#  'images/input/frames_transfered/a0479.jpg',
#  'images/input/frames_transfered/a0480.jpg',
#  'images/input/frames_transfered/a0481.jpg',
#  'images/input/frames_transfered/a0482.jpg',
#  'images/input/frames_transfered/a0483.jpg',
#  'images/input/frames_transfered/a0484.jpg',
#  'images/input/frames_transfered/a0485.jpg',
#  'images/input/frames_transfered/a0486.jpg',
#  'images/input/frames_transfered/a0487.jpg',
#  'images/input/frames_transfered/a0488.jpg',
#  'images/input/frames_transfered/a0489.jpg',
#  'images/input/frames_transfered/a0490.jpg',
#  'images/input/frames_transfered/a0491.jpg',
#  'images/input/frames_transfered/a0492.jpg',
#  'images/input/frames_transfered/a0493.jpg',
#  'images/input/frames_transfered/a0494.jpg',
#  'images/input/frames_transfered/a0495.jpg',
#  'images/input/frames_transfered/a0496.jpg',
#  'images/input/frames_transfered/a0497.jpg',
#  'images/input/frames_transfered/a0498.jpg',
#  'images/input/frames_transfered/a0499.jpg',
#  'images/input/frames_transfered/a0500.jpg',
#  'images/input/frames_transfered/a0501.jpg',
#  'images/input/frames_transfered/a0502.jpg',
#  'images/input/frames_transfered/a0503.jpg',
#  'images/input/frames_transfered/a0504.jpg',
#  'images/input/frames_transfered/a0505.jpg',
#  'images/input/frames_transfered/a0506.jpg',
#  'images/input/frames_transfered/a0507.jpg',
#  'images/input/frames_transfered/a0508.jpg',
#  'images/input/frames_transfered/a0509.jpg',
#  'images/input/frames_transfered/a0510.jpg',
#  'images/input/frames_transfered/a0511.jpg',
#  'images/input/frames_transfered/a0512.jpg',
#  'images/input/frames_transfered/a0513.jpg',
#  'images/input/frames_transfered/a0514.jpg',
#  'images/input/frames_transfered/a0515.jpg',
#  'images/input/frames_transfered/a0516.jpg',
#  'images/input/frames_transfered/a0517.jpg',
#  'images/input/frames_transfered/a0518.jpg',
#  'images/input/frames_transfered/a0519.jpg',
#  'images/input/frames_transfered/a0520.jpg',
#  'images/input/frames_transfered/a0521.jpg',
#  'images/input/frames_transfered/a0522.jpg',
#  'images/input/frames_transfered/a0523.jpg',
#  'images/input/frames_transfered/a0524.jpg',
#  'images/input/frames_transfered/a0525.jpg',
#  'images/input/frames_transfered/a0526.jpg',
#  'images/input/frames_transfered/a0527.jpg',
#  'images/input/frames_transfered/a0528.jpg',
#  'images/input/frames_transfered/a0529.jpg',
#  'images/input/frames_transfered/a0530.jpg',
#  'images/input/frames_transfered/a0531.jpg',
#  'images/input/frames_transfered/a0532.jpg',
#  'images/input/frames_transfered/a0533.jpg',
#  'images/input/frames_transfered/a0534.jpg',
#  'images/input/frames_transfered/a0535.jpg',
#  'images/input/frames_transfered/a0536.jpg',
#  'images/input/frames_transfered/a0537.jpg',
#  'images/input/frames_transfered/a0538.jpg',
#  'images/input/frames_transfered/a0539.jpg',
#  'images/input/frames_transfered/a0540.jpg',
#  'images/input/frames_transfered/a0541.jpg',
#  'images/input/frames_transfered/a0542.jpg',
#  'images/input/frames_transfered/a0543.jpg',
#  'images/input/frames_transfered/a0544.jpg',
#  'images/input/frames_transfered/a0545.jpg',
#  'images/input/frames_transfered/a0546.jpg',
#  'images/input/frames_transfered/a0547.jpg',
#  'images/input/frames_transfered/a0548.jpg',
#  'images/input/frames_transfered/a0549.jpg',
#  'images/input/frames_transfered/a0550.jpg',
#  'images/input/frames_transfered/a0551.jpg',
#  'images/input/frames_transfered/a0552.jpg',
#  'images/input/frames_transfered/a0553.jpg',
#  'images/input/frames_transfered/a0554.jpg',
#  'images/input/frames_transfered/a0555.jpg',
#  'images/input/frames_transfered/a0556.jpg',
#  'images/input/frames_transfered/a0557.jpg',
#  'images/input/frames_transfered/a0558.jpg',
#  'images/input/frames_transfered/a0559.jpg',
#  'images/input/frames_transfered/a0560.jpg',
#  'images/input/frames_transfered/a0561.jpg',
#  'images/input/frames_transfered/a0562.jpg',
#  'images/input/frames_transfered/a0563.jpg',
#  'images/input/frames_transfered/a0564.jpg',
#  'images/input/frames_transfered/a0565.jpg',
#  'images/input/frames_transfered/a0566.jpg',
#  'images/input/frames_transfered/a0567.jpg',
#  'images/input/frames_transfered/a0568.jpg',
#  'images/input/frames_transfered/a0569.jpg',
#  'images/input/frames_transfered/a0570.jpg',
#  'images/input/frames_transfered/a0571.jpg',
#  'images/input/frames_transfered/a0572.jpg',
#  'images/input/frames_transfered/a0573.jpg',
#  'images/input/frames_transfered/a0574.jpg',
#  'images/input/frames_transfered/a0575.jpg',
#  'images/input/frames_transfered/a0576.jpg',
#  'images/input/frames_transfered/a0577.jpg',
#  'images/input/frames_transfered/a0578.jpg',
#  'images/input/frames_transfered/a0579.jpg',
#  'images/input/frames_transfered/a0580.jpg',
#  'images/input/frames_transfered/a0581.jpg',
#  'images/input/frames_transfered/a0582.jpg',
#  'images/input/frames_transfered/a0583.jpg',
#  'images/input/frames_transfered/a0584.jpg',
#  'images/input/frames_transfered/a0585.jpg',
#  'images/input/frames_transfered/a0586.jpg',
#  'images/input/frames_transfered/a0587.jpg',
#  'images/input/frames_transfered/a0588.jpg',
#  'images/input/frames_transfered/a0589.jpg',
#  'images/input/frames_transfered/a0590.jpg',
#  'images/input/frames_transfered/a0591.jpg',
#  'images/input/frames_transfered/a0592.jpg',
#  'images/input/frames_transfered/a0593.jpg',
#  'images/input/frames_transfered/a0594.jpg',
#  'images/input/frames_transfered/a0595.jpg',
#  'images/input/frames_transfered/a0596.jpg',
#  'images/input/frames_transfered/a0597.jpg',
#  'images/input/frames_transfered/a0598.jpg',
#  'images/input/frames_transfered/a0599.jpg',
#  'images/input/frames_transfered/a0600.jpg',
#  'images/input/frames_transfered/a0601.jpg',
#  'images/input/frames_transfered/a0602.jpg',
#  'images/input/frames_transfered/a0603.jpg',
#  'images/input/frames_transfered/a0604.jpg',
#  'images/input/frames_transfered/a0605.jpg',
#  'images/input/frames_transfered/a0606.jpg',
#  'images/input/frames_transfered/a0607.jpg',
#  'images/input/frames_transfered/a0608.jpg',
#  'images/input/frames_transfered/a0609.jpg',
#  'images/input/frames_transfered/a0610.jpg',
#  'images/input/frames_transfered/a0611.jpg',
#  'images/input/frames_transfered/a0612.jpg',
#  'images/input/frames_transfered/a0613.jpg',
#  'images/input/frames_transfered/a0614.jpg',
#  'images/input/frames_transfered/a0615.jpg',
#  'images/input/frames_transfered/a0616.jpg',
#  'images/input/frames_transfered/a0617.jpg',
#  'images/input/frames_transfered/a0618.jpg',
#  'images/input/frames_transfered/a0619.jpg',
#  'images/input/frames_transfered/a0620.jpg',
#  'images/input/frames_transfered/a0621.jpg',
#  'images/input/frames_transfered/a0622.jpg',
#  'images/input/frames_transfered/a0623.jpg',
#  'images/input/frames_transfered/a0624.jpg',
#  'images/input/frames_transfered/a0625.jpg',
#  'images/input/frames_transfered/a0626.jpg',
#  'images/input/frames_transfered/a0627.jpg',
#  'images/input/frames_transfered/a0628.jpg',
#  'images/input/frames_transfered/a0629.jpg',
#  'images/input/frames_transfered/a0630.jpg',
#  'images/input/frames_transfered/a0631.jpg',
#  'images/input/frames_transfered/a0632.jpg',
#  'images/input/frames_transfered/a0633.jpg',
#  'images/input/frames_transfered/a0634.jpg',
#  'images/input/frames_transfered/a0635.jpg',
#  'images/input/frames_transfered/a0636.jpg',
#  'images/input/frames_transfered/a0637.jpg',
#  'images/input/frames_transfered/a0638.jpg',
#  'images/input/frames_transfered/a0639.jpg',
#  'images/input/frames_transfered/a0640.jpg',
#  'images/input/frames_transfered/a0641.jpg',
#  'images/input/frames_transfered/a0642.jpg',
#  'images/input/frames_transfered/a0643.jpg',
#  'images/input/frames_transfered/a0644.jpg',
#  'images/input/frames_transfered/a0645.jpg',
#  'images/input/frames_transfered/a0646.jpg',
#  'images/input/frames_transfered/a0647.jpg',
#  'images/input/frames_transfered/a0648.jpg',
#  'images/input/frames_transfered/a0649.jpg',
#  'images/input/frames_transfered/a0650.jpg',
#  'images/input/frames_transfered/a0651.jpg',
#  'images/input/frames_transfered/a0652.jpg',
#  'images/input/frames_transfered/a0653.jpg',
#  'images/input/frames_transfered/a0654.jpg',
#  'images/input/frames_transfered/a0655.jpg',
#  'images/input/frames_transfered/a0656.jpg',
#  'images/input/frames_transfered/a0657.jpg',
#  'images/input/frames_transfered/a0658.jpg',
#  'images/input/frames_transfered/a0659.jpg',
#  'images/input/frames_transfered/a0660.jpg',
#  'images/input/frames_transfered/a0661.jpg',
#  'images/input/frames_transfered/a0662.jpg',
#  'images/input/frames_transfered/a0663.jpg',
#  'images/input/frames_transfered/a0664.jpg',
#  'images/input/frames_transfered/a0665.jpg',
#  'images/input/frames_transfered/a0666.jpg',
#  'images/input/frames_transfered/a0667.jpg',
#  'images/input/frames_transfered/a0668.jpg',
#  'images/input/frames_transfered/a0669.jpg',
#  'images/input/frames_transfered/a0670.jpg',
#  'images/input/frames_transfered/a0671.jpg',
#  'images/input/frames_transfered/a0672.jpg',
#  'images/input/frames_transfered/a0673.jpg',
#  'images/input/frames_transfered/a0674.jpg',
#  'images/input/frames_transfered/a0675.jpg',
#  'images/input/frames_transfered/a0676.jpg',
#  'images/input/frames_transfered/a0677.jpg',
#  'images/input/frames_transfered/a0678.jpg',
#  'images/input/frames_transfered/a0679.jpg',
#  'images/input/frames_transfered/a0680.jpg',
#  'images/input/frames_transfered/a0681.jpg',
#  'images/input/frames_transfered/a0682.jpg',
#  'images/input/frames_transfered/a0683.jpg',
#  'images/input/frames_transfered/a0684.jpg',
#  'images/input/frames_transfered/a0685.jpg',
#  'images/input/frames_transfered/a0686.jpg',
#  'images/input/frames_transfered/a0687.jpg',
#  'images/input/frames_transfered/a0688.jpg',
#  'images/input/frames_transfered/a0689.jpg',
#  'images/input/frames_transfered/a0690.jpg',
#  'images/input/frames_transfered/a0691.jpg',
#  'images/input/frames_transfered/a0692.jpg',
#  'images/input/frames_transfered/a0693.jpg',
#  'images/input/frames_transfered/a0694.jpg',
#  'images/input/frames_transfered/a0695.jpg',
#  'images/input/frames_transfered/a0696.jpg',
#  'images/input/frames_transfered/a0697.jpg',
#  'images/input/frames_transfered/a0698.jpg',
#  'images/input/frames_transfered/a0699.jpg',
#  'images/input/frames_transfered/a0700.jpg',
#  'images/input/frames_transfered/a0701.jpg',
#  'images/input/frames_transfered/a0702.jpg',
#  'images/input/frames_transfered/a0703.jpg',
#  'images/input/frames_transfered/a0704.jpg',
#  'images/input/frames_transfered/a0705.jpg',
#  'images/input/frames_transfered/a0706.jpg',
#  'images/input/frames_transfered/a0707.jpg',
#  'images/input/frames_transfered/a0708.jpg',
#  'images/input/frames_transfered/a0709.jpg',
#  'images/input/frames_transfered/a0710.jpg',
#  'images/input/frames_transfered/a0711.jpg',
#  'images/input/frames_transfered/a0712.jpg',
#  'images/input/frames_transfered/a0713.jpg',
#  'images/input/frames_transfered/a0714.jpg',
#  'images/input/frames_transfered/a0715.jpg',
#  'images/input/frames_transfered/a0716.jpg',
#  'images/input/frames_transfered/a0717.jpg',
#  'images/input/frames_transfered/a0718.jpg',
#  'images/input/frames_transfered/a0719.jpg',
#  'images/input/frames_transfered/a0720.jpg',
#  'images/input/frames_transfered/a0721.jpg',
#  'images/input/frames_transfered/a0722.jpg',
#  'images/input/frames_transfered/a0723.jpg',
#  'images/input/frames_transfered/a0724.jpg',
#  'images/input/frames_transfered/a0725.jpg',
#  'images/input/frames_transfered/a0726.jpg',
#  'images/input/frames_transfered/a0727.jpg',
#  'images/input/frames_transfered/a0728.jpg',
#  'images/input/frames_transfered/a0729.jpg',
#  'images/input/frames_transfered/a0730.jpg',
#  'images/input/frames_transfered/a0731.jpg',
#  'images/input/frames_transfered/a0732.jpg',
#  'images/input/frames_transfered/a0733.jpg',
#  'images/input/frames_transfered/a0734.jpg',
#  'images/input/frames_transfered/a0735.jpg',
#  'images/input/frames_transfered/a0736.jpg',
#  'images/input/frames_transfered/a0737.jpg',
#  'images/input/frames_transfered/a0738.jpg',
#  'images/input/frames_transfered/a0739.jpg',
#  'images/input/frames_transfered/a0740.jpg',
#  'images/input/frames_transfered/a0741.jpg',
#  'images/input/frames_transfered/a0742.jpg',
#  'images/input/frames_transfered/a0743.jpg',
#  'images/input/frames_transfered/a0744.jpg',
#  'images/input/frames_transfered/a0745.jpg',
#  'images/input/frames_transfered/a0746.jpg',
#  'images/input/frames_transfered/a0747.jpg',
#  'images/input/frames_transfered/a0748.jpg',
#  'images/input/frames_transfered/a0749.jpg',
#  'images/input/frames_transfered/a0750.jpg',
#  'images/input/frames_transfered/a0751.jpg',
#  'images/input/frames_transfered/a0752.jpg',
#  'images/input/frames_transfered/a0753.jpg',
#  'images/input/frames_transfered/a0754.jpg',
#  'images/input/frames_transfered/a0755.jpg',
#  'images/input/frames_transfered/a0756.jpg',
#  'images/input/frames_transfered/a0757.jpg',
#  'images/input/frames_transfered/a0758.jpg',
#  'images/input/frames_transfered/a0759.jpg',
#  'images/input/frames_transfered/a0760.jpg',
#  'images/input/frames_transfered/a0761.jpg',
#  'images/input/frames_transfered/a0762.jpg',
#  'images/input/frames_transfered/a0763.jpg',
#  'images/input/frames_transfered/a0764.jpg',
#  'images/input/frames_transfered/a0765.jpg',
#  'images/input/frames_transfered/a0766.jpg',
#  'images/input/frames_transfered/a0767.jpg',
#  'images/input/frames_transfered/a0768.jpg',
#  'images/input/frames_transfered/a0769.jpg',
#  'images/input/frames_transfered/a0770.jpg',
#  'images/input/frames_transfered/a0771.jpg',
#  'images/input/frames_transfered/a0772.jpg',
#  'images/input/frames_transfered/a0773.jpg',
#  'images/input/frames_transfered/a0774.jpg',
#  'images/input/frames_transfered/a0775.jpg',
#  'images/input/frames_transfered/a0776.jpg',
#  'images/input/frames_transfered/a0777.jpg',
#  'images/input/frames_transfered/a0778.jpg',
#  'images/input/frames_transfered/a0779.jpg',
#  'images/input/frames_transfered/a0780.jpg',
#  'images/input/frames_transfered/a0781.jpg',
#  'images/input/frames_transfered/a0782.jpg',
#  'images/input/frames_transfered/a0783.jpg',
#  'images/input/frames_transfered/a0784.jpg',
#  'images/input/frames_transfered/a0785.jpg',
#  'images/input/frames_transfered/a0786.jpg',
#  'images/input/frames_transfered/a0787.jpg',
#  'images/input/frames_transfered/a0788.jpg',
#  'images/input/frames_transfered/a0789.jpg',
#  'images/input/frames_transfered/a0790.jpg',
#  'images/input/frames_transfered/a0791.jpg',
#  'images/input/frames_transfered/a0792.jpg',
#  'images/input/frames_transfered/a0793.jpg',
#  'images/input/frames_transfered/a0794.jpg',
#  'images/input/frames_transfered/a0795.jpg',
#  'images/input/frames_transfered/a0796.jpg',
#  'images/input/frames_transfered/a0797.jpg',
#  'images/input/frames_transfered/a0798.jpg',
#  'images/input/frames_transfered/a0799.jpg',
#  'images/input/frames_transfered/a0800.jpg',
#  'images/input/frames_transfered/a0801.jpg',
#  'images/input/frames_transfered/a0802.jpg',
#  'images/input/frames_transfered/a0803.jpg',
#  'images/input/frames_transfered/a0804.jpg',
#  'images/input/frames_transfered/a0805.jpg',
#  'images/input/frames_transfered/a0806.jpg',
#  'images/input/frames_transfered/a0807.jpg',
#  'images/input/frames_transfered/a0808.jpg',
#  'images/input/frames_transfered/a0809.jpg',
#  'images/input/frames_transfered/a0810.jpg',
#  'images/input/frames_transfered/a0811.jpg',
#  'images/input/frames_transfered/a0812.jpg',
#  'images/input/frames_transfered/a0813.jpg',
#  'images/input/frames_transfered/a0814.jpg',
#  'images/input/frames_transfered/a0815.jpg',
#  'images/input/frames_transfered/a0816.jpg',
#  'images/input/frames_transfered/a0817.jpg',
#  'images/input/frames_transfered/a0818.jpg',
#  'images/input/frames_transfered/a0819.jpg',
#  'images/input/frames_transfered/a0820.jpg',
#  'images/input/frames_transfered/a0821.jpg',
#  'images/input/frames_transfered/a0822.jpg',
#  'images/input/frames_transfered/a0823.jpg',
#  'images/input/frames_transfered/a0824.jpg',
#  'images/input/frames_transfered/a0825.jpg',
#  'images/input/frames_transfered/a0826.jpg',
#  'images/input/frames_transfered/a0827.jpg',
#  'images/input/frames_transfered/a0828.jpg',
#  'images/input/frames_transfered/a0829.jpg',
#  'images/input/frames_transfered/a0830.jpg',
#  'images/input/frames_transfered/a0831.jpg',
#  'images/input/frames_transfered/a0832.jpg',
#  'images/input/frames_transfered/a0833.jpg',
#  'images/input/frames_transfered/a0834.jpg',
#  'images/input/frames_transfered/a0835.jpg',
#  'images/input/frames_transfered/a0836.jpg',
#  'images/input/frames_transfered/a0837.jpg',
#  'images/input/frames_transfered/a0838.jpg',
#  'images/input/frames_transfered/a0839.jpg',
#  'images/input/frames_transfered/a0840.jpg',
#  'images/input/frames_transfered/a0841.jpg',
#  'images/input/frames_transfered/a0842.jpg',
#  'images/input/frames_transfered/a0843.jpg',
#  'images/input/frames_transfered/a0844.jpg',
#  'images/input/frames_transfered/a0845.jpg',
#  'images/input/frames_transfered/a0846.jpg',
#  'images/input/frames_transfered/a0847.jpg',
#  'images/input/frames_transfered/a0848.jpg',
#  'images/input/frames_transfered/a0849.jpg',
#  'images/input/frames_transfered/a0850.jpg',
#  'images/input/frames_transfered/a0851.jpg',
#  'images/input/frames_transfered/a0852.jpg',
#  'images/input/frames_transfered/a0853.jpg',
#  'images/input/frames_transfered/a0854.jpg',
#  'images/input/frames_transfered/a0855.jpg',
#  'images/input/frames_transfered/a0856.jpg',
#  'images/input/frames_transfered/a0857.jpg',
#  'images/input/frames_transfered/a0858.jpg',
#  'images/input/frames_transfered/a0859.jpg',
#  'images/input/frames_transfered/a0860.jpg',
#  'images/input/frames_transfered/a0861.jpg',
#  'images/input/frames_transfered/a0862.jpg',
#  'images/input/frames_transfered/a0863.jpg',
#  'images/input/frames_transfered/a0864.jpg',
#  'images/input/frames_transfered/a0865.jpg',
#  'images/input/frames_transfered/a0866.jpg',
#  'images/input/frames_transfered/a0867.jpg',
#  'images/input/frames_transfered/a0868.jpg',
#  'images/input/frames_transfered/a0869.jpg',
#  'images/input/frames_transfered/a0870.jpg',
#  'images/input/frames_transfered/a0871.jpg',
#  'images/input/frames_transfered/a0872.jpg',
#  'images/input/frames_transfered/a0873.jpg',
#  'images/input/frames_transfered/a0874.jpg',
#  'images/input/frames_transfered/a0875.jpg',
#  'images/input/frames_transfered/a0876.jpg',
#  'images/input/frames_transfered/a0877.jpg',
#  'images/input/frames_transfered/a0878.jpg',
#  'images/input/frames_transfered/a0879.jpg',
#  'images/input/frames_transfered/a0880.jpg',
#  'images/input/frames_transfered/a0881.jpg',
#  'images/input/frames_transfered/a0882.jpg',
#  'images/input/frames_transfered/a0883.jpg',
#  'images/input/frames_transfered/a0884.jpg',
#  'images/input/frames_transfered/a0885.jpg',
#  'images/input/frames_transfered/a0886.jpg',
#  'images/input/frames_transfered/a0887.jpg',
#  'images/input/frames_transfered/a0888.jpg',
#  'images/input/frames_transfered/a0889.jpg',
#  'images/input/frames_transfered/a0890.jpg',
#  'images/input/frames_transfered/a0891.jpg',
#  'images/input/frames_transfered/a0892.jpg',
#  'images/input/frames_transfered/a0893.jpg',
#  'images/input/frames_transfered/a0894.jpg',
#  'images/input/frames_transfered/a0895.jpg',
#  'images/input/frames_transfered/a0896.jpg',
#  'images/input/frames_transfered/a0897.jpg',
#  'images/input/frames_transfered/a0898.jpg',
#  'images/input/frames_transfered/a0899.jpg']

# %%
Count = len(filenames_transfered)
Height, Width, Channels = cv2.imread(filenames_transfered[0]).shape
# rows, cols, 3 for a frame
wrapped_imgs = np.zeros((Count, Height, Width, Channels),dtype=np.float32)

for idx, file_i in enumerate(filenames_transfered):
    wrapped_imgs[idx] = cv2.cvtColor(cv2.imread(file_i), cv2.COLOR_BGR2RGB) / 255.0

# %%
print(wrapped_imgs[1,450,400])
# Out:
# [0.16862746 0.16862746 0.20784314]

# %%
def my_blendImages(sourceTransform, referenceTransform):
    '''
    Input:
        - sourceTransform: source frame projected onto reference frame plane
        - referenceTransform: reference frame projected onto same space

    Output:
        - blendedOutput: naive blending result from frame stitching
    '''

    blendedOutput = referenceTransform
    indices = referenceTransform == 0.0
    blendedOutput[indices] = sourceTransform[indices]

    return blendedOutput
#     return (blendedOutput / blendedOutput.max() * 255).astype(np.uint8)

# %%
result = np.zeros((Height, Width, Channels),dtype = np.float32)
for i in range (0, 10,1):
    result1 = np.zeros((Height, Width, Channels),dtype = np.float32)
    result1 = my_blendImages(wrapped_imgs[i],result)
    result = result1
# warpped2(wrapped_imgs[0],result)
# warpped2(wrapped_imgs[200],result)
# warpped2(wrapped_imgs[400],result)
# warpped2(wrapped_imgs[600],result)
# warpped2(wrapped_imgs[800],result)
plt.imshow(result)
plt.show()


# for i in range (0,Count):
#     result = utils.blendImages(wrapped_imgs[i], result)
# # blendedOutput = utils.blendImages(projectedSource, projectedReference)

# plt.imshow(result)
# plt.show()

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import statistics
import pdb

# for each pixel, find the median across the 900 frames
# vectorized approach
rows,cols = wrapped_imgs[0].shape[0], wrapped_imgs[0].shape[1]
median_calc = np.zeros((rows,cols,3,len(wrapped_imgs)))
# 800 * 2000 * 3 * 900
median_calc.fill(np.nan)

frame,x,y,c = np.nonzero(wrapped_imgs)


median_calc[x,y,c,frame] = wrapped_imgs[frame,x,y,c]
median = np.nanmedian(median_calc,axis=3) # Compute the median along the specified axis, while ignoring NaNs.

# %%
plt.figure(figsize=(65,15))
plt.imshow(median/255)

# %% [markdown]
# ### Part 5: Create background movie
#
# Map the background panorama to the movie coordinates. For each frame of the movie, say frame 1, you need to estimate a projection from the panorama to frame 1. Note, you should be able to re-use the homographies that you estimated in __Part 3__. Perform this for all frames and generate a movie that looks like the input movie but shows only background pixels. All moving objects that belong to the foreground must be removed.

# %%
import os
import cv2
import numpy as np

# %%
for i in range(0, 2):
    cur_H = pastHomographies[i][450]
    inv_H = np.linalg.inv(cur_H)
    img_warped = cv2.warpPerspective(median, inv_H, (360, 480))

# %%
utils.imageFolder2mpeg('./images/input/background_frame',output_path='./images/input/background_result.mpeg', fps=30.0)

# %% [markdown]
# ### Part 6: Create foreground movie
#
# In the background video, moving objects are removed. In each frame, those pixels that are different enough than the background color are considered foreground. For each frame determine foreground pixels and generate a movie that only includes foreground pixels.

# %%
import os
import cv2
import numpy as np

for i in range(0, Count):
    difference = frames[i] - (warped_imgs[i]/255)
    cv2.imwrite('images/input/foreground_frames/a{:04d}.jpg'.format(i), difference*255)
utils.imageFolder2mpeg('./images/input/foreground_frames',output_path='./images/input/foreground_result.mpeg', fps=30.0)

# %% [markdown]
# ## Bells and whistles

# %%
# in Part 1 and file my_example1.ipynb and my_example2.ipynb
