# %% [markdown]
# # Programming Project #5: Video Stitching and Processing

# %% [markdown]
# ## CS445: Computational Photography - Fall 2019

# %% [markdown]
# ### Part I: Stitch two key frames <img src="images/project_5/image005.jpg" alt="Drawing" style="float: right; width: 450px"/>
#
# #### This involves:
# 1. compute homography H between two frames;
# 2. project each frame onto the same surface;
# 3. blend the surfaces.
#
#
#
# Check that your homography is correct by plotting four points that form a square in frame 270 and their projections in each image, like this:
# <p>
#     <img src="images/project_5/image002.jpg" alt="Drawing"/>
#     <img src="images/project_5/image004.jpg" alt="Drawing"/>
# </p>

# %%
import cv2
import numpy as np
from numpy.linalg import svd, inv

# %matplotlib inline
from matplotlib import pyplot as plt

# %%
pts = np.array([[10,5],[20,30],[70,20],[50,10]], np.int32)
pts = pts.reshape((-1,1,2))
print(pts)
# Out:
# [[[10  5]]
#
#  [[20 30]]
#
#  [[70 20]]
#
#  [[50 10]]]

# %%
import PIL.Image as Image

# %%
# images location
im1 = './images/input/my_frames2/f0120.jpg'
im2 = './images/input/my_frames2/f0140.jpg'

# Load an color image in grayscale
im1 = cv2.imread(im1) # float32, 0.0-1.0
im2 = cv2.imread(im2)
# im1.resize((480,320),Image.ANTIALIAS)
print(im1.shape[0],im1.shape[1],im1.shape[2])
img_rows = im1.shape[0] # 1920
img_cols = im1.shape[1] # 1080
# Out:
# 1920 1080 3

# %%
def auto_homography(Ia,Ib, homography_func=None):
    '''
    Computes a homography that maps points from Ia to Ib

    Input: Ia and Ib are images
    Output: H is the homography

    '''
    if Ia.dtype == 'float32' and Ib.dtype == 'float32':
        Ia = (Ia*255).astype(np.uint8)
        Ib = (Ib*255).astype(np.uint8)
    
    Ia_gray = cv2.cvtColor(Ia,cv2.COLOR_BGR2GRAY)
    Ib_gray = cv2.cvtColor(Ib,cv2.COLOR_BGR2GRAY)

    # Initiate SIFT detector
    sift = cv2.xfeatures2d.SIFT_create()
    
    # find the keypoints and descriptors with SIFT
    # kp_a is keypoints List and des_a is descriptors List
    kp_a, des_a = sift.detectAndCompute(Ia_gray,None)
    kp_b, des_b = sift.detectAndCompute(Ib_gray,None)    
    
    # BFMatcher with default params
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(des_a,des_b, k=2)
#     print('---TEST values in matches, which is list of elements(a,b)---')
#     print(matches[0])
#     print(matches[0][0].distance)
#     print(matches[0][1].distance)
    
    # Apply ratio test
    good = []
    for m,n in matches:
        if m.distance < 0.75*n.distance:
            good.append(m)
    
    numMatches = int(len(good)) # numMatches = 215
    matches = good 
    
    # Xa and Xb are 3xN matrices that contain homogeneous coordinates for the N
    # matching points for each image
    Xa = np.ones((3,numMatches))
    Xb = np.ones((3,numMatches))
    
#     print('---TEST 3*215 point---')
#     print(Xa[:,0][0:2])
#     print(Xa[:,0])
    pts1_good = np.ones((3,4))
    pts2_good = np.ones((3,4))
    for idx, match_i in enumerate(matches):
        Xa[:,idx][0:2] = kp_a[match_i.queryIdx].pt
        Xb[:,idx][0:2] = kp_b[match_i.trainIdx].pt

    ## RANSAC
    niter = 1000
    best_score = 0
    
    H = np.zeros((3,3))
    for t in range(niter):
        # estimate homography
        subset = np.random.choice(numMatches, 4, replace=False)
        pts1 = Xa[:,subset]
        pts2 = Xb[:,subset]

        H_t = homography_func(pts1, pts2)
#         H_t = computeHomography(pts1, pts2) # edit helper code below (computeHomography)
        # pts1 = 3xN matrix and N = 4

        # score homography
        Xb_ = np.dot(H_t, Xa) # project points from first image to second using H
        du = Xb_[0,:]/Xb_[2,:] - Xb[0,:]/Xb[2,:]
        dv = Xb_[1,:]/Xb_[2,:] - Xb[1,:]/Xb[2,:]
        
        ok_t = np.sqrt(du**2 + dv**2) < 1  # you may need to play with this threshold
        score_t = sum(ok_t)

        if score_t > best_score:
            best_score = score_t
            H = H_t
            in_idx = ok_t
            pts1_good = pts1
            pts2_good = pts2
#     print(pts1_good)
#     print(pts2_good)
    print('best score: {:02f}'.format(best_score))
    
# # Check that your homography is correct by plotting four points that form a square in frame 270 
#     # use as the four corners to draw the polylines
#     con_pts1 = np.zeros((4,2),np.int32)
#     con_pts2 = np.zeros((4,2),np.int32)
    
#     for i in range (4):
# #         print("point %d Xa"%(i),pts1_good[:,i])
# #         print("point %d Xb"%(i),pts2_good[:,i])  
# #         Xb_ = np.dot(H, Xa)
# #         print("point %d Xb_"%(i),Xb_[:,i])
# #         print(Xb_[:,i]/Xb_[2,i])
#         con_pts1[i] = pts1_good[0:2,i]
#         con_pts2[i] = pts2_good[0:2,i]
# #         print(con_pts1[i])
# #         print(con_pts2[i])
# #     A[[i, j], :] = A[[j, i], :] # 实现了第i行与第j行的互换
#     im1_RGB2 = cv2.cvtColor(Ia,cv2.COLOR_BGR2RGB)
#     im2_RGB2 = cv2.cvtColor(Ib,cv2.COLOR_BGR2RGB)
#     con_pts1[[0, 2], :] = con_pts1[[2, 0], :]
#     con_pts2[[0, 2], :] = con_pts2[[2, 0], :]
    
# #   for draw rectangular  im1_RGB2 = cv2.rectangle(im1_RGB2,(100,100),(200,200),(255,0,0),3)
# #     pts = np.array([[10,5],[20,30],[70,20],[50,10]], np.int32)
#     con_pts1 = con_pts1.reshape((-1,1,2))
#     con_pts2 = con_pts2.reshape((-1,1,2))
# #     print("--------")
# #     print(con_pts1)
# #     print(con_pts2)
#     im1_RGB2 = cv2.polylines(im1_RGB2,[con_pts1],True,(255,0,0),thickness = 2,lineType = 8)
#     im2_RGB2 = cv2.polylines(im2_RGB2,[con_pts2],True,(255,0,0),thickness = 2,lineType = 8)
    
#     plt.imshow(im1_RGB2)
#     plt.show()
    
#     plt.imshow(im2_RGB2)
#     plt.show()
    
#     # Optionally, you may want to re-estimate H based on inliers

    return H

# %%
def computeHomography(pts1, pts2):
    '''
    Compute homography that maps from pts1 to pts2 using least squares solver
     
    Input: pts1 and pts2 are 3xN matrices for N points in homogeneous
    coordinates.  N is 4.
    
    Output: H is a 3x3 matrix, such that pts2~=H*pts1
    '''
    
    dimen, num = pts1.shape
    A = np.zeros((2*num, 9), dtype = np.float32)
    
    for i in range (0, num):
        # p_prime = w*[u_prime,v_prime,1]
        # p = [u,v,1]
        p_prime = pts2[:,i]
        u_prime = p_prime[0]/p_prime[2]
        v_prime = p_prime[1]/p_prime[2]
        
        p = pts1[:,i]
        u = p[0]/p[2]
        v = p[1]/p[2]
        A[i*2,:] = [-u,-v,-1,0,0,0,u*u_prime, v*u_prime, u_prime]
        A[i*2+1,:] = [0,0,0,-u,-v,-1,u*v_prime, v*v_prime, v_prime]
    U,S,Vt = svd(A)
    h = Vt[-1,:]
    H = np.reshape(h, (3, 3))
    
#     std1_u = np.std(pts1[1,:])
#     std1_v =  np.std(pts1[2,:])
#     mean1_u = np.mean(pts1[1,:])
#     mean1_v = np.mean(pts1[2,:]) 
#     T1 = np.matrix([[1/std1_u, 0, 0],[0, 1/std1_v, 0],[0, 0, 1]]) * np.matrix([[1,0,-mean1_u],[0,1,-mean1_v],[0,0,1]])
    
#     std2_u = np.std(pts2[1,:])
#     std2_v = np.std(pts2[2,:])
#     mean2_u = np.mean(pts2[1,:])
#     mean2_v = np.mean(pts2[2,:]) 
#     T2 = np.matrix([[1/std2_u, 0, 0],[0, 1/std2_v, 0],[0, 0, 1]]) * np.matrix([[1,0,-mean2_u],[0,1,-mean2_v],[0,0,1]])
#     H = T2/H_n * T1
    return H

# %%
H = auto_homography(im1,im2, computeHomography)
# Out:
# best score: 291.000000

# %%
im1_path = './images/input/my_frames2/f0120.jpg'
im2_path = './images/input/my_frames2/f0140.jpg'
im1_cv2 = cv2.imread(im1_path) # uint 0-255
im2_cv2 = cv2.imread(im2_path)

im1_RGB = cv2.cvtColor(im1_cv2,cv2.COLOR_BGR2RGB)
im2_RGB = cv2.cvtColor(im2_cv2,cv2.COLOR_BGR2RGB)

im1_plt = im1_RGB.astype(np.float32)/255
im2_plt = im2_RGB.astype(np.float32)/255


# im1 = cv2.imread(im1_path,cv2.COLOR_BGR2RGB)
# im2 = cv2.imread(im2_path,cv2.COLOR_BGR2RGB)
# Load an color image in grayscale
# im1 = plt.imread(im1) # float32, 0.0-1.0
# im2 = plt.imread(im2)

fig, axes = plt.subplots(3,2)
axes[0,0].imshow(im1_cv2)
axes[0,1].imshow(im2_cv2)
axes[1,0].imshow(im1_RGB)
axes[1,1].imshow(im2_RGB)
axes[2,0].imshow(im1_plt)
axes[2,1].imshow(im2_plt)
"It is important to change color from BGR to RGB"
# Out:
# 'It is important to change color from BGR to RGB'

# %%
cols = 4000
rows = 2200
# 360*480
# pts = np.float32([[0, 0], [0, h-1], [w-1, h-1], [w-1, 0]]).reshape(-1, 1, 2)
# dst = cv2.perspectiveTransform(pts, H)
H_transition = np.identity(3)
H_transition[0,2] = (cols-img_cols)/2
H_transition[1,2] = (rows-img_rows)/2
print(H_transition)
# Xb_ = np.dot(H, im1_plt) # project points from first image to second using H
# du = Xb_[0,:]/Xb_[2,:]
# img_warped = cv2.warpPerspective(img, H_t.dot(H), (output_width, output_height))

img_warped_270 = cv2.warpPerspective(im2_plt,H_transition,(cols, rows))
img_warped_0 = cv2.warpPerspective(im1_plt, np.dot(H_transition, H), (cols, rows))
# img_warped3 = cv2.warpPerspective(img_warped2, H_transition, (w, h))

plt.imshow(img_warped_270)
plt.show()
plt.imshow(img_warped_0)
plt.show()
#  method 1
print("method1")
result = img_warped_270
for i in range(0,rows):
    for j in range(0,cols):
        if (result[i,j].sum() == 0) and (img_warped_0[i,j].sum() != 0):
            result[i,j] = img_warped_0[i,j]
plt.imshow(result)
plt.show()
# Out:
# [[1.00e+00 0.00e+00 1.46e+03]
#  [0.00e+00 1.00e+00 1.40e+02]
#  [0.00e+00 0.00e+00 1.00e+00]]
# method1

# %%
'''
#  method 2
print("method2")
for col in range(0, cols):
    if img_warped_270[:, col].any() and img_warped_0[:, col].any():
        left = col
        break
for col in range(cols-1, 0, -1):
    if img_warped_270[:, col].any() and img_warped_0[:, col].any():
        right = col
        break
srcImg = img_warped_270
warpImg = img_warped_0
res = np.zeros([rows, cols, 3], np.float32)

for row in range(0, rows):
    for col in range(0, cols):
        if not srcImg[row, col].any():
            res[row, col] = warpImg[row, col]
        elif not warpImg[row, col].any():
            res[row, col] = srcImg[row, col]
        else:
            srcImgLen = float(abs(col - right))
            testImgLen = float(abs(col - left))
            alpha = srcImgLen / (srcImgLen + testImgLen)
            res[row, col] = np.clip(srcImg[row, col] * (1-alpha) + warpImg[row, col] * alpha, 0, 255)
plt.imshow(res)
plt.show()
'''

# %% [markdown]
# ### Part II: Panorama using five key frames
#
# In this part you will produce a panorama using five key frames. Let's determine frames [90, 270, 450, 630, 810] as key frames. The goal is to map all the five frames onto the plane corresponding to frame 450 (that we also call the _reference frame_). For the frames 270 and 630 you can follow the instructions in part 1.
#
# <img src="images/project_5/header.jpg" alt="Drawing" style="float: center; width: 500px"/>
#
# Mapping frame 90 to frame 450 is difficult because they share very little area. Therefore you need to perform a two stage mapping by using frame 270 as a guide. Compute one projection from 90 to 270 and one from 270 to 450 and multiply the two matrices. This produces a projection from 90 to 450 even though these frames have very little area in common

# %%
import cv2
import numpy as np
import utils

# %%
def warpped(result,img1,img2,H):
    # img2 = H*img1
    rows, cols, c = result.shape
#     cols = 1200
#     rows = 500
    img_warped = cv2.warpPerspective(img1, np.dot(H_transition, H), (cols, rows))
    return utils.blendImages(img_warped, result)
#     the following is written by myself instead of using utils.blendImages
#     for i in range(0,rows):
#         for j in range(0,cols):
#             if (result[i,j].sum() == 0) and (img_warped[i,j].sum() != 0):
#                 result[i,j] = img_warped[i,j]
#     return 0

# %%
master_frames =[170,220,270,320,370]
reference_frame = 270
reference_idx = master_frames.index(reference_frame)
im1_path = './images/input/my_frames2/f0080.jpg'
im2_path = './images/input/my_frames2/f0100.jpg'
im3_path = './images/input/my_frames2/f0120.jpg'
im4_path = './images/input/my_frames2/f0140.jpg'
im5_path = './images/input/my_frames2/f0160.jpg'
im1_cv2 = cv2.imread(im1_path) # float32, 0.0-1.0
im2_cv2 = cv2.imread(im2_path)
im3_cv2 = cv2.imread(im3_path)
im4_cv2 = cv2.imread(im4_path)
im5_cv2 = cv2.imread(im5_path)

im1_RGB = cv2.cvtColor(im1_cv2,cv2.COLOR_BGR2RGB)
im2_RGB = cv2.cvtColor(im2_cv2,cv2.COLOR_BGR2RGB)
im3_RGB = cv2.cvtColor(im3_cv2,cv2.COLOR_BGR2RGB)
im4_RGB = cv2.cvtColor(im4_cv2,cv2.COLOR_BGR2RGB)
im5_RGB = cv2.cvtColor(im5_cv2,cv2.COLOR_BGR2RGB)

# fig, axes = plt.subplots(1,5)
# axes[0].imshow(im1_RGB)
# axes[1].imshow(im2_RGB)
# axes[2].imshow(im3_RGB)
# axes[3].imshow(im4_RGB)
# axes[4].imshow(im5_RGB)

H12 = auto_homography(im1_cv2,im2_cv2, computeHomography)
H23 = auto_homography(im2_cv2,im3_cv2, computeHomography)
H43 = auto_homography(im4_cv2,im3_cv2, computeHomography)
H54 = auto_homography(im5_cv2,im4_cv2, computeHomography)


H13 = np.dot(H23,H12)
H53 = np.dot(H43,H54)
cols = 4000
rows = 2200
# 1920*1080
H_transition = np.identity(3)
H_transition[0,2] = (cols-img_cols)/2
H_transition[1,2] = (rows-img_rows)/2

result = cv2.warpPerspective(im1_RGB ,np.dot(H_transition, H13),(cols, rows))

warpped(result,im2_RGB,im3_RGB,H23)
warpped(result,im3_RGB,im3_RGB,np.identity(3))
warpped(result,im4_RGB,im3_RGB,H43)
warpped(result,im5_RGB,im3_RGB,H53)

# img_warped_0 = cv2.warpPerspective(im1_plt, np.dot(H_transition, H), (cols, rows))
# img_warped3 = cv2.warpPerspective(img_warped2, H_transition, (w, h))

plt.imshow(result)
plt.show()
# Out:
# best score: 130.000000
# best score: 199.000000
# best score: 285.000000
# best score: 231.000000

# %% [markdown]
# ### Part 3: Map the video to the reference plane

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from math import floor

# import utils

# %%
dir_frames = 'images/input/my_frames2'
filenames = []
filesinfo = os.scandir(dir_frames)
filesinfo

# %%
filenames = [f.path for f in filesinfo if f.name.endswith(".jpg")]
filenames.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))
filenames
# Out:
# ['images/input/my_frames2/f0001.jpg',
#  'images/input/my_frames2/f0002.jpg',
#  'images/input/my_frames2/f0003.jpg',
#  'images/input/my_frames2/f0004.jpg',
#  'images/input/my_frames2/f0005.jpg',
#  'images/input/my_frames2/f0006.jpg',
#  'images/input/my_frames2/f0007.jpg',
#  'images/input/my_frames2/f0008.jpg',
#  'images/input/my_frames2/f0009.jpg',
#  'images/input/my_frames2/f0010.jpg',
#  'images/input/my_frames2/f0011.jpg',
#  'images/input/my_frames2/f0012.jpg',
#  'images/input/my_frames2/f0013.jpg',
#  'images/input/my_frames2/f0014.jpg',
#  'images/input/my_frames2/f0015.jpg',
#  'images/input/my_frames2/f0016.jpg',
#  'images/input/my_frames2/f0017.jpg',
#  'images/input/my_frames2/f0018.jpg',
#  'images/input/my_frames2/f0019.jpg',
#  'images/input/my_frames2/f0020.jpg',
#  'images/input/my_frames2/f0021.jpg',
#  'images/input/my_frames2/f0022.jpg',
#  'images/input/my_frames2/f0023.jpg',
#  'images/input/my_frames2/f0024.jpg',
#  'images/input/my_frames2/f0025.jpg',
#  'images/input/my_frames2/f0026.jpg',
#  'images/input/my_frames2/f0027.jpg',
#  'images/input/my_frames2/f0028.jpg',
#  'images/input/my_frames2/f0029.jpg',
#  'images/input/my_frames2/f0030.jpg',
#  'images/input/my_frames2/f0031.jpg',
#  'images/input/my_frames2/f0032.jpg',
#  'images/input/my_frames2/f0033.jpg',
#  'images/input/my_frames2/f0034.jpg',
#  'images/input/my_frames2/f0035.jpg',
#  'images/input/my_frames2/f0036.jpg',
#  'images/input/my_frames2/f0037.jpg',
#  'images/input/my_frames2/f0038.jpg',
#  'images/input/my_frames2/f0039.jpg',
#  'images/input/my_frames2/f0040.jpg',
#  'images/input/my_frames2/f0041.jpg',
#  'images/input/my_frames2/f0042.jpg',
#  'images/input/my_frames2/f0043.jpg',
#  'images/input/my_frames2/f0044.jpg',
#  'images/input/my_frames2/f0045.jpg',
#  'images/input/my_frames2/f0046.jpg',
#  'images/input/my_frames2/f0047.jpg',
#  'images/input/my_frames2/f0048.jpg',
#  'images/input/my_frames2/f0049.jpg',
#  'images/input/my_frames2/f0050.jpg',
#  'images/input/my_frames2/f0051.jpg',
#  'images/input/my_frames2/f0052.jpg',
#  'images/input/my_frames2/f0053.jpg',
#  'images/input/my_frames2/f0054.jpg',
#  'images/input/my_frames2/f0055.jpg',
#  'images/input/my_frames2/f0056.jpg',
#  'images/input/my_frames2/f0057.jpg',
#  'images/input/my_frames2/f0058.jpg',
#  'images/input/my_frames2/f0059.jpg',
#  'images/input/my_frames2/f0060.jpg',
#  'images/input/my_frames2/f0061.jpg',
#  'images/input/my_frames2/f0062.jpg',
#  'images/input/my_frames2/f0063.jpg',
#  'images/input/my_frames2/f0064.jpg',
#  'images/input/my_frames2/f0065.jpg',
#  'images/input/my_frames2/f0066.jpg',
#  'images/input/my_frames2/f0067.jpg',
#  'images/input/my_frames2/f0068.jpg',
#  'images/input/my_frames2/f0069.jpg',
#  'images/input/my_frames2/f0070.jpg',
#  'images/input/my_frames2/f0071.jpg',
#  'images/input/my_frames2/f0072.jpg',
#  'images/input/my_frames2/f0073.jpg',
#  'images/input/my_frames2/f0074.jpg',
#  'images/input/my_frames2/f0075.jpg',
#  'images/input/my_frames2/f0076.jpg',
#  'images/input/my_frames2/f0077.jpg',
#  'images/input/my_frames2/f0078.jpg',
#  'images/input/my_frames2/f0079.jpg',
#  'images/input/my_frames2/f0080.jpg',
#  'images/input/my_frames2/f0081.jpg',
#  'images/input/my_frames2/f0082.jpg',
#  'images/input/my_frames2/f0083.jpg',
#  'images/input/my_frames2/f0084.jpg',
#  'images/input/my_frames2/f0085.jpg',
#  'images/input/my_frames2/f0086.jpg',
#  'images/input/my_frames2/f0087.jpg',
#  'images/input/my_frames2/f0088.jpg',
#  'images/input/my_frames2/f0089.jpg',
#  'images/input/my_frames2/f0090.jpg',
#  'images/input/my_frames2/f0091.jpg',
#  'images/input/my_frames2/f0092.jpg',
#  'images/input/my_frames2/f0093.jpg',
#  'images/input/my_frames2/f0094.jpg',
#  'images/input/my_frames2/f0095.jpg',
#  'images/input/my_frames2/f0096.jpg',
#  'images/input/my_frames2/f0097.jpg',
#  'images/input/my_frames2/f0098.jpg',
#  'images/input/my_frames2/f0099.jpg',
#  'images/input/my_frames2/f0100.jpg',
#  'images/input/my_frames2/f0101.jpg',
#  'images/input/my_frames2/f0102.jpg',
#  'images/input/my_frames2/f0103.jpg',
#  'images/input/my_frames2/f0104.jpg',
#  'images/input/my_frames2/f0105.jpg',
#  'images/input/my_frames2/f0106.jpg',
#  'images/input/my_frames2/f0107.jpg',
#  'images/input/my_frames2/f0108.jpg',
#  'images/input/my_frames2/f0109.jpg',
#  'images/input/my_frames2/f0110.jpg',
#  'images/input/my_frames2/f0111.jpg',
#  'images/input/my_frames2/f0112.jpg',
#  'images/input/my_frames2/f0113.jpg',
#  'images/input/my_frames2/f0114.jpg',
#  'images/input/my_frames2/f0115.jpg',
#  'images/input/my_frames2/f0116.jpg',
#  'images/input/my_frames2/f0117.jpg',
#  'images/input/my_frames2/f0118.jpg',
#  'images/input/my_frames2/f0119.jpg',
#  'images/input/my_frames2/f0120.jpg',
#  'images/input/my_frames2/f0121.jpg',
#  'images/input/my_frames2/f0122.jpg',
#  'images/input/my_frames2/f0123.jpg',
#  'images/input/my_frames2/f0124.jpg',
#  'images/input/my_frames2/f0125.jpg',
#  'images/input/my_frames2/f0126.jpg',
#  'images/input/my_frames2/f0127.jpg',
#  'images/input/my_frames2/f0128.jpg',
#  'images/input/my_frames2/f0129.jpg',
#  'images/input/my_frames2/f0130.jpg',
#  'images/input/my_frames2/f0131.jpg',
#  'images/input/my_frames2/f0132.jpg',
#  'images/input/my_frames2/f0133.jpg',
#  'images/input/my_frames2/f0134.jpg',
#  'images/input/my_frames2/f0135.jpg',
#  'images/input/my_frames2/f0136.jpg',
#  'images/input/my_frames2/f0137.jpg',
#  'images/input/my_frames2/f0138.jpg',
#  'images/input/my_frames2/f0139.jpg',
#  'images/input/my_frames2/f0140.jpg',
#  'images/input/my_frames2/f0141.jpg',
#  'images/input/my_frames2/f0142.jpg',
#  'images/input/my_frames2/f0143.jpg',
#  'images/input/my_frames2/f0144.jpg',
#  'images/input/my_frames2/f0145.jpg',
#  'images/input/my_frames2/f0146.jpg',
#  'images/input/my_frames2/f0147.jpg',
#  'images/input/my_frames2/f0148.jpg',
#  'images/input/my_frames2/f0149.jpg',
#  'images/input/my_frames2/f0150.jpg',
#  'images/input/my_frames2/f0151.jpg',
#  'images/input/my_frames2/f0152.jpg',
#  'images/input/my_frames2/f0153.jpg',
#  'images/input/my_frames2/f0154.jpg',
#  'images/input/my_frames2/f0155.jpg',
#  'images/input/my_frames2/f0156.jpg',
#  'images/input/my_frames2/f0157.jpg',
#  'images/input/my_frames2/f0158.jpg',
#  'images/input/my_frames2/f0159.jpg',
#  'images/input/my_frames2/f0160.jpg',
#  'images/input/my_frames2/f0161.jpg',
#  'images/input/my_frames2/f0162.jpg',
#  'images/input/my_frames2/f0163.jpg',
#  'images/input/my_frames2/f0164.jpg',
#  'images/input/my_frames2/f0165.jpg',
#  'images/input/my_frames2/f0166.jpg',
#  'images/input/my_frames2/f0167.jpg',
#  'images/input/my_frames2/f0168.jpg',
#  'images/input/my_frames2/f0169.jpg',
#  'images/input/my_frames2/f0170.jpg',
#  'images/input/my_frames2/f0171.jpg',
#  'images/input/my_frames2/f0172.jpg',
#  'images/input/my_frames2/f0173.jpg',
#  'images/input/my_frames2/f0174.jpg',
#  'images/input/my_frames2/f0175.jpg',
#  'images/input/my_frames2/f0176.jpg',
#  'images/input/my_frames2/f0177.jpg',
#  'images/input/my_frames2/f0178.jpg',
#  'images/input/my_frames2/f0179.jpg',
#  'images/input/my_frames2/f0180.jpg',
#  'images/input/my_frames2/f0181.jpg',
#  'images/input/my_frames2/f0182.jpg',
#  'images/input/my_frames2/f0183.jpg',
#  'images/input/my_frames2/f0184.jpg',
#  'images/input/my_frames2/f0185.jpg',
#  'images/input/my_frames2/f0186.jpg',
#  'images/input/my_frames2/f0187.jpg',
#  'images/input/my_frames2/f0188.jpg',
#  'images/input/my_frames2/f0189.jpg',
#  'images/input/my_frames2/f0190.jpg',
#  'images/input/my_frames2/f0191.jpg',
#  'images/input/my_frames2/f0192.jpg',
#  'images/input/my_frames2/f0193.jpg',
#  'images/input/my_frames2/f0194.jpg',
#  'images/input/my_frames2/f0195.jpg',
#  'images/input/my_frames2/f0196.jpg',
#  'images/input/my_frames2/f0197.jpg',
#  'images/input/my_frames2/f0198.jpg',
#  'images/input/my_frames2/f0199.jpg',
#  'images/input/my_frames2/f0200.jpg',
#  'images/input/my_frames2/f0201.jpg',
#  'images/input/my_frames2/f0202.jpg',
#  'images/input/my_frames2/f0203.jpg',
#  'images/input/my_frames2/f0204.jpg',
#  'images/input/my_frames2/f0205.jpg',
#  'images/input/my_frames2/f0206.jpg',
#  'images/input/my_frames2/f0207.jpg',
#  'images/input/my_frames2/f0208.jpg',
#  'images/input/my_frames2/f0209.jpg',
#  'images/input/my_frames2/f0210.jpg',
#  'images/input/my_frames2/f0211.jpg',
#  'images/input/my_frames2/f0212.jpg',
#  'images/input/my_frames2/f0213.jpg',
#  'images/input/my_frames2/f0214.jpg',
#  'images/input/my_frames2/f0215.jpg',
#  'images/input/my_frames2/f0216.jpg',
#  'images/input/my_frames2/f0217.jpg',
#  'images/input/my_frames2/f0218.jpg',
#  'images/input/my_frames2/f0219.jpg',
#  'images/input/my_frames2/f0220.jpg',
#  'images/input/my_frames2/f0221.jpg',
#  'images/input/my_frames2/f0222.jpg',
#  'images/input/my_frames2/f0223.jpg',
#  'images/input/my_frames2/f0224.jpg',
#  'images/input/my_frames2/f0225.jpg',
#  'images/input/my_frames2/f0226.jpg',
#  'images/input/my_frames2/f0227.jpg',
#  'images/input/my_frames2/f0228.jpg',
#  'images/input/my_frames2/f0229.jpg',
#  'images/input/my_frames2/f0230.jpg',
#  'images/input/my_frames2/f0231.jpg',
#  'images/input/my_frames2/f0232.jpg',
#  'images/input/my_frames2/f0233.jpg',
#  'images/input/my_frames2/f0234.jpg',
#  'images/input/my_frames2/f0235.jpg',
#  'images/input/my_frames2/f0236.jpg',
#  'images/input/my_frames2/f0237.jpg',
#  'images/input/my_frames2/f0238.jpg',
#  'images/input/my_frames2/f0239.jpg',
#  'images/input/my_frames2/f0240.jpg',
#  'images/input/my_frames2/f0241.jpg',
#  'images/input/my_frames2/f0242.jpg',
#  'images/input/my_frames2/f0243.jpg',
#  'images/input/my_frames2/f0244.jpg',
#  'images/input/my_frames2/f0245.jpg',
#  'images/input/my_frames2/f0246.jpg',
#  'images/input/my_frames2/f0247.jpg',
#  'images/input/my_frames2/f0248.jpg',
#  'images/input/my_frames2/f0249.jpg',
#  'images/input/my_frames2/f0250.jpg',
#  'images/input/my_frames2/f0251.jpg',
#  'images/input/my_frames2/f0252.jpg',
#  'images/input/my_frames2/f0253.jpg',
#  'images/input/my_frames2/f0254.jpg',
#  'images/input/my_frames2/f0255.jpg',
#  'images/input/my_frames2/f0256.jpg',
#  'images/input/my_frames2/f0257.jpg',
#  'images/input/my_frames2/f0258.jpg',
#  'images/input/my_frames2/f0259.jpg',
#  'images/input/my_frames2/f0260.jpg',
#  'images/input/my_frames2/f0261.jpg',
#  'images/input/my_frames2/f0262.jpg',
#  'images/input/my_frames2/f0263.jpg',
#  'images/input/my_frames2/f0264.jpg',
#  'images/input/my_frames2/f0265.jpg',
#  'images/input/my_frames2/f0266.jpg',
#  'images/input/my_frames2/f0267.jpg',
#  'images/input/my_frames2/f0268.jpg',
#  'images/input/my_frames2/f0269.jpg',
#  'images/input/my_frames2/f0270.jpg',
#  'images/input/my_frames2/f0271.jpg',
#  'images/input/my_frames2/f0272.jpg',
#  'images/input/my_frames2/f0273.jpg',
#  'images/input/my_frames2/f0274.jpg',
#  'images/input/my_frames2/f0275.jpg',
#  'images/input/my_frames2/f0276.jpg',
#  'images/input/my_frames2/f0277.jpg',
#  'images/input/my_frames2/f0278.jpg',
#  'images/input/my_frames2/f0279.jpg',
#  'images/input/my_frames2/f0280.jpg',
#  'images/input/my_frames2/f0281.jpg',
#  'images/input/my_frames2/f0282.jpg',
#  'images/input/my_frames2/f0283.jpg',
#  'images/input/my_frames2/f0284.jpg']

# %%
frameCount = len(filenames)
frameHeight, frameWidth, frameChannels = cv2.imread(filenames[0]).shape
# rows, cols, 3 for a frame
frames = np.zeros((frameCount, frameHeight, frameWidth, frameChannels),dtype=np.float32)
# 900, rows, cols, 3 for all frames

# %%
# im2_cv2 = cv2.imread(im2_path)
# im2_RGB = cv2.cvtColor(im2_cv2,cv2.COLOR_BGR2RGB)
# im2_plt = im2_RGB.astype(np.float32)/255  !!! (value/255.0) instead of 255
for idx, file_i in enumerate(filenames):
    frames[idx] = cv2.cvtColor(cv2.imread(file_i), cv2.COLOR_BGR2RGB) / 255.0

# %%
def auto_homography(Ia,Ib, homography_func=None, normalization_func=None):
    '''
    Computes a homography that maps points from Ia to Ib

    Input: Ia and Ib are images
    Output: H is the homography

    '''
    if Ia.dtype == 'float32' and Ib.dtype == 'float32':
        Ia = (Ia*255).astype(np.uint8)
        Ib = (Ib*255).astype(np.uint8)
    
    Ia_gray = cv2.cvtColor(Ia,cv2.COLOR_BGR2GRAY)
    Ib_gray = cv2.cvtColor(Ib,cv2.COLOR_BGR2GRAY)

    # Initiate SIFT detector
    sift = cv2.xfeatures2d.SIFT_create()
    
    # find the keypoints and descriptors with SIFT
    # kp_a is keypoints List and des_a is descriptors List
    kp_a, des_a = sift.detectAndCompute(Ia_gray,None)
    kp_b, des_b = sift.detectAndCompute(Ib_gray,None)    
    
    # BFMatcher with default params
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(des_a,des_b, k=2)
#     print('---TEST values in matches, which is list of elements(a,b)---')
#     print(matches[0])
#     print(matches[0][0].distance)
#     print(matches[0][1].distance)
    
    # Apply ratio test
    good = []
    for m,n in matches:
        if m.distance < 0.75*n.distance:
            good.append(m)
    
    numMatches = int(len(good)) # numMatches = 215
    matches = good 
    
    # Xa and Xb are 3xN matrices that contain homogeneous coordinates for the N
    # matching points for each image
    Xa = np.ones((3,numMatches))
    Xb = np.ones((3,numMatches))
    
#     print('---TEST 3*215 point---')
#     print(Xa[:,0][0:2])
#     print(Xa[:,0])
    pts1_good = np.ones((3,4))
    pts2_good = np.ones((3,4))
    for idx, match_i in enumerate(matches):
        Xa[:,idx][0:2] = kp_a[match_i.queryIdx].pt
        Xb[:,idx][0:2] = kp_b[match_i.trainIdx].pt

    ## RANSAC
    niter = 1000
    best_score = 0
    
    H = np.zeros((3,3))
    for t in range(niter):
        # estimate homography
        subset = np.random.choice(numMatches, 4, replace=False)
        pts1 = Xa[:,subset]
        pts2 = Xb[:,subset]

        H_t = homography_func(pts1, pts2, normalization_func)
#         H_t = computeHomography(pts1, pts2) # edit helper code below (computeHomography)
        # pts1 = 3xN matrix and N = 4

        # score homography
        Xb_ = np.dot(H_t, Xa) # project points from first image to second using H
        du = Xb_[0,:]/Xb_[2,:] - Xb[0,:]/Xb[2,:]
        dv = Xb_[1,:]/Xb_[2,:] - Xb[1,:]/Xb[2,:]
        
        ok_t = np.sqrt(du**2 + dv**2) < 1  # you may need to play with this threshold
        score_t = sum(ok_t)

        if score_t > best_score:
            best_score = score_t
            H = H_t
            in_idx = ok_t
            pts1_good = pts1
            pts2_good = pts2
#     print(pts1_good)
#     print(pts2_good)
    print('best score: {:02f}'.format(best_score))
    
# # Check that your homography is correct by plotting four points that form a square in frame 270 
#     # use as the four corners to draw the polylines
#     con_pts1 = np.zeros((4,2),np.int32)
#     con_pts2 = np.zeros((4,2),np.int32)
    
#     for i in range (4):
# #         print("point %d Xa"%(i),pts1_good[:,i])
# #         print("point %d Xb"%(i),pts2_good[:,i])  
# #         Xb_ = np.dot(H, Xa)
# #         print("point %d Xb_"%(i),Xb_[:,i])
# #         print(Xb_[:,i]/Xb_[2,i])
#         con_pts1[i] = pts1_good[0:2,i]
#         con_pts2[i] = pts2_good[0:2,i]
# #         print(con_pts1[i])
# #         print(con_pts2[i])
# #     A[[i, j], :] = A[[j, i], :] # 实现了第i行与第j行的互换
#     im1_RGB2 = cv2.cvtColor(Ia,cv2.COLOR_BGR2RGB)
#     im2_RGB2 = cv2.cvtColor(Ib,cv2.COLOR_BGR2RGB)
#     con_pts1[[0, 2], :] = con_pts1[[2, 0], :]
#     con_pts2[[0, 2], :] = con_pts2[[2, 0], :]
    
# #   for draw rectangular  im1_RGB2 = cv2.rectangle(im1_RGB2,(100,100),(200,200),(255,0,0),3)
# #     pts = np.array([[10,5],[20,30],[70,20],[50,10]], np.int32)
#     con_pts1 = con_pts1.reshape((-1,1,2))
#     con_pts2 = con_pts2.reshape((-1,1,2))
# #     print("--------")
# #     print(con_pts1)
# #     print(con_pts2)
#     im1_RGB2 = cv2.polylines(im1_RGB2,[con_pts1],True,(255,0,0),thickness = 2,lineType = 8)
#     im2_RGB2 = cv2.polylines(im2_RGB2,[con_pts2],True,(255,0,0),thickness = 2,lineType = 8)
    
#     plt.imshow(im1_RGB2)
#     plt.show()
    
#     plt.imshow(im2_RGB2)
#     plt.show()
    
#     # Optionally, you may want to re-estimate H based on inliers

    return H

# %%
def computeHomography(pts1, pts2, normalization_func=None):
    '''
    Compute homography that maps from pts1 to pts2 using least squares solver
     
    Input: pts1 and pts2 are 3xN matrices for N points in homogeneous
    coordinates.  N is 4.
    
    Output: H is a 3x3 matrix, such that pts2~=H*pts1
    '''
    
    dimen, num = pts1.shape
    A = np.zeros((2*num, 9), dtype = np.float32)
    
    for i in range (0, num):
        # p_prime = w*[u_prime,v_prime,1]
        # p = [u,v,1]
        p_prime = pts2[:,i]
        u_prime = p_prime[0]/p_prime[2]
        v_prime = p_prime[1]/p_prime[2]
        
        p = pts1[:,i]
        u = p[0]/p[2]
        v = p[1]/p[2]
        A[i*2,:] = [-u,-v,-1,0,0,0,u*u_prime, v*u_prime, u_prime]
        A[i*2+1,:] = [0,0,0,-u,-v,-1,u*v_prime, v*v_prime, v_prime]
    U,S,Vt = svd(A)
    h = Vt[-1,:]
    H = np.reshape(h, (3, 3))
    
#     std1_u = np.std(pts1[1,:])
#     std1_v =  np.std(pts1[2,:])
#     mean1_u = np.mean(pts1[1,:])
#     mean1_v = np.mean(pts1[2,:]) 
#     T1 = np.matrix([[1/std1_u, 0, 0],[0, 1/std1_v, 0],[0, 0, 1]]) * np.matrix([[1,0,-mean1_u],[0,1,-mean1_v],[0,0,1]])
    
#     std2_u = np.std(pts2[1,:])
#     std2_v = np.std(pts2[2,:])
#     mean2_u = np.mean(pts2[1,:])
#     mean2_v = np.mean(pts2[2,:]) 
#     T2 = np.matrix([[1/std2_u, 0, 0],[0, 1/std2_v, 0],[0, 0, 1]]) * np.matrix([[1,0,-mean2_u],[0,1,-mean2_v],[0,0,1]])
#     H = T2/H_n * T1
    return H

# %%
def projectImage(frames, sourceFrameIndex, referenceFrameIndex,
                 pastHomographies, originTranslations, xrange=4000,
                 yrange=2200, overlapThreshold=40000, errorThreshold=4e-5,
                 numKeyframes=5, checkAllKeyframes=0, auto_H_func=None,
                 homography_func=None, normalization_func=None):
    '''
    Input:
        - frames: 4D array of frames
        - sourceFrameIndex: index of the frame to be projected
        - referenceFrameIndex: index of the frame to be projected to
        - pastHomographies: 2D cell array caching previously computed
          homographies from every frame to every other frame
        - xrange, yrange: dimensions of the output image
        - overlapThreshold: sufficient number of pixels overlapping between
          projected source and reference frames to ensure good homography
        - errorThreshold: acceptable error for good homography
        - numKeyframes: number of equidistant keyframes between source and
          reference frame to be visited in search of better homography
        - checkAllKeyframes: 0 if algorithms breaks after first better
          homography is found, 1 if all keyframes are to be visited

    Output:
        - bestProjectedImage: source frame optimally projected onto reference
          frame using reestimation of homography based on closest-frame search
          and using closest-frame homography as
    '''
        # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# cols = 4000
# rows = 2200
# # 1920*1080
# H_transition = np.identity(3)
# H_transition[0,2] = (cols-img_cols)/2
# H_transition[1,2] = (rows-img_rows)/2
        
    H_transition = np.identity(3)
    H_transition[0,2] = (xrange-img_cols)/2
    H_transition[1,2] = (yrange-img_rows)/2

    print("once")
    numFrames = frames.shape[0]
    _, referenceTransform, ref_origin_coord = transformImage(frames, referenceFrameIndex, referenceFrameIndex, pastHomographies, xrange, yrange, auto_H_func, homography_func, normalization_func)
    _, sourceTransform, src_origin_coord = transformImage(frames, sourceFrameIndex, referenceFrameIndex, pastHomographies, xrange, yrange, auto_H_func, homography_func, normalization_func)
    _, err = computeOverlap(sourceTransform, src_origin_coord, referenceTransform, ref_origin_coord, overlapThreshold)
    originTranslations[sourceFrameIndex] = src_origin_coord
    
    
    x_min, y_min = originTranslations[0]
    # Translation matrix
    t = [-x_min, -y_min]
    H_t = np.array([[1, 0, t[0]], [0, 1, t[1]], [0, 0, 1]], dtype=np.float32)
    # Dot product of translation matrix and homography
    pastHomographies[sourceFrameIndex, referenceFrameIndex] = H_t.dot(pastHomographies[sourceFrameIndex, referenceFrameIndex])

#     projectedImage = cv2.warpPerspective((frames[sourceFrameIndex]*255).astype(np.uint8),
#                                          pastHomographies[sourceFrameIndex, referenceFrameIndex],
#                                          (xrange, yrange))
    projectedImage = cv2.warpPerspective((frames[sourceFrameIndex]*255).astype(np.uint8),
                                         H_transition.dot(pastHomographies[sourceFrameIndex, referenceFrameIndex]),
                                         (xrange, yrange))
   
    
    if err > errorThreshold:
        print('Finding better homography...')
        increment = floor(((referenceFrameIndex - sourceFrameIndex) - 1) / (numKeyframes + 1))
        keyframeIndex = sourceFrameIndex + increment  # frame being used to find better homography from source to reference
#         increment = 10
#         keyframeIndex = 130
        
        found = 0
        counter = 0
        bestHomography = np.eye(3)  # initialize H as identity

        while counter < numKeyframes and keyframeIndex < numFrames and keyframeIndex > 0:

            # compute homography and projected image from keyframe to
            # reference frame
            H2, keyframeTransform, keyframe_origin_coord = transformImage(frames, keyframeIndex, referenceFrameIndex, pastHomographies, xrange, yrange, auto_H_func, homography_func, normalization_func)
            a, error1 = computeOverlap(keyframeTransform, keyframe_origin_coord, referenceTransform, ref_origin_coord, overlapThreshold)
#             H2 = pastHomographies[130, 270]
            
            # compute homography and projected image from source frame to
            # keyframe (new reference = keyframe)
            _, keyframeToKeyframeTransform, keyframeToKeyframe_origin_coord = transformImage(frames, keyframeIndex, keyframeIndex, pastHomographies, xrange, yrange,  auto_H_func, homography_func, normalization_func)
            H1, sourceToKeyframeTransform, srcToKeyframe_origin_coord = transformImage(frames, sourceFrameIndex, keyframeIndex, pastHomographies, xrange, yrange,  auto_H_func, homography_func, normalization_func)
            b, error2 = computeOverlap(sourceToKeyframeTransform, srcToKeyframe_origin_coord, keyframeToKeyframeTransform, keyframeToKeyframe_origin_coord, overlapThreshold)

            sufficientOverlap = (a and b)

            if (sufficientOverlap and max(error1, error2) < err):
#             if 1 :
                found = 1
                bestHomography = np.dot(H1, H2)
                src_origin_coord = keyframe_origin_coord + srcToKeyframe_origin_coord
                if not checkAllKeyframes:
                    break

            keyframeIndex = keyframeIndex + increment
            counter = counter + 1

        if found:
            print('Found better homography')
            pastHomographies[sourceFrameIndex, referenceFrameIndex] = bestHomography
            originTranslations[sourceFrameIndex] = src_origin_coord
            min_origin_coord = np.amin(originTranslations, axis=0)

            x_min, y_min = originTranslations[0]
            # Translation matrix
            t = [-x_min, -y_min]
            H_t = np.array([[1, 0, t[0]], [0, 1, t[1]], [0, 0, 1]], dtype=np.float32)

            # Dot product of translation matrix and homography
            T = H_t.dot(bestHomography)
            
#             projectedImage = cv2.warpPerspective((frames[sourceFrameIndex]*255).astype(np.uint8), T, (xrange, yrange))

            projectedImage = cv2.warpPerspective((frames[sourceFrameIndex]*255).astype(np.uint8), np.dot(H_transition,T), (xrange, yrange))

            pastHomographies[sourceFrameIndex, referenceFrameIndex] = T.astype(np.float32)
    
    return projectedImage, pastHomographies, originTranslations

# %%
## Example usage of utils.projectImage

pastHomographies = np.zeros((len(filenames),len(filenames), 3, 3),dtype=np.float32)
# 900*900*(3*3) H13 = pastHomographies[1,3]
originTranslations = np.zeros((len(filenames), 2), dtype=np.float32)
# store the current homographies
# sourceFrameIndex = 630
# referenceFrameIndex = 450

# %%
from utils import transformImage, computeOverlap

# %%
# frameCount = len(filenames)
# frameHeight, frameWidth, frameChannels = cv2.imread(filenames[0]).shape
# # rows, cols, 3 for a frame
# frames = np.zeros((frameCount, frameHeight, frameWidth, frameChannels),dtype=np.float32)
# # 900, rows, cols, 3 for all frames

# idx start from 0
# for idx, file_i in enumerate(filenames):
#     frames[idx] = cv2.cvtColor(cv2.imread(file_i), cv2.COLOR_BGR2RGB) / 255.0

pastHomographies = np.zeros((len(filenames),len(filenames), 3, 3),dtype=np.float32)
# 900*900*(3*3) H13 = pastHomographies[1,3]
originTranslations = np.zeros((len(filenames), 2),dtype=np.float32)

# %%
# blendOutput_images = np.zeros((900,800,2000,3))
# 900 * rows * cols * 3
master_frames =[x for x in range (0, len(filenames))]

reference_frame = 140
referenceFrameIndex = master_frames.index(reference_frame)
print(referenceFrameIndex)

projectedSource, pastHomographies, originTranslations = projectImage(frames, referenceFrameIndex, referenceFrameIndex,
                                                            pastHomographies, originTranslations,
                                                            auto_H_func=auto_homography, homography_func=computeHomography)
cols = 4000
rows = 2200
# 1920*1080
H_transition = np.identity(3)
H_transition[0,2] = (cols-img_cols)/2
H_transition[1,2] = (rows-img_rows)/2

# H = np.identity(3)
# projectedSource = cv2.warpPerspective((frames[450]*255).astype(np.uint8), np.dot(H_transition, H), (cols, rows))
projectedSource = cv2.cvtColor(projectedSource,cv2.COLOR_RGB2BGR)
cv2.imwrite('images/input/my_frames_transfer2/a{:04d}.jpg'.format(referenceFrameIndex), projectedSource)
print('------frame{:04d} have been written------'.format(referenceFrameIndex))
# blendOutput_images[referenceFrameIndex] = projectedSource

for i in range(139,0,-1):
    sourceFrameIndex = master_frames[i]
    
    projectedSource, pastHomographies, originTranslations = projectImage(frames, sourceFrameIndex, referenceFrameIndex,
                                                            pastHomographies, originTranslations,
                                                            auto_H_func=auto_homography, homography_func=computeHomography)
    projectedSource = cv2.cvtColor(projectedSource,cv2.COLOR_RGB2BGR)
    cv2.imwrite('images/input/my_frames_transfer2/a{:04d}.jpg'.format(i), projectedSource)
    print('------frame{:04d} have been written------'.format(i))
#     blendOutput_images[sourceFrameIndex] = projectedSource
    
# for i in range(178,280,1):
#     print(i)
# #     projectedSource = cv2.warpPerspective((frames[sourceFrameIndex]*255).astype(np.uint8),
# #                                          H_transition.dot(auto_homography(frames[sourceFrameIndex],frames[450],computeHomography)),
# #                                          (2000, 800))
#     sourceFrameIndex = master_frames[i]

#     projectedSource, pastHomographies, originTranslations = projectImage(frames, sourceFrameIndex, referenceFrameIndex,
#                                                             pastHomographies, originTranslations,
#                                                             auto_H_func=auto_homography, homography_func=computeHomography)
#     projectedSource = cv2.cvtColor(projectedSource,cv2.COLOR_RGB2BGR)
#     cv2.imwrite('images/input/my_frames_transfer2/a{:04d}.jpg'.format(i), projectedSource)
#     print('------frame{:04d} have been written------'.format(i))
# #     blendOutput_images[sourceFrameIndex] = projectedSource
# Out:
# 140
# once
# Overlap:2066665
# Error:0.0
# ------frame0140 have been written------
# once
# Overlap:2004347
# Error:1.5859501421952714e-05
# ------frame0139 have been written------
# once
# Overlap:1945110
# Error:2.2393131701793403e-05
# ------frame0138 have been written------
# once
# best score: 1002.000000
# Overlap:1886562
# Error:2.6004509575976024e-05
# ------frame0137 have been written------
# once
# best score: 975.000000
# Overlap:1827398
# Error:2.7102794353057736e-05
# ------frame0136 have been written------
# once
# best score: 819.000000
# Overlap:1770938
# Error:2.9983501859058e-05
# ------frame0135 have been written------
# once
# best score: 767.000000
# Overlap:1717244
# Error:3.1623547279024025e-05
# ------frame0134 have been written------
# once
# best score: 692.000000
# Overlap:1646722
# Error:3.31311381430362e-05
# ------frame0133 have been written------
# once
# best score: 713.000000
# Overlap:1593883
# Error:3.5427499307414355e-05
# ------frame0132 have been written------
# once
# best score: 580.000000
# Overlap:1528387
# Error:3.60145898736349e-05
# ------frame0131 have been written------
# once
# best score: 570.000000
# Overlap:1478063
# Error:3.814862205764224e-05
# ------frame0130 have been written------
# once
# best score: 543.000000
# Overlap:1412805
# Error:4.152262977184406e-05
# Finding better homography...
# Overlap:1478063
# Error:3.814862205764224e-05
# best score: 12224.000000
# best score: 2050.000000
# Overlap:1999009
# Error:1.760137831445263e-05
# Found better homography
# ------frame0129 have been written------
# once
# best score: 489.000000
# Overlap:1352365
# Error:4.413617517676072e-05
# Finding better homography...
# Overlap:1416871
# Error:4.187027585441156e-05
# best score: 13463.000000
# best score: 2461.000000
# Overlap:2007502
# Error:1.8228374092119985e-05
# Found better homography
# ------frame0128 have been written------
# once
# best score: 460.000000
# Overlap:1305625
# Error:4.5891326067443796e-05
# Finding better homography...
# Overlap:1416871
# Error:4.187027585441156e-05
# best score: 1684.000000
# Overlap:1942201
# Error:2.1956811304777297e-05
# Found better homography
# ------frame0127 have been written------
# once
# best score: 434.000000
# Overlap:1250578
# Error:4.813076065633821e-05
# Finding better homography...
# Overlap:1359381
# Error:4.296114317684134e-05
# best score: 13776.000000
# best score: 1794.000000
# Overlap:1932782
# Error:2.1508018490545512e-05
# Found better homography
# ------frame0126 have been written------
# once
# best score: 399.000000
# Overlap:1191715
# Error:4.910480497570831e-05
# Finding better homography...
# Overlap:1299959
# Error:4.5140967614050704e-05
# best score: 13876.000000
# best score: 1803.000000
# Overlap:1940759
# Error:2.2025028138242377e-05
# Found better homography
# ------frame0125 have been written------
# once
# best score: 422.000000
# Overlap:1133917
# Error:5.066583302045544e-05
# Finding better homography...
# Overlap:1239632
# Error:4.6536004377446176e-05
# best score: 15009.000000
# best score: 1878.000000
# Overlap:1941816
# Error:2.291496953090153e-05
# Found better homography
# ------frame0124 have been written------
# once
# best score: 355.000000
# Overlap:1079146
# Error:5.192171389078338e-05
# Finding better homography...
# Overlap:1187206
# Error:4.993777779022109e-05
# best score: 16079.000000
# best score: 1854.000000
# Overlap:1945553
# Error:2.1939303369340348e-05
# Found better homography
# ------frame0123 have been written------
# once
# best score: 344.000000
# Overlap:1025209
# Error:5.3208921012016845e-05
# Finding better homography...
# Overlap:1127450
# Error:5.132598869391836e-05
# best score: 16051.000000
# best score: 1867.000000
# Overlap:1946839
# Error:2.2119953554707908e-05
# Found better homography
# ------frame0122 have been written------
# once
# best score: 290.000000
# Overlap:957435
# Error:5.4346739885675186e-05
# Finding better homography...
# Overlap:1127450
# Error:5.132598869391836e-05
# best score: 1622.000000
# Overlap:1883450
# Error:2.4483834350929966e-05
# Found better homography
# ------frame0121 have been written------
# once
# best score: 314.000000
# Overlap:913598
# Error:5.767493955983346e-05
# Finding better homography...
# Overlap:1072714
# Error:5.4368816205631096e-05
# best score: 15542.000000
# best score: 1531.000000
# Overlap:1880914
# Error:2.4445503839755335e-05
# Found better homography
# ------frame0120 have been written------
# once
# best score: 249.000000
# Overlap:852769
# Error:5.8786448180539016e-05
# Finding better homography...
# Overlap:1016470
# Error:5.612285079557095e-05
# best score: 15734.000000
# best score: 1499.000000
# Overlap:1885636
# Error:2.4754647256849308e-05
# Found better homography
# ------frame0119 have been written------
# once
# best score: 214.000000
# Overlap:797444
# Error:6.025599479502648e-05
# Finding better homography...
# Overlap:959782
# Error:5.838744855176852e-05
# best score: 15622.000000
# best score: 1501.000000
# Overlap:1885961
# Error:2.5239737126181024e-05
# Found better homography
# ------frame0118 have been written------
# once
# best score: 187.000000
# Overlap:756567
# Error:6.190517880841222e-05
# Finding better homography...
# Overlap:903535
# Error:6.443568240421815e-05
# best score: 15473.000000
# best score: 1371.000000
# Overlap:1899035
# Error:2.437070163283705e-05
# Overlap:1072714
# Error:5.4368816205631096e-05
# best score: 894.000000
# Overlap:1724320
# Error:3.0218229318180538e-05
# Found better homography
# ------frame0117 have been written------
# once
# best score: 169.000000
# Overlap:700581
# Error:6.272929981895895e-05
# Finding better homography...
# Overlap:850385
# Error:6.707346486935266e-05
# best score: 14330.000000
# best score: 1437.000000
# Overlap:1902460
# Error:2.3448828061647757e-05
# Overlap:1016470
# Error:5.612285079557095e-05
# best score: 923.000000
# Overlap:1720930
# Error:2.9764296043577475e-05
# Found better homography
# ------frame0116 have been written------
# once
# best score: 154.000000
# Overlap:650669
# Error:6.440487992421e-05
# Finding better homography...
# Overlap:850385
# Error:6.707346486935266e-05
# best score: 1321.000000
# Overlap:1843851
# Error:2.5298088086637814e-05
# Overlap:1072714
# Error:5.4368816205631096e-05
# best score: 750.000000
# Overlap:1606988
# Error:3.286492209609832e-05
# Found better homography
# ------frame0115 have been written------
# once
# best score: 130.000000
# Overlap:589669
# Error:6.75211505752318e-05
# Finding better homography...
# Overlap:796993
# Error:6.798467429775605e-05
# best score: 14322.000000
# best score: 1280.000000
# Overlap:1843601
# Error:2.5750321215706492e-05
# Overlap:1016470
# Error:5.612285079557095e-05
# best score: 711.000000
# Overlap:1605808
# Error:3.531890476149736e-05
# Found better homography
# ------frame0114 have been written------
# once
# best score: 138.000000
# Overlap:534361
# Error:6.907926551188526e-05
# Finding better homography...
# Overlap:750743
# Error:7.330785607096162e-05
# best score: 12889.000000
# best score: 1360.000000
# Overlap:1838587
# Error:2.540355549996405e-05
# Overlap:959782
# Error:5.838744855176852e-05
# best score: 743.000000
# Overlap:1607492
# Error:3.6535767514768376e-05
# Found better homography
# ------frame0113 have been written------
# once
# best score: 105.000000
# Overlap:499171
# Error:7.088643526150738e-05
# Finding better homography...
# Overlap:691114
# Error:7.504801004862634e-05
# best score: 12373.000000
# best score: 1341.000000
# Overlap:1838470
# Error:2.6301712571859107e-05
# Overlap:903535
# Error:6.443568240421815e-05
# best score: 798.000000
# Overlap:1615109
# Error:3.4869552051856344e-05
# Found better homography
# ------frame0112 have been written------
# once
# best score: 92.000000
# Overlap:399299
# Error:8.09092360697547e-05
# Finding better homography...
# Overlap:645407
# Error:7.828449633603275e-05
# best score: 12469.000000
# best score: 1332.000000
# Overlap:1842554
# Error:2.43974006134128e-05
# Found better homography
# ------frame0111 have been written------
# once
# best score: 65.000000
# Overlap:379263
# Error:7.985106932243515e-05
# Finding better homography...
# Overlap:585263
# Error:8.244713506462484e-05
# best score: 12351.000000
# best score: 1272.000000
# Overlap:1850847
# Error:2.4392889374461443e-05
# Overlap:796993
# Error:6.798467429775605e-05
# best score: 779.000000
# Overlap:1634909
# Error:3.204368342222545e-05
# Found better homography
# ------frame0110 have been written------
# once
# best score: 51.000000
# Overlap:290558
# Error:9.351174813780249e-05
# Finding better homography...
# Overlap:585263
# Error:8.244713506462484e-05
# best score: 1149.000000
# Overlap:1781768
# Error:2.781686216759459e-05
# Found better homography
# ------frame0109 have been written------
# once
# best score: 40.000000
# Overlap:167830
# Error:0.00014401191703342865
# Finding better homography...
# Overlap:536688
# Error:8.636067423836888e-05
# best score: 12322.000000
# best score: 1073.000000
# Overlap:1777282
# Error:2.820837351023261e-05
# Found better homography
# ------frame0108 have been written------
# once
# best score: 10.000000
# Overlap:1150847
# Error:0.0002055008108072135
# Finding better homography...
# Overlap:485934
# Error:9.185987215262417e-05
# best score: 12319.000000
# best score: 1167.000000
# Overlap:1779317
# Error:2.71682203748081e-05
# Found better homography
# ------frame0107 have been written------
# once
# best score: 13.000000
# Overlap:0
# Error:3.4028234663852886e+38
# Finding better homography...
# Overlap:440060
# Error:9.513279302036888e-05
# best score: 11990.000000
# best score: 1001.000000
# Overlap:1776310
# Error:2.7779841795112362e-05
# Found better homography
# ------frame0106 have been written------
# once
# best score: 7.000000
# Overlap:2016332
# Error:0.00016604953868990907
# Finding better homography...
# Overlap:382039
# Error:0.00010063112027804035
# best score: 11209.000000
# best score: 1079.000000
# Overlap:1758759
# Error:2.6956660077101312e-05
# Found better homography
# ------frame0105 have been written------
# once
# best score: 5.000000
# Overlap:110324
# Error:0.0004620929828021888
# Finding better homography...
# Overlap:327094
# Error:0.00011001224271183193
# best score: 11551.000000
# best score: 1035.000000
# Overlap:1752548
# Error:2.8549157228702718e-05
# Found better homography
# ------frame0104 have been written------
# once
# best score: 5.000000
# Overlap:1773402
# Error:0.00015215465724165676
# Finding better homography...
# Overlap:327094
# Error:0.00011001224271183193
# best score: 943.000000
# Overlap:1696013
# Error:2.8437220523450228e-05
# Found better homography
# ------frame0103 have been written------
# once
# best score: 6.000000
# Overlap:2012769
# Error:0.0001401855470767116
# Finding better homography...
# Overlap:273915
# Error:0.00012162366184565082
# best score: 11358.000000
# best score: 806.000000
# Overlap:1686615
# Error:2.8421643093943252e-05
# Found better homography
# ------frame0102 have been written------
# once
# best score: 5.000000
# Overlap:1983817
# Error:0.00017174762148394423
# Finding better homography...
# Overlap:218025
# Error:0.0001403681768636857
# best score: 11371.000000
# best score: 717.000000
# Overlap:1689346
# Error:2.7769787595244307e-05
# Found better homography
# ------frame0101 have been written------
# once
# best score: 6.000000
# Overlap:1940572
# Error:0.00015580045113442495
# Finding better homography...
# Overlap:164641
# Error:0.00015757684266758256
# best score: 10720.000000
# best score: 759.000000
# Overlap:1659592
# Error:2.781031660430067e-05
# Overlap:485934
# Error:9.185987215262417e-05
# best score: 466.000000
# Overlap:1338384
# Error:4.076692876708916e-05
# Found better homography
# ------frame0100 have been written------
# once
# best score: 5.000000
# Overlap:1070047
# Error:0.00013342839631821598
# Finding better homography...
# Overlap:100134
# Error:0.00022079657108821244
# best score: 11008.000000
# best score: 696.000000
# Overlap:1674239
# Error:2.5483048604568666e-05
# Overlap:440060
# Error:9.513279302036888e-05
# best score: 412.000000
# Overlap:1322920
# Error:4.187551677021931e-05
# Found better homography
# ------frame0099 have been written------
# once
# best score: 5.000000
# Overlap:1963757
# Error:0.0001707685486284455
# Finding better homography...
# Overlap:42763
# Error:0.0003665719965723376
# best score: 10736.000000
# best score: 679.000000
# Overlap:1654684
# Error:2.478909719714413e-05
# Overlap:382039
# Error:0.00010063112027804035
# best score: 416.000000
# Overlap:1302268
# Error:4.1778392823493906e-05
# Found better homography
# ------frame0098 have been written------
# once
# best score: 5.000000
# Overlap:1932597
# Error:0.00015185493104852326
# Finding better homography...
# Overlap:42763
# Error:0.0003665719965723376
# best score: 589.000000
# Overlap:1581538
# Error:2.6291749489784125e-05
# Overlap:440060
# Error:9.513279302036888e-05
# best score: 330.000000
# Overlap:1194979
# Error:4.3390435364366346e-05
# Found better homography
# ------frame0097 have been written------
# once
# best score: 6.000000
# Overlap:1925393
# Error:0.00015633372243095797
# Finding better homography...
# Overlap:2718
# Error:0.0009914698006031949
# best score: 10395.000000
# best score: 484.000000
# Overlap:1570622
# Error:2.6855113378721372e-05
# Overlap:382039
# Error:0.00010063112027804035
# best score: 301.000000
# Overlap:1180288
# Error:4.412680491413569e-05
# Found better homography
# ------frame0096 have been written------
# once
# best score: 5.000000
# Overlap:1041293
# Error:0.00013593219066589555
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 9974.000000
# best score: 413.000000
# Overlap:1560609
# Error:2.589924039802108e-05
# Overlap:327094
# Error:0.00011001224271183193
# best score: 293.000000
# Overlap:1163344
# Error:4.566460429532544e-05
# Found better homography
# ------frame0095 have been written------
# once
# best score: 6.000000
# Overlap:1784057
# Error:0.00015111676361280067
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 9632.000000
# best score: 430.000000
# Overlap:1553800
# Error:2.624947474602104e-05
# Overlap:273915
# Error:0.00012162366184565082
# best score: 238.000000
# Overlap:1132171
# Error:4.309167404146365e-05
# Found better homography
# ------frame0094 have been written------
# once
# best score: 7.000000
# Overlap:1953689
# Error:0.0001639947850331213
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 9388.000000
# best score: 422.000000
# Overlap:1555233
# Error:2.626386039380728e-05
# Overlap:218025
# Error:0.0001403681768636857
# best score: 212.000000
# Overlap:1134555
# Error:3.970660650402273e-05
# Found better homography
# ------frame0093 have been written------
# once
# best score: 6.000000
# Overlap:1269857
# Error:0.00014836875829277217
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 9042.000000
# best score: 394.000000
# Overlap:1539610
# Error:2.517636208882885e-05
# Overlap:164641
# Error:0.00015757684266758256
# best score: 231.000000
# Overlap:1114656
# Error:3.9746527323509276e-05
# Overlap:536688
# Error:8.636067423836888e-05
# best score: 130.000000
# Overlap:762298
# Error:6.015589196500744e-05
# Found better homography
# ------frame0092 have been written------
# once
# best score: 8.000000
# Overlap:2058136
# Error:0.00014995533997923138
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 357.000000
# Overlap:1471832
# Error:2.7346158305263103e-05
# Overlap:218025
# Error:0.0001403681768636857
# best score: 221.000000
# Overlap:990079
# Error:4.341137927291049e-05
# Found better homography
# ------frame0091 have been written------
# once
# best score: 10.000000
# Overlap:1321362
# Error:0.00013312619220435913
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 8772.000000
# best score: 288.000000
# Overlap:1465718
# Error:2.69667032836378e-05
# Overlap:164641
# Error:0.00015757684266758256
# best score: 195.000000
# Overlap:990500
# Error:4.30789169808137e-05
# Overlap:585263
# Error:8.244713506462484e-05
# best score: 99.000000
# Overlap:560129
# Error:7.038905014663852e-05
# Found better homography
# ------frame0090 have been written------
# once
# best score: 10.000000
# Overlap:1436168
# Error:0.00018336770445845853
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 8471.000000
# best score: 273.000000
# Overlap:1486830
# Error:2.9512043476979695e-05
# Overlap:100134
# Error:0.00022079657108821244
# best score: 214.000000
# Overlap:976909
# Error:4.070548737755981e-05
# Overlap:536688
# Error:8.636067423836888e-05
# best score: 100.000000
# Overlap:552665
# Error:7.321203629070536e-05
# Found better homography
# ------frame0089 have been written------
# once
# best score: 8.000000
# Overlap:2034445
# Error:0.00013668630695964462
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 7958.000000
# best score: 305.000000
# Overlap:1481604
# Error:2.9698017526013463e-05
# Overlap:42763
# Error:0.0003665719965723376
# best score: 176.000000
# Overlap:965163
# Error:3.9806447230073163e-05
# Overlap:485934
# Error:9.185987215262417e-05
# best score: 86.000000
# Overlap:516611
# Error:8.114154949799218e-05
# Found better homography
# ------frame0088 have been written------
# once
# best score: 12.000000
# Overlap:2064048
# Error:0.00015376502067185462
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 7309.000000
# best score: 303.000000
# Overlap:1470643
# Error:2.9109063724943313e-05
# Overlap:2718
# Error:0.0009914698006031949
# best score: 197.000000
# Overlap:933752
# Error:4.288478098128667e-05
# Overlap:440060
# Error:9.513279302036888e-05
# best score: 85.000000
# Overlap:512353
# Error:7.032672277197875e-05
# Found better homography
# ------frame0087 have been written------
# once
# best score: 9.000000
# Overlap:1977226
# Error:0.00015557607308072966
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 6870.000000
# best score: 312.000000
# Overlap:1483840
# Error:2.948111437792375e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 183.000000
# Overlap:937849
# Error:4.106422990310828e-05
# Overlap:382039
# Error:0.00010063112027804035
# best score: 82.000000
# Overlap:495159
# Error:7.135553626874788e-05
# Found better homography
# ------frame0086 have been written------
# once
# best score: 7.000000
# Overlap:1998129
# Error:0.00013935894527424472
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 287.000000
# Overlap:1402247
# Error:2.9786100307514413e-05
# Overlap:2718
# Error:0.0009914698006031949
# best score: 133.000000
# Overlap:806514
# Error:4.699367000523255e-05
# Overlap:485934
# Error:9.185987215262417e-05
# best score: 34.000000
# Overlap:311998
# Error:9.703739120539907e-05
# Found better homography
# ------frame0085 have been written------
# once
# best score: 12.000000
# Overlap:2044629
# Error:0.00013528663223508222
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 5939.000000
# best score: 296.000000
# Overlap:1408399
# Error:3.031626269670545e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 122.000000
# Overlap:815701
# Error:4.7222677321153404e-05
# Overlap:440060
# Error:9.513279302036888e-05
# best score: 40.000000
# Overlap:295849
# Error:0.0001108802814546163
# Found better homography
# ------frame0084 have been written------
# once
# best score: 8.000000
# Overlap:1336793
# Error:0.0001715827059389233
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 6081.000000
# best score: 293.000000
# Overlap:1405738
# Error:3.005796375894901e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 126.000000
# Overlap:808871
# Error:5.096783344340196e-05
# Overlap:382039
# Error:0.00010063112027804035
# best score: 19.000000
# Overlap:285373
# Error:0.00011310753074842573
# Found better homography
# ------frame0083 have been written------
# once
# best score: 10.000000
# Overlap:2037538
# Error:0.00012645912046819392
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 6230.000000
# best score: 309.000000
# Overlap:1409606
# Error:2.9318161678824737e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 173.000000
# Overlap:809374
# Error:4.953764288884841e-05
# Overlap:327094
# Error:0.00011001224271183193
# best score: 37.000000
# Overlap:258156
# Error:0.00011335664777274532
# Found better homography
# ------frame0082 have been written------
# once
# best score: 10.000000
# Overlap:2039501
# Error:0.00014314372103459456
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 5976.000000
# best score: 262.000000
# Overlap:1422041
# Error:2.8977291695882655e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 140.000000
# Overlap:813781
# Error:4.680554867282741e-05
# Overlap:273915
# Error:0.00012162366184565082
# best score: 15.000000
# Overlap:273434
# Error:9.341295785450319e-05
# Found better homography
# ------frame0081 have been written------
# once
# best score: 8.000000
# Overlap:1949506
# Error:0.00014912177122563413
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 5865.000000
# best score: 379.000000
# Overlap:1433595
# Error:2.841425203361699e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 163.000000
# Overlap:816742
# Error:4.880688538720783e-05
# Overlap:218025
# Error:0.0001403681768636857
# best score: 47.000000
# Overlap:258790
# Error:8.307275755468168e-05
# Found better homography
# ------frame0080 have been written------
# once
# best score: 10.000000
# Overlap:1724071
# Error:0.00018648386018205244
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 301.000000
# Overlap:1364197
# Error:3.076554841060422e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 128.000000
# Overlap:692950
# Error:5.4221846115741166e-05
# Overlap:327094
# Error:0.00011001224271183193
# best score: 5.000000
# Overlap:2069858
# Error:0.0001646203299979942
# Found better homography
# ------frame0079 have been written------
# once
# best score: 8.000000
# Overlap:1809901
# Error:0.0001623293256484633
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 6311.000000
# best score: 316.000000
# Overlap:1382081
# Error:3.14212434678738e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 133.000000
# Overlap:693327
# Error:5.263651219320761e-05
# Overlap:273915
# Error:0.00012162366184565082
# best score: 8.000000
# Overlap:2032688
# Error:0.00014659985366390033
# Found better homography
# ------frame0078 have been written------
# once
# best score: 7.000000
# Overlap:2038216
# Error:0.0001902299995633962
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 6407.000000
# best score: 317.000000
# Overlap:1398693
# Error:3.292898063141313e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 104.000000
# Overlap:703085
# Error:5.413567994271622e-05
# Overlap:218025
# Error:0.0001403681768636857
# best score: 6.000000
# Overlap:0
# Error:3.4028234663852886e+38
# Overlap:750743
# Error:7.330785607096162e-05
# best score: 7.000000
# Overlap:1859756
# Error:0.0001233511014731012
# Found better homography
# ------frame0077 have been written------
# once
# best score: 8.000000
# Overlap:1940891
# Error:0.00013719126110110362
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 6663.000000
# best score: 369.000000
# Overlap:1406348
# Error:3.318471280970914e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 99.000000
# Overlap:705994
# Error:5.124472753686565e-05
# Overlap:164641
# Error:0.00015757684266758256
# best score: 7.000000
# Overlap:2029102
# Error:0.0001763721645032699
# Overlap:691114
# Error:7.504801004862634e-05
# best score: 6.000000
# Overlap:2036568
# Error:0.0001517781607772737
# Overlap:1239632
# Error:4.6536004377446176e-05
# best score: 6.000000
# Overlap:2068120
# Error:0.00016913996316597022
# ------frame0076 have been written------
# once
# best score: 6.000000
# Overlap:1988209
# Error:0.00017549661613554994
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 6897.000000
# best score: 284.000000
# Overlap:1454991
# Error:4.219069522131269e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 99.000000
# Overlap:731000
# Error:5.590352447723822e-05
# Overlap:100134
# Error:0.00022079657108821244
# best score: 9.000000
# Overlap:1853354
# Error:0.00016859116846139802
# Overlap:645407
# Error:7.828449633603275e-05
# best score: 7.000000
# Overlap:2070742
# Error:0.0001607680805025093
# Found better homography
# ------frame0075 have been written------
# once
# best score: 9.000000
# Overlap:2012596
# Error:0.00018805647943150015
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 7053.000000
# best score: 288.000000
# Overlap:1435830
# Error:3.5883211391005986e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 100.000000
# Overlap:723918
# Error:5.2505838553436425e-05
# Overlap:42763
# Error:0.0003665719965723376
# best score: 9.000000
# Overlap:0
# Error:3.4028234663852886e+38
# Overlap:585263
# Error:8.244713506462484e-05
# best score: 6.000000
# Overlap:1808479
# Error:0.0001610408740929616
# Found better homography
# ------frame0074 have been written------
# once
# best score: 9.000000
# Overlap:1991124
# Error:0.00013864479166170692
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 272.000000
# Overlap:1373807
# Error:3.522691405833122e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 75.000000
# Overlap:614879
# Error:6.217780391400908e-05
# Overlap:164641
# Error:0.00015757684266758256
# best score: 6.000000
# Overlap:2010039
# Error:0.00016255710694204154
# Overlap:750743
# Error:7.330785607096162e-05
# best score: 6.000000
# Overlap:1132315
# Error:0.00026926929431651147
# Overlap:1359381
# Error:4.296114317684134e-05
# best score: 7.000000
# Overlap:1698923
# Error:0.00017343580360310734
# ------frame0073 have been written------
# once
# best score: 7.000000
# Overlap:982511
# Error:0.00024567101816504915
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 7400.000000
# best score: 289.000000
# Overlap:1408356
# Error:4.212173517198549e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 75.000000
# Overlap:624933
# Error:6.380608915641759e-05
# Overlap:100134
# Error:0.00022079657108821244
# best score: 7.000000
# Overlap:1305835
# Error:0.00021855222457953775
# Found better homography
# ------frame0072 have been written------
# once
# best score: 12.000000
# Overlap:2023432
# Error:0.0001589803798377424
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 7535.000000
# best score: 256.000000
# Overlap:1434259
# Error:4.68845273362337e-05
# Overlap:0
# Error:3.4028234663852886e+38
# best score: 76.000000
# Overlap:609518
# Error:6.091494145679442e-05
# Overlap:42763
# Error:0.0003665719965723376
# best score: 6.000000
# Overlap:1292086
# Error:0.00023286688540090808
# Overlap:645407
# Error:7.828449633603275e-05
# best score: 8.000000
# Overlap:1978699
# Error:0.0001720160637948666
# Overlap:1239632
# Error:4.6536004377446176e-05
# best score: 11.000000
# Overlap:2070623
# Error:0.0002006491133399439
# ------frame0071 have been written------
# once
# best score: 9.000000
# Overlap:1775825
# Error:0.00013908105256331784
# Finding better homography...
# Overlap:0
# Error:3.4028234663852886e+38
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-a4dad12ee1dc> in <module>()
#      29     projectedSource, pastHomographies, originTranslations = projectImage(frames, sourceFrameIndex, referenceFrameIndex,
#      30                                                             pastHomographies, originTranslations,
# ---> 31                                                             auto_H_func=auto_homography, homography_func=computeHomography)
#      32     projectedSource = cv2.cvtColor(projectedSource,cv2.COLOR_RGB2BGR)
#      33     cv2.imwrite('images/input/my_frames_transfer2/a{:04d}.jpg'.format(i), projectedSource)
#
# <ipython-input-63-1d3d27ec73d4> in projectImage(frames, sourceFrameIndex, referenceFrameIndex, pastHomographies, originTranslations, xrange, yrange, overlapThreshold, errorThreshold, numKeyframes, checkAllKeyframes, auto_H_func, homography_func, normalization_func)
#      81             # compute homography and projected image from source frame to
#      82             # keyframe (new reference = keyframe)
# ---> 83             _, keyframeToKeyframeTransform, keyframeToKeyframe_origin_coord = transformImage(frames, keyframeIndex, keyframeIndex, pastHomographies, xrange, yrange,  auto_H_func, homography_func, normalization_func)
#      84             H1, sourceToKeyframeTransform, srcToKeyframe_origin_coord = transformImage(frames, sourceFrameIndex, keyframeIndex, pastHomographies, xrange, yrange,  auto_H_func, homography_func, normalization_func)
#      85             b, error2 = computeOverlap(sourceToKeyframeTransform, srcToKeyframe_origin_coord, keyframeToKeyframeTransform, keyframeToKeyframe_origin_coord, overlapThreshold)
#
# ~/Desktop/CS 445/CS445_proj5/Project 5/jieting2_proj5/utils.py in transformImage(frames, sourceFrameIndex, referenceFrameIndex, pastHomographies, xrange, yrange, auto_H_func, homography_func, normalization_func)
#     178     else:
#     179         homography = auto_H_func(frames[sourceFrameIndex], frames[referenceFrameIndex],
# --> 180                                  homography_func, normalization_func)
#     181         pastHomographies[sourceFrameIndex, referenceFrameIndex] = homography.astype(np.float32)
#     182
#
# <ipython-input-45-f079c1a0be6d> in auto_homography(Ia, Ib, homography_func, normalization_func)
#      74
#      75         ok_t = np.sqrt(du**2 + dv**2) < 1  # you may need to play with this threshold
# ---> 76         score_t = sum(ok_t)
#      77
#      78         if score_t > best_score:
#
# KeyboardInterrupt:

# %%
import utils

# %%
utils.imageFolder2mpeg('./images/input/my_frames_transfer2',output_path='./images/input/output_my_result2.mpeg', fps=24.0)

# %%
for i in range (0,len(filenames)):
    blendedOutput = utils.blendImages(blendOutput_images[i],blendedOutput)
# blendedOutput = utils.blendImages(projectedSource, projectedReference)
plt.imshow(blendedOutput)

# %%
# im2_cv2 = cv2.imread(im2_path)
# im2_RGB = cv2.cvtColor(im2_cv2,cv2.COLOR_BGR2RGB)
# im2_plt = im2_RGB.astype(np.float32)/255  !!! (value/255.0) instead of 255
# for idx, file_i in enumerate(filenames):
#     frames[idx] = cv2.cvtColor(cv2.imread(file_i), cv2.COLOR_BGR2RGB) / 255.0

# %% [markdown]
# ### Part 4: Create background panorama
#
# In this part you will remove moving objects from the video and create a background panorama that should incorporate pixels from all the frames.
#
# In the video you produced in __part 3__ each pixel appears in several frames. You need to estimate which of the many colors correspond to the background. We take advantage of the fact that the background color is fixed while the foreground color changes frequently (because foreground moves).
#
# <img src="images/project_5/background.jpg" alt="Drawing" style="float: center; width: 500px"/>
#
#
# For each pixel in the sequence of __part 3__, determine all valid colors (colors that come from all frames that overlap that pixel). You can experiment with different methods for determining the background color of each pixel, as discussed in class. Perform the same procedure for all pixels and generate output. The output should be a completed panorama showing only pixels of background or non-moving objects.

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Part 5: Create background movie
#
# Map the background panorama to the movie coordinates. For each frame of the movie, say frame 1, you need to estimate a projection from the panorama to frame 1. Note, you should be able to re-use the homographies that you estimated in __Part 3__. Perform this for all frames and generate a movie that looks like the input movie but shows only background pixels. All moving objects that belong to the foreground must be removed.

# %%
import os
import cv2
import numpy as np

# %% [markdown]
# ### Part 6: Create foreground movie
#
# In the background video, moving objects are removed. In each frame, those pixels that are different enough than the background color are considered foreground. For each frame determine foreground pixels and generate a movie that only includes foreground pixels.

# %%
import os
import cv2
import numpy as np

# %% [markdown]
# ## Bells and whistles
